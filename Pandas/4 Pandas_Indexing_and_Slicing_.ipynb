# %%
import numpy as np
import pandas as pd

# %% [markdown]
# diffrence between loc and iloc with iloc we can access the data with index and using loc we can access the data with label name

# %% [markdown]
# in iloc we select wit position and in loc we select with label

# %%
dates = pd.date_range('20-09-2024',periods=8)
df = pd.DataFrame(np.random.randn(8,4),index=dates) # we can also provide columns here
df
# Out:
#                    0         1         2         3
# 2024-09-20  0.428660 -1.972700  1.007530  0.393253
# 2024-09-21 -0.359737  0.823017  1.667330  1.153350
# 2024-09-22 -1.150473  1.745118 -0.443183  1.468314
# 2024-09-23 -0.399934  0.508075  0.878393  0.564230
# 2024-09-24 -0.629624  0.795364 -0.328399 -0.966566
# 2024-09-25 -0.220793 -0.121421 -1.702588 -0.579475
# 2024-09-26  0.001045 -0.146991  0.311149  0.036234
# 2024-09-27 -1.433178 -0.749112 -0.486706 -0.747407

# %%
# add columns
df.columns = ['A','B','C','D']
df
# Out:
#                    A         B         C         D
# 2024-09-20  0.428660 -1.972700  1.007530  0.393253
# 2024-09-21 -0.359737  0.823017  1.667330  1.153350
# 2024-09-22 -1.150473  1.745118 -0.443183  1.468314
# 2024-09-23 -0.399934  0.508075  0.878393  0.564230
# 2024-09-24 -0.629624  0.795364 -0.328399 -0.966566
# 2024-09-25 -0.220793 -0.121421 -1.702588 -0.579475
# 2024-09-26  0.001045 -0.146991  0.311149  0.036234
# 2024-09-27 -1.433178 -0.749112 -0.486706 -0.747407

# %%
df.rename(columns={'A':'D','B':'C','C':'B','D':'D'},) # we can also use this method
# Out:
#                    D         C         B         D
# 2024-09-20  0.428660 -1.972700  1.007530  0.393253
# 2024-09-21 -0.359737  0.823017  1.667330  1.153350
# 2024-09-22 -1.150473  1.745118 -0.443183  1.468314
# 2024-09-23 -0.399934  0.508075  0.878393  0.564230
# 2024-09-24 -0.629624  0.795364 -0.328399 -0.966566
# 2024-09-25 -0.220793 -0.121421 -1.702588 -0.579475
# 2024-09-26  0.001045 -0.146991  0.311149  0.036234
# 2024-09-27 -1.433178 -0.749112 -0.486706 -0.747407

# %%
df.rename_axis('Date')
# Out:
#                    A         B         C         D
# Date
# 2024-09-20  0.428660 -1.972700  1.007530  0.393253
# 2024-09-21 -0.359737  0.823017  1.667330  1.153350
# 2024-09-22 -1.150473  1.745118 -0.443183  1.468314
# 2024-09-23 -0.399934  0.508075  0.878393  0.564230
# 2024-09-24 -0.629624  0.795364 -0.328399 -0.966566
# 2024-09-25 -0.220793 -0.121421 -1.702588 -0.579475
# 2024-09-26  0.001045 -0.146991  0.311149  0.036234
# 2024-09-27 -1.433178 -0.749112 -0.486706 -0.747407

# %% [markdown]
# **Selecting**

# %% [markdown]
# using loc and iloc

# %%
df.iloc[1] # second row
# Out:
# A   -0.359737
# B    0.823017
# C    1.667330
# D    1.153350
# Name: 2024-09-21 00:00:00, dtype: float64

# %%
df.iloc[1:5] # range
# Out:
#                    A         B         C         D
# 2024-09-21 -0.808828 -0.062810  0.652455 -0.111944
# 2024-09-22  0.129117  0.470941  0.333752  0.803249
# 2024-09-23  0.797133 -0.151877 -1.454577  0.373286
# 2024-09-24  0.242940 -0.431656  2.456066 -0.748917

# %%
df.iloc[5,2] # 6th row 3rd col item
# Out:
# 0.6540835339821771

# %%
df.iloc[1:5,1:4]
# Out:
#                    B         C         D
# 2024-09-21 -0.062810  0.652455 -0.111944
# 2024-09-22  0.470941  0.333752  0.803249
# 2024-09-23 -0.151877 -1.454577  0.373286
# 2024-09-24 -0.431656  2.456066 -0.748917

# %%
# with step
df.iloc[5,::2]
# Out:
# A   -1.880945
# C    0.654084
# Name: 2024-09-25 00:00:00, dtype: float64

# %%
df.iloc[1:6,::2] # column step
# Out:
#                    A         C
# 2024-09-21 -0.808828  0.652455
# 2024-09-22  0.129117  0.333752
# 2024-09-23  0.797133 -1.454577
# 2024-09-24  0.242940  2.456066
# 2024-09-25 -1.880945  0.654084

# %%
# row and column step
df.iloc[1:8:2,::2] # 1,3,5,6 rows Withcolumn a,b
# Out:
#                    A         C
# 2024-09-21 -0.808828  0.652455
# 2024-09-23  0.797133 -1.454577
# 2024-09-25 -1.880945  0.654084
# 2024-09-27  0.359361  0.718370
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['A'].plot(kind='hist', bins=20, title='A')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['C'].plot(kind='hist', bins=20, title='C')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='A', y='C', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
# ...

# %%
df
# Out:
#                    A         B         C         D
# 2024-09-20 -0.413746  0.787280 -0.998448  2.559626
# 2024-09-21 -0.808828 -0.062810  0.652455 -0.111944
# 2024-09-22  0.129117  0.470941  0.333752  0.803249
# 2024-09-23  0.797133 -0.151877 -1.454577  0.373286
# 2024-09-24  0.242940 -0.431656  2.456066 -0.748917
# 2024-09-25 -1.880945  0.983353  0.654084 -1.292185
# 2024-09-26 -0.958018  1.140304  1.187228  0.699864
# 2024-09-27  0.359361  0.543777  0.718370 -0.790835

# %%
# we can Also use negative indexing
df.iloc[:-2:2,:-1:2]
# Out:
#                    A         C
# 2024-09-20 -0.413746 -0.998448
# 2024-09-22  0.129117  0.333752
# 2024-09-24  0.242940  2.456066

# %% [markdown]
# fancy indexing

# %% [markdown]
# when we take indexing it's importent to remeber it may gives out of bound error if you give index that not in DF

# %%
df.iloc[[1,3,5,7]]
# Out:
#                    A         B         C         D
# 2024-09-21 -0.808828 -0.062810  0.652455 -0.111944
# 2024-09-23  0.797133 -0.151877 -1.454577  0.373286
# 2024-09-25 -1.880945  0.983353  0.654084 -1.292185
# 2024-09-27  0.359361  0.543777  0.718370 -0.790835

# %%
# fancy indexing
df.iloc[[1,3,7],[1,3]]
# Out:
#                    B         D
# 2024-09-21 -0.062810 -0.111944
# 2024-09-23 -0.151877  0.373286
# 2024-09-27  0.543777 -0.790835

# %% [markdown]
# Loc

# %%
df.loc['2024-09-23'] # access the data with labels
# Out:
# A    0.797133
# B   -0.151877
# C   -1.454577
# D    0.373286
# Name: 2024-09-23 00:00:00, dtype: float64

# %%
df.loc[['2024-09-23','2024-09-21','2024-09-27']]#fancy indexing
# Out:
#                    A         B         C         D
# 2024-09-23  0.797133 -0.151877 -1.454577  0.373286
# 2024-09-21 -0.808828 -0.062810  0.652455 -0.111944
# 2024-09-27  0.359361  0.543777  0.718370 -0.790835

# %%
df.loc[['2024-09-23','2024-09-21','2024-09-27'],['A','D']]
# Out:
#                    A         D
# 2024-09-23  0.797133  0.373286
# 2024-09-21 -0.808828 -0.111944
# 2024-09-27  0.359361 -0.790835

# %%
# slicing
df.loc['2024-09-23':'2024-09-27']
# Out:
#                    A         B         C         D
# 2024-09-23  0.797133 -0.151877 -1.454577  0.373286
# 2024-09-24  0.242940 -0.431656  2.456066 -0.748917
# 2024-09-25 -1.880945  0.983353  0.654084 -1.292185
# 2024-09-26 -0.958018  1.140304  1.187228  0.699864
# 2024-09-27  0.359361  0.543777  0.718370 -0.790835

# %%
df.loc['2024-09-23':'2024-09-27','B':'D']
# Out:
#                    B         C         D
# 2024-09-23 -0.151877 -1.454577  0.373286
# 2024-09-24 -0.431656  2.456066 -0.748917
# 2024-09-25  0.983353  0.654084 -1.292185
# 2024-09-26  1.140304  1.187228  0.699864
# 2024-09-27  0.543777  0.718370 -0.790835

# %%
# with step 2
df.loc['2024-09-23':'2024-09-27':2,'A':'D':2]
# Out:
#                    A         C
# 2024-09-23  0.797133 -1.454577
# 2024-09-25 -1.880945  0.654084
# 2024-09-27  0.359361  0.718370

# %%
df[['A','B']] # normal selection
# Out:
#                    A         B
# 2024-09-20 -0.413746  0.787280
# 2024-09-21 -0.808828 -0.062810
# 2024-09-22  0.129117  0.470941
# 2024-09-23  0.797133 -0.151877
# 2024-09-24  0.242940 -0.431656
# 2024-09-25 -1.880945  0.983353
# 2024-09-26 -0.958018  1.140304
# 2024-09-27  0.359361  0.543777

# %%
df[['A','B']]
# Out:
#                    A         B
# 2024-09-20 -0.413746  0.787280
# 2024-09-21 -0.808828 -0.062810
# 2024-09-22  0.129117  0.470941
# 2024-09-23  0.797133 -0.151877
# 2024-09-24  0.242940 -0.431656
# 2024-09-25 -1.880945  0.983353
# 2024-09-26 -0.958018  1.140304
# 2024-09-27  0.359361  0.543777

# %% [markdown]
# Selection By condition

# %%
df[lambda df:df['A']>0]
# Out:
#                    A         B         C         D
# 2024-09-22  0.129117  0.470941  0.333752  0.803249
# 2024-09-23  0.797133 -0.151877 -1.454577  0.373286
# 2024-09-24  0.242940 -0.431656  2.456066 -0.748917
# 2024-09-27  0.359361  0.543777  0.718370 -0.790835

# %%
df.loc[lambda df:df['A']>0]
# Out:
#                    A         B         C         D
# 2024-09-22  0.129117  0.470941  0.333752  0.803249
# 2024-09-23  0.797133 -0.151877 -1.454577  0.373286
# 2024-09-24  0.242940 -0.431656  2.456066 -0.748917
# 2024-09-27  0.359361  0.543777  0.718370 -0.790835

# %%
df['A'].iloc[1]
# Out:
# -0.8088283346530244

# %%
df['A']['2024-09-24']
# Out:
# 0.24294023384957214

# %%
df['B']['2024-09-24']
# Out:
# -0.43165607148576973

# %%
df[['A','D']].iloc[1:4]
# Out:
#                    A         D
# 2024-09-21 -0.808828 -0.111944
# 2024-09-22  0.129117  0.803249
# 2024-09-23  0.797133  0.373286

# %%
df[['A','B']].loc[['2024-09-21','2024-09-23']]
# Out:
#                    A         B
# 2024-09-21 -0.808828 -0.062810
# 2024-09-23  0.797133 -0.151877

# %%
df.index[0:5]
# Out:
# DatetimeIndex(['2024-09-20', '2024-09-21', '2024-09-22', '2024-09-23',
#                '2024-09-24'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# **Fast scalar value getting and setting**
#
# using at and iat we can access scalar values easily

# %% [markdown]
# Since indexing with [] must handle a lot of cases (single-label access, slicing, boolean indexing, etc.), it has a bit of overhead in order to figure out what you’re asking for. If you only want to access a scalar value, the fastest way is to use the at and iat methods, which are implemented on all of the data structures.

# %% [markdown]
# Similarly to loc, at provides label based scalar lookups, while, iat provides integer based lookups analogously to iloc

# %%
df
# Out:
#                    A         B         C         D
# 2024-09-20 -0.413746  0.787280 -0.998448  2.559626
# 2024-09-21 -0.808828 -0.062810  0.652455 -0.111944
# 2024-09-22  0.129117  0.470941  0.333752  0.803249
# 2024-09-23  0.797133 -0.151877 -1.454577  0.373286
# 2024-09-24  0.242940 -0.431656  2.456066 -0.748917
# 2024-09-25 -1.880945  0.983353  0.654084 -1.292185
# 2024-09-26 -0.958018  1.140304  1.187228  0.699864
# 2024-09-27  0.359361  0.543777  0.718370 -0.790835

# %%
df.iat[2,1] # access particulor scaler value
# Out:
# 0.4709413332769927

# %%
df.iat[5,3] # 1. row 2. column
# Out:
# -1.2921846801781278

# %%
df.at[dates[5],'D']
# Out:
# -1.2921846801781278

# %%
df.at['2024-09-27','C']
# Out:
# 0.7183704051547188

# %% [markdown]
# **Boolean Indexing**

# %%
df['A']>0
# Out:
# 2024-09-20    False
# 2024-09-21    False
# 2024-09-22     True
# 2024-09-23     True
# 2024-09-24     True
# 2024-09-25    False
# 2024-09-26    False
# 2024-09-27     True
# Freq: D, Name: A, dtype: bool

# %%
df[df['A']>0]
# Out:
#                    A         B         C         D
# 2024-09-22  0.129117  0.470941  0.333752  0.803249
# 2024-09-23  0.797133 -0.151877 -1.454577  0.373286
# 2024-09-24  0.242940 -0.431656  2.456066 -0.748917
# 2024-09-27  0.359361  0.543777  0.718370 -0.790835

# %%
df[df['A'] == df["B"]] # means all false
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []

# %% [markdown]
# **isin**

# %%
df.isin(['A','D'])
# Out:
#                 A      B      C      D
# 2024-09-20  False  False  False  False
# 2024-09-21  False  False  False  False
# 2024-09-22  False  False  False  False
# 2024-09-23  False  False  False  False
# 2024-09-24  False  False  False  False
# 2024-09-25  False  False  False  False
# 2024-09-26  False  False  False  False
# 2024-09-27  False  False  False  False

# %%
df['A'].isin([0.242940])
# Out:
# 2024-09-20    False
# 2024-09-21    False
# 2024-09-22    False
# 2024-09-23    False
# 2024-09-24    False
# 2024-09-25    False
# 2024-09-26    False
# 2024-09-27    False
# Freq: D, Name: A, dtype: bool

# %% [markdown]
# **Where()**

# %%
df[df['A']>0]
# Out:
#                    A         B         C         D
# 2024-09-22  0.129117  0.470941  0.333752  0.803249
# 2024-09-23  0.797133 -0.151877 -1.454577  0.373286
# 2024-09-24  0.242940 -0.431656  2.456066 -0.748917
# 2024-09-27  0.359361  0.543777  0.718370 -0.790835

# %%
df.where(df>0)
# Out:
#                    A         B         C         D
# 2024-09-20       NaN  0.787280       NaN  2.559626
# 2024-09-21       NaN       NaN  0.652455       NaN
# 2024-09-22  0.129117  0.470941  0.333752  0.803249
# 2024-09-23  0.797133       NaN       NaN  0.373286
# 2024-09-24  0.242940       NaN  2.456066       NaN
# 2024-09-25       NaN  0.983353  0.654084       NaN
# 2024-09-26       NaN  1.140304  1.187228  0.699864
# 2024-09-27  0.359361  0.543777  0.718370       NaN

# %%
df['A'].where(df['A']<0)
# Out:
# 2024-09-20   -0.413746
# 2024-09-21   -0.808828
# 2024-09-22         NaN
# 2024-09-23         NaN
# 2024-09-24         NaN
# 2024-09-25   -1.880945
# 2024-09-26   -0.958018
# 2024-09-27         NaN
# Freq: D, Name: A, dtype: float64

# %%
# here  others option is used to fill the null values
df.where(df>0,1)

# note:  where returns a modified copy of the data.
# Out:
#                    A         B         C         D
# 2024-09-20  1.000000  0.787280  1.000000  2.559626
# 2024-09-21  1.000000  1.000000  0.652455  1.000000
# 2024-09-22  0.129117  0.470941  0.333752  0.803249
# 2024-09-23  0.797133  1.000000  1.000000  0.373286
# 2024-09-24  0.242940  1.000000  2.456066  1.000000
# 2024-09-25  1.000000  0.983353  0.654084  1.000000
# 2024-09-26  1.000000  1.140304  1.187228  0.699864
# 2024-09-27  0.359361  0.543777  0.718370  1.000000

# %% [markdown]
# **Mask**

# %% [markdown]
# mask() is the inverse boolean operation of where.

# %%
df.mask(df>0)
# Out:
#                    A         B         C         D
# 2024-09-20 -0.413746       NaN -0.998448       NaN
# 2024-09-21 -0.808828 -0.062810       NaN -0.111944
# 2024-09-22       NaN       NaN       NaN       NaN
# 2024-09-23       NaN -0.151877 -1.454577       NaN
# 2024-09-24       NaN -0.431656       NaN -0.748917
# 2024-09-25 -1.880945       NaN       NaN -1.292185
# 2024-09-26 -0.958018       NaN       NaN       NaN
# 2024-09-27       NaN       NaN       NaN -0.790835

# %%
df.where(df>0)
# Out:
#                    A         B         C         D
# 2024-09-20       NaN  0.787280       NaN  2.559626
# 2024-09-21       NaN       NaN  0.652455       NaN
# 2024-09-22  0.129117  0.470941  0.333752  0.803249
# 2024-09-23  0.797133       NaN       NaN  0.373286
# 2024-09-24  0.242940       NaN  2.456066       NaN
# 2024-09-25       NaN  0.983353  0.654084       NaN
# 2024-09-26       NaN  1.140304  1.187228  0.699864
# 2024-09-27  0.359361  0.543777  0.718370       NaN

# %%
df.where(df>0).iloc[1:5,:]
# Out:
#                    A         B         C         D
# 2024-09-21       NaN       NaN  0.652455       NaN
# 2024-09-22  0.129117  0.470941  0.333752  0.803249
# 2024-09-23  0.797133       NaN       NaN  0.373286
# 2024-09-24  0.242940       NaN  2.456066       NaN

# %% [markdown]
# ### The query() Method
# DataFrame objects have a query() method that allows selection using an expression.

# %%
df
# Out:
#                    A         B         C         D
# 2024-09-20 -0.413746  0.787280 -0.998448  2.559626
# 2024-09-21 -0.808828 -0.062810  0.652455 -0.111944
# 2024-09-22  0.129117  0.470941  0.333752  0.803249
# 2024-09-23  0.797133 -0.151877 -1.454577  0.373286
# 2024-09-24  0.242940 -0.431656  2.456066 -0.748917
# 2024-09-25 -1.880945  0.983353  0.654084 -1.292185
# 2024-09-26 -0.958018  1.140304  1.187228  0.699864
# 2024-09-27  0.359361  0.543777  0.718370 -0.790835

# %%
#pure python
(df['A']>df['C']) & (df['D']>df['B'])
# Out:
# 2024-09-20     True
# 2024-09-21    False
# 2024-09-22    False
# 2024-09-23     True
# 2024-09-24    False
# 2024-09-25    False
# 2024-09-26    False
# 2024-09-27    False
# Freq: D, dtype: bool

# %%
df[(df['A']>df['C']) & (df['D']>df['B'])] # python
# Out:
#                    A         B         C         D
# 2024-09-20 -0.413746  0.787280 -0.998448  2.559626
# 2024-09-23  0.797133 -0.151877 -1.454577  0.373286

# %%
df.query('(A>C & D>B)') # same as the above
# Out:
#                    A         B         C         D
# 2024-09-20 -0.413746  0.787280 -0.998448  2.559626
# 2024-09-23  0.797133 -0.151877 -1.454577  0.373286

# %%
df.query('A>C and D>B')
# Out:
#                    A         B         C         D
# 2024-09-20 -0.413746  0.787280 -0.998448  2.559626
# 2024-09-23  0.797133 -0.151877 -1.454577  0.373286

# %%
df.query('A>B and B>C')
# Out:
#                    A         B         C         D
# 2024-09-23  0.797133 -0.151877 -1.454577  0.373286

# %%
df.query('A>B>C') # same like above
# Out:
#                    A         B         C         D
# 2024-09-23  0.797133 -0.151877 -1.454577  0.373286

# %%
# learn multi indexing query

# %% [markdown]
# **The in and not in operators**

# %% [markdown]
# query() also supports special use of Python’s in and not in comparison operators, providing a succinct syntax for calling the isin method of a Series or DataFrame.

# %%
df.query('A in B')
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []

# %%
# how to do in python
df[df['A'].isin(df['B'])] # same like above
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []

# %%
df.query('A not in B')
# Out:
#                    A         B         C         D
# 2024-09-20  1.025105 -0.001740 -0.701807 -2.968789
# 2024-09-21 -1.873912 -0.911195  0.345322 -0.719275
# 2024-09-22  2.613391  2.570797 -1.043818 -0.979426
# 2024-09-23  0.899600 -0.051248  2.335125 -1.056676
# 2024-09-24  1.208419  0.601748  0.035747 -0.500771
# 2024-09-25  0.042422 -1.339690  0.486822 -1.244200
# 2024-09-26 -0.796040  1.013167 -0.026437 -2.127044
# 2024-09-27  0.192100  0.082380  0.673840  0.962561

# %%
# in pure python
df[~df['A'].isin(df['B'])]
# Out:
#                    A         B         C         D
# 2024-09-20  1.025105 -0.001740 -0.701807 -2.968789
# 2024-09-21 -1.873912 -0.911195  0.345322 -0.719275
# 2024-09-22  2.613391  2.570797 -1.043818 -0.979426
# 2024-09-23  0.899600 -0.051248  2.335125 -1.056676
# 2024-09-24  1.208419  0.601748  0.035747 -0.500771
# 2024-09-25  0.042422 -1.339690  0.486822 -1.244200
# 2024-09-26 -0.796040  1.013167 -0.026437 -2.127044
# 2024-09-27  0.192100  0.082380  0.673840  0.962561

# %%
df.query('A  in B or C < D')
# Out:
#                    A         B         C         D
# 2024-09-21  0.743553  0.017528  1.218238  1.273133
# 2024-09-24  1.656928  0.341196 -1.102000  0.822996
# 2024-09-25 -0.958266 -1.497270 -0.778995  1.238631
# 2024-09-26 -1.560512 -1.886399 -0.568717  0.955309

# %%
# inpure python
df[df['B'].isin(df['A'])|(df['C']<df['D'])]
# Out:
#                    A         B         C         D
# 2024-09-21  0.743553  0.017528  1.218238  1.273133
# 2024-09-24  1.656928  0.341196 -1.102000  0.822996
# 2024-09-25 -0.958266 -1.497270 -0.778995  1.238631
# 2024-09-26 -1.560512 -1.886399 -0.568717  0.955309

# %% [markdown]
# >**Note**
#
# that in and not in are evaluated in Python, since numexpr has no equivalent of this operation. However, only the in/not in expression itself is evaluated in vanilla Python. For example, in the expression

# %%
df.query('A in B + C + D')
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []

# %% [markdown]
# (b + c + d) is evaluated by numexpr and then the in operation is evaluated in plain Python. In general, any operations that can be evaluated using numexpr will be.

# %% [markdown]
# >**Special use of the == operator with list objects**
#
#
# Comparing a list of values to a column using ==/!= works similarly to in/not in.

# %%
df1 = pd.DataFrame({'a': list('aabbccddeeff'), 'b': list('aaaabbbbcccc'),
                   'c': np.random.randint(5, size=12),
                   'd': np.random.randint(9, size=12)})

# %%
df1.query("a == ['a','b','c' ]")
# Out:
#    a  b  c  d
# 0  a  a  3  0
# 1  a  a  2  7
# 2  b  a  4  8
# 3  b  a  1  7
# 4  c  b  2  5
# 5  c  b  4  0

# %%
#pure python
df1[df1['a'].isin(['a','b','c'])]
# Out:
#    a  b  c  d
# 0  a  a  3  0
# 1  a  a  2  7
# 2  b  a  4  8
# 3  b  a  1  7
# 4  c  b  2  5
# 5  c  b  4  0

# %%
df.query('c==[1,2]')
# Out:
#     a  b  c  d
# 0   a  a  2  2
# 5   c  b  1  4
# 7   d  b  1  1
# 10  f  c  2  2
# 11  f  c  1  7

# %%
# using in/not in
df.query('c in [1,2]') #same like above
# Out:
#     a  b  c  d
# 0   a  a  2  2
# 5   c  b  1  4
# 7   d  b  1  1
# 10  f  c  2  2
# 11  f  c  1  7

# %%
# pure python
df[df['c'].isin([1,2])] # same like above
# Out:
#     a  b  c  d
# 0   a  a  2  2
# 5   c  b  1  4
# 7   d  b  1  1
# 10  f  c  2  2
# 11  f  c  1  7

# %%
df.query('[1,2] not in c')
# Out:
#    a  b  c  d
# 1  a  a  3  2
# 2  b  a  4  8
# 3  b  a  3  6
# 4  c  b  3  0
# 6  d  b  0  1
# 8  e  c  0  3
# 9  e  c  3  6

# %%
# same like above wit !=
df.query('[1,2]!= c')
# Out:
#    a  b  c  d
# 1  a  a  3  2
# 2  b  a  4  8
# 3  b  a  3  6
# 4  c  b  3  0
# 6  d  b  0  1
# 8  e  c  0  3
# 9  e  c  3  6

# %%
# pure pythpon
df[~df['c'].isin([1,2])] # same like above with pure python using ~ instedd of not
# Out:
#    a  b  c  d
# 1  a  a  3  2
# 2  b  a  4  8
# 3  b  a  3  6
# 4  c  b  3  0
# 6  d  b  0  1
# 8  e  c  0  3
# 9  e  c  3  6

# %% [markdown]
# >**Duplicate data**
#
# If you want to identify and remove duplicate rows in a DataFrame, there are two methods that will help: duplicated and drop_duplicates. Each takes as an argument the columns to use to identify duplicated rows.
#
# * **duplicated** returns a boolean vector whose length is the number of rows, and which indicates whether a row is duplicated.
#
# * **drop_duplicates** removes duplicate rows.

# %% [markdown]
# By default, the first observed row of a duplicate set is considered unique, but each method has a keep parameter to specify targets to be kept.
#
# * keep='first' (default): mark / drop duplicates except for the first occurrence.
#
# * keep='last': mark / drop duplicates except for the last occurrence.
#
# * keep=False: mark / drop all duplicates.

# %%
df2 = pd.DataFrame({'a': ['one', 'one', 'two', 'two', 'two', 'three', 'four'],
                    'b': ['x', 'y', 'x', 'y', 'x', 'x', 'x'],
                    'c': np.random.randn(7)})
df2
# Out:
#        a  b         c
# 0    one  x -0.081801
# 1    one  y -0.057409
# 2    two  x  1.113796
# 3    two  y  0.385563
# 4    two  x -0.053936
# 5  three  x  0.608919
# 6   four  x  0.731750

# %%
df2.duplicated('a')
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# 5    False
# 6    False
# dtype: bool

# %%
df2.duplicated('a',keep='last')
# observe the output carefully..
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# dtype: bool

# %%
df2.duplicated('a',keep=False)
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# 6    False
# dtype: bool

# %%
df2.drop_duplicates('a')
# Out:
#        a  b         c
# 0    one  x -0.081801
# 2    two  x  1.113796
# 5  three  x  0.608919
# 6   four  x  0.731750

# %%
df2.drop_duplicates('a',keep='last')
# Out:
#        a  b         c
# 1    one  y -0.057409
# 4    two  x -0.053936
# 5  three  x  0.608919
# 6   four  x  0.731750

# %%
df2.drop_duplicates('a',keep=False)
# Out:
#        a  b         c
# 5  three  x  0.608919
# 6   four  x  0.731750

# %% [markdown]
# Also, you can pass a list of columns to identify duplications.

# %%
df2.duplicated(['a','b']) # the ouputs are the combinations
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# dtype: bool

# %%
df2.drop_duplicates(['a','b'])
# Out:
#        a  b         c
# 0    one  x -0.081801
# 1    one  y -0.057409
# 2    two  x  1.113796
# 3    two  y  0.385563
# 5  three  x  0.608919
# 6   four  x  0.731750

# %% [markdown]
# To drop duplicates by index value, use Index.duplicated then perform slicing. The same set of options are available for the keep parameter.

# %%
df3 = pd.DataFrame({'a': np.arange(6),
                    'b': np.random.randn(6)},
                   index=['a', 'a', 'b', 'c', 'b', 'a'])

# %%
df3
# Out:
#    a         b
# a  0  0.330054
# a  1 -0.104062
# b  2  0.359648
# c  3 -0.579237
# b  4  1.765364
# a  5  0.494060

# %%
df3.index.duplicated()
# Out:
# array([False,  True, False, False,  True,  True])

# %%
df3[~df3.index.duplicated()] # not duplicates
# Out:
#    a         b
# a  0  0.330054
# b  2  0.359648
# c  3 -0.579237

# %%
df3.index.duplicated(keep='first')
# Out:
# array([False,  True, False, False,  True,  True])

# %%
df3[df3.index.duplicated(keep='first')]
# Out:
#    a         b
# a  1 -0.104062
# b  4  1.765364
# a  5  0.494060

# %%
df3[~df3.index.duplicated(keep='first')]
# Out:
#    a         b
# a  0  0.330054
# b  2  0.359648
# c  3 -0.579237

# %%
df3[~df3.index.duplicated(keep=False)]
# Out:
#    a         b
# c  3 -0.579237

# %% [markdown]
# >**Dictionary-like get() method**
#
# Each of Series or DataFrame have a get method which can return a default value

# %%
s = pd.Series([1, 2, 3], index=['a', 'b', 'c'])
s.get('a')  # equivalent to s['a']
# Out:
# 1

# %%
s.get('c')
# Out:
# 3

# %%
s.get('x',default=-1) # we can also set default init if the value is not in the series it gives default value
# Out:
# -1

# %% [markdown]
# >**Looking up values by index/column labels**
#
# Sometimes you want to extract a set of values given a sequence of row labels and column labels, this can be achieved by pandas.factorize and NumPy indexing. For instance:

# %%
df = pd.DataFrame({'col': ["A", "A", "B", "B"],
                   'A': [80, 23, np.nan, 22],
                   'B': [80, 55, 76, 67]})
df
# Out:
#   col     A   B
# 0   A  80.0  80
# 1   A  23.0  55
# 2   B   NaN  76
# 3   B  22.0  67

# %%
idx, cols = pd.factorize(df['col'])

# %%
idx
# Out:
# array([0, 0, 1, 1])

# %%
cols
# Out:
# Index(['A', 'B'], dtype='object')

# %%
df.reindex(cols, axis=1).to_numpy()[np.arange(len(df)), idx]
# Out:
# array([80., 23., 76., 67.])

# %% [markdown]
# Formerly this could be achieved with the dedicated DataFrame.lookup method which was deprecated in version 1.2.0 and removed in version 2.0.0.

# %% [markdown]
# Index objects

# %%
index = pd.Index(['a','b','c'])

# %%
# wena also provide Dtype
index = pd.Index(['a','b','c','d'],dtype='object')
index.dtype
# Out:
# dtype('O')

# %%
'c' in index
# Out:
# True

# %%
index = pd.Index([1,2,3,4]) # remember I must be captial
index = pd.Index([1,2,3,4],dtype='float')
index.dtype
# Out:
# dtype('float64')

# %%
# naminig to the index
index = pd.Index(['a','b','c','d'],dtype='string',name = 'somthing')
index.name
# Out:
# 'somthing'

# %%
# lets create a data frame
index = pd.Index(list(range(5)),name='rows')
columns = pd.Index(['a','b','c'],name='cols')

df = pd.DataFrame(np.random.rand(5,3),index = index,columns=columns)
df
# Out:
# cols         a         b         c
# rows
# 0     0.002584  0.184596  0.313207
# 1     0.465908  0.571581  0.103987
# 2     0.432448  0.378951  0.998239
# 3     0.094779  0.154120  0.758813
# 4     0.832634  0.997448  0.240509

# %%
df['a']
# Out:
# rows
# 0    0.002584
# 1    0.465908
# 2    0.432448
# 3    0.094779
# 4    0.832634
# Name: a, dtype: float64

# %% [markdown]
# >**Setting metadata**
#
# Indexes are “mostly immutable”, but it is possible to set and change their name attribute. You can use the rename, set_names to set these attributes directly, and they default to returning a copy.

# %%
ind = pd.Index([1,2,3,4])

# %%
ind.name

# %%
ind.rename('AJay',inplace=True)

# %%
ind.name
# Out:
# 'AJay'

# %%
ind.set_names('apple',inplace=True)

# %%
ind.name
# Out:
# 'apple'

# %%
ind.name = 'Gnani'

# %%
ind.name
# Out:
# 'Gnani'

# %% [markdown]
# set_names, set_levels, and set_codes also take an optional level argument

# %%
index = pd.MultiIndex.from_product([range(3), ['one', 'two']], names=['first', 'second'])
index
# Out:
# MultiIndex([(0, 'one'),
#             (0, 'two'),
#             (1, 'one'),
#             (1, 'two'),
#             (2, 'one'),
#             (2, 'two')],
#            names=['first', 'second'])

# %%
index.levels[1]
# Out:
# Index(['one', 'two'], dtype='object', name='second')

# %%
index.set_levels(['a','b'],level=1)
# Out:
# MultiIndex([(0, 'a'),
#             (0, 'b'),
#             (1, 'a'),
#             (1, 'b'),
#             (2, 'a'),
#             (2, 'b')],
#            names=['first', 'second'])

# %%
index.levels[1]
# Out:
# Index(['one', 'two'], dtype='object', name='second')

# %% [markdown]
# >**Set operations on Index objects**
#
# The two main operations are union and intersection. Difference is provided via the .difference() method.

# %%
a = pd.Index(['c', 'b', 'a'])
b = pd.Index(['c', 'e', 'd'])

a.difference(b)
# Out:
# Index(['a', 'b'], dtype='object')

# %% [markdown]
# Also available is the symmetric_difference operation, which returns elements that appear in either idx1 or idx2, but not in both. This is equivalent to the Index created by idx1.difference(idx2).union(idx2.difference(idx1)), with duplicates dropped.

# %%
a.symmetric_difference(b)
# Out:
# Index(['a', 'b', 'd', 'e'], dtype='object')

# %%
idx1 = pd.Index([1, 2, 3, 4])

idx2 = pd.Index([2, 3, 4, 5])

idx1.symmetric_difference(idx2)
# Out:
# Index([1, 5], dtype='int64')

# %% [markdown]
# >**Note:** The resulting index from a set operation will be sorted in ascending order.

# %% [markdown]
# When performing Index.union() between indexes with different dtypes, the indexes must be cast to a common dtype. Typically, though not always, this is object dtype. The exception is when performing a union between integer and float data. In this case, the integer values are converted to float

# %%
idx1 = pd.Index([0, 1, 2])

idx2 = pd.Index([0.5, 1.5])

idx1.union(idx2)
# Out:
# Index([0.0, 0.5, 1.0, 1.5, 2.0], dtype='float64')

# %% [markdown]
# >**Missing values**
#
# Important
#
# Even though Index can hold missing values (NaN), it should be avoided if you do not want any unexpected results. For example, some operations exclude missing values implicitly.

# %% [markdown]
# Index.fillna fills missing values with specified scalar value.

# %%
idx1 = pd.Index([1, np.nan, 3, 4])

# %%
idx1
# Out:
# Index([1.0, nan, 3.0, 4.0], dtype='float64')

# %%
idx1.fillna(2)
# Out:
# Index([1.0, 2.0, 3.0, 4.0], dtype='float64')

# %%
idx2 = pd.DatetimeIndex([pd.Timestamp('2011-01-01'),
                         pd.NaT,
                         pd.Timestamp('2011-01-03')])

# %%
idx2
# Out:
# DatetimeIndex(['2011-01-01', 'NaT', '2011-01-03'], dtype='datetime64[ns]', freq=None)

# %%
idx2.fillna(pd.Timestamp('2024-09-28'))
# Out:
# DatetimeIndex(['2011-01-01', '2024-09-28', '2011-01-03'], dtype='datetime64[ns]', freq=None)

# %%
idx2

# %% [markdown]
# ### **Set / reset index**
# Occasionally you will load or create a data set into a DataFrame and want to add an index after you’ve already done so. There are a couple of different ways.Set / reset index
# Occasionally you will load or create a data set into a DataFrame and want to add an index after you’ve already done so. There are a couple of different ways.

# %% [markdown]
# >**Set an index**
#
# DataFrame has a set_index() method which takes a column name (for a regular Index) or a list of column names (for a MultiIndex). To create a new, re-indexed DataFrame:

# %%
data = pd.DataFrame({'a': ['bar', 'bar', 'foo', 'foo'],
                     'b': ['one', 'two', 'one', 'two'],
                     'c': ['z', 'y', 'x', 'w'],
                     'd': [1., 2., 3, 4]})

# %%
data
# Out:
#      a    b  c    d
# 0  bar  one  z  1.0
# 1  bar  two  y  2.0
# 2  foo  one  x  3.0
# 3  foo  two  w  4.0

# %%
indexed1 = data.set_index('c')

# %%
indexed1
# Out:
#      a    b    d
# c
# z  bar  one  1.0
# y  bar  two  2.0
# x  foo  one  3.0
# w  foo  two  4.0

# %%
data
# Out:
#      a    b  c    d
# 0  bar  one  z  1.0
# 1  bar  two  y  2.0
# 2  foo  one  x  3.0
# 3  foo  two  w  4.0

# %%
indexed2 =  data.set_index(['a','b'])

# %%
indexed2
# Out:
#          c    d
# a   b
# bar one  z  1.0
#     two  y  2.0
# foo one  x  3.0
#     two  w  4.0

# %% [markdown]
# >**Note:**
# The append keyword option allow you to keep the existing index and append the given columns to a MultiIndex:

# %%
frame2 = data.set_index('c',append=True) # append is used to add multi indexing with out take of the previous index

# %%
frame2
# Out:
#        a    b    d
#   c
# 0 z  bar  one  1.0
# 1 y  bar  two  2.0
# 2 x  foo  one  3.0
# 3 w  foo  two  4.0

# %%
frame2 = data.set_index('c',append=False) # flase mens it replace the index
frame2
# Out:
#      a    b    d
# c
# z  bar  one  1.0
# y  bar  two  2.0
# x  foo  one  3.0
# w  foo  two  4.0

# %% [markdown]
# Other options in set_index allow you not drop the index columns.

# %%
frame = data.set_index('c',drop=False) #it changes the index with out droping the column c

# %%
frame
# Out:
#      a    b  c    d
# c
# z  bar  one  z  1.0
# y  bar  two  y  2.0
# x  foo  one  x  3.0
# w  foo  two  w  4.0

# %% [markdown]
# Reset the index
# As a convenience, there is a new function on DataFrame called reset_index() which transfers the index values into the DataFrame’s columns and sets a simple integer index. This is the inverse operation of set_index().
