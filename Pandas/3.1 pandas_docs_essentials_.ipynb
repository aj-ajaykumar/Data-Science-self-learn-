# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # combinig overlaping data sets

# %%
df1 = pd.DataFrame(
    {"A": [1.0, np.nan, 3.0, 5.0, np.nan], "B": [np.nan, 2.0, 3.0, np.nan, 6.0]}
)


df2 = pd.DataFrame(
    {
        "A": [5.0, 2.0, 4.0, np.nan, 3.0, 7.0],
        "B": [np.nan, np.nan, 3.0, 4.0, 6.0, 8.0],
    }
)

# %%
df1
# Out:
#      A    B
# 0  1.0  NaN
# 1  NaN  2.0
# 2  3.0  3.0
# 3  5.0  NaN
# 4  NaN  6.0

# %%
df2
# Out:
#      A    B
# 0  5.0  NaN
# 1  2.0  NaN
# 2  4.0  3.0
# 3  NaN  4.0
# 4  3.0  6.0
# 5  7.0  8.0

# %%
df1.combine_first(df2)
# Out:
#      A    B
# 0  1.0  NaN
# 1  2.0  2.0
# 2  3.0  3.0
# 3  5.0  4.0
# 4  3.0  6.0
# 5  7.0  8.0

# %% [markdown]
# # genaral data frame combine

# %%
def combiner(x,y):
  return np.where(pd.isna(x),y,x)

# %%
df1.combine(df2,combiner) # this is same like above
# Out:
#      A    B
# 0  1.0  NaN
# 1  2.0  2.0
# 2  3.0  3.0
# 3  5.0  4.0
# 4  3.0  6.0
# 5  7.0  8.0

# %% [markdown]
# # descriptive Statestics

# %%
df = pd.DataFrame(
    {
        "one": pd.Series(np.random.randn(3), index=["a", "b", "c"]),
        "two": pd.Series(np.random.randn(4), index=["a", "b", "c", "d"]),
        "three": pd.Series(np.random.randn(3), index=["b", "c", "d"]),
    }
)

# %%
df
# Out:
#         one       two     three
# a -0.554632  0.291273       NaN
# b  1.132131  0.395076  0.405484
# c  0.422700  0.029379 -0.847735
# d       NaN -1.556421  0.131991

# %%
df.mean()
# Out:
# one      0.333400
# two     -0.210173
# three   -0.103420
# dtype: float64

# %%
df.mean(0) # here 0 is the axis
# Out:
# one      0.333400
# two     -0.210173
# three   -0.103420
# dtype: float64

# %%
df.mean(1)
# Out:
# a   -0.131679
# b    0.644230
# c   -0.131885
# d   -0.712215
# dtype: float64

# %% [markdown]
# **All such methods have a skipna option signaling whether to exclude missing data (True by default):**

# %%
df
# Out:
#         one       two     three
# a -0.554632  0.291273       NaN
# b  1.132131  0.395076  0.405484
# c  0.422700  0.029379 -0.847735
# d       NaN -1.556421  0.131991

# %%
df.sum(0,skipna=False)
# Out:
# one           NaN
# two     -0.840693
# three         NaN
# dtype: float64

# %%
df.sum(1,skipna=True)
# Out:
# a   -0.263358
# b    1.932691
# c   -0.395656
# d   -1.424429
# dtype: float64

# %%
df.std()
# Out:
# one      0.846920
# two      0.910594
# three    0.658941
# dtype: float64

# %%
ts_stand = (df-df.mean())/df.std()

# %%
ts_stand
# Out:
#         one       two     three
# a -1.048543  0.550681       NaN
# b  0.943102  0.664675  0.772306
# c  0.105441  0.263073 -1.129562
# d       NaN -1.478428  0.357257

# %%
ts_stand.std()
# Out:
# one      1.0
# two      1.0
# three    1.0
# dtype: float64

# %%
xs_stand = df.sub(df.mean(1),axis = 0).div(df.std(1),axis = 0)

# %%
xs_stand
# Out:
#         one       two     three
# a -0.707107  0.707107       NaN
# b  1.154613 -0.589623 -0.564990
# c  0.852698  0.247951 -1.100648
# d       NaN -0.707107  0.707107

# %%
xs_stand.std()
# Out:
# one      0.999178
# two      0.678221
# three    0.928542
# dtype: float64

# %%
xs_stand.std(1)
# Out:
# a    1.0
# b    1.0
# c    1.0
# d    1.0
# dtype: float64

# %% [markdown]
# **Note that methods like cumsum() and cumprod() preserve the location of NaN values. This is somewhat different from expanding() and rolling() since NaN behavior is furthermore dictated by a min_periods parameter.**

# %%
df
# Out:
#         one       two     three
# a -0.554632  0.291273       NaN
# b  1.132131  0.395076  0.405484
# c  0.422700  0.029379 -0.847735
# d       NaN -1.556421  0.131991

# %%
df.cumsum()
# Out:
#         one       two     three
# a -0.554632  0.291273       NaN
# b  0.577500  0.686349  0.405484
# c  1.000200  0.715728 -0.442251
# d       NaN -0.840693 -0.310259

# %%
df.cumsum(1)
# Out:
#         one       two     three
# a -0.554632 -0.263358       NaN
# b  1.132131  1.527207  1.932691
# c  0.422700  0.452079 -0.395656
# d       NaN -1.556421 -1.424429

# %%
df.cumprod()
# Out:
#         one       two     three
# a -0.554632  0.291273       NaN
# b -0.627916  0.115075  0.405484
# c -0.265420  0.003381 -0.343743
# d       NaN -0.005262 -0.045371

# %%
df.cumprod(1)
# Out:
#         one       two     three
# a -0.554632 -0.161549       NaN
# b  1.132131  0.447278  0.181364
# c  0.422700  0.012419 -0.010528
# d       NaN -1.556421 -0.205434

# %% [markdown]
# #functions

# %%
df.count()
# Out:
# one      3
# two      4
# three    3
# dtype: int64

# %%
df.count(1)
# Out:
# a    2
# b    3
# c    3
# d    2
# dtype: int64

# %%
df.sum()
# Out:
# one      1.000200
# two     -0.840693
# three   -0.310259
# dtype: float64

# %%
df.sum(1)
# Out:
# a   -0.263358
# b    1.932691
# c   -0.395656
# d   -1.424429
# dtype: float64

# %%
df.mean()
# Out:
# one      0.333400
# two     -0.210173
# three   -0.103420
# dtype: float64

# %%
df.mean(1)
# Out:
# a   -0.131679
# b    0.644230
# c   -0.131885
# d   -0.712215
# dtype: float64

# %%
df.median()
# Out:
# one      0.422700
# two      0.160326
# three    0.131991
# dtype: float64

# %%
df.median(1)
# Out:
# a   -0.131679
# b    0.405484
# c    0.029379
# d   -0.712215
# dtype: float64

# %%
df.min()
# Out:
# one     -0.554632
# two     -1.556421
# three   -0.847735
# dtype: float64

# %%
df.min(axis =1)
# Out:
# a   -0.554632
# b    0.395076
# c   -0.847735
# d   -1.556421
# dtype: float64

# %%
df.max(axis =0)
# Out:
# one      1.132131
# two      0.395076
# three    0.405484
# dtype: float64

# %%
df.max(1)
# Out:
# a    0.291273
# b    1.132131
# c    0.422700
# d    0.131991
# dtype: float64

# %%
df.mode()
# Out:
#         one       two     three
# 0 -0.554632 -1.556421 -0.847735
# 1  0.422700  0.029379  0.131991
# 2  1.132131  0.291273  0.405484
# 3       NaN  0.395076       NaN

# %%
df.mode(1)
# Out:
#           0         1         2
# a -0.554632  0.291273       NaN
# b  0.395076  0.405484  1.132131
# c -0.847735  0.029379  0.422700
# d -1.556421  0.131991       NaN

# %%
df.abs() # absolut values
# Out:
#         one       two     three
# a  0.554632  0.291273       NaN
# b  1.132131  0.395076  0.405484
# c  0.422700  0.029379  0.847735
# d       NaN  1.556421  0.131991

# %%
df.prod()
# Out:
# one     -0.265420
# two     -0.005262
# three   -0.045371
# dtype: float64

# %%
df.prod(1)
# Out:
# a   -0.161549
# b    0.181364
# c   -0.010528
# d   -0.205434
# dtype: float64

# %%
df.std() # Bessel-corrected sample standard deviation
# Out:
# one      0.846920
# two      0.910594
# three    0.658941
# dtype: float64

# %%
df.std(1)
# Out:
# a    0.598145
# b    0.422567
# c    0.650389
# d    1.193888
# dtype: float64

# %%
df.var() # Unbiased variance
# Out:
# one      0.717273
# two      0.829181
# three    0.434204
# dtype: float64

# %%
df.var(1)
# Out:
# a    0.357777
# b    0.178563
# c    0.423006
# d    1.425368
# dtype: float64

# %%
df.sem()# Standard error of the mean
# Out:
# one      0.488969
# two      0.455297
# three    0.380440
# dtype: float64

# %%
df.sem(1)
# Out:
# a    0.422952
# b    0.243969
# c    0.375502
# d    0.844206
# dtype: float64

# %%
df.skew()# Sample skewness (3rd moment)
# Out:
# one     -0.469210
# two     -1.835085
# three   -1.402466
# dtype: float64

# %%
df.skew(1)
# Out:
# a         NaN
# b    1.730869
# c   -1.047181
# d         NaN
# dtype: float64

# %%
df.kurt()# Sample kurtosis (4th moment)
# Out:
# one           NaN
# two      3.398122
# three         NaN
# dtype: float64

# %%
df.kurt(1)
# Out:
# a   NaN
# b   NaN
# c   NaN
# d   NaN
# dtype: float64

# %%
df.quantile(.25) # Sample quantile (value at %)
# Out:
# one     -0.065966
# two     -0.367071
# three   -0.357872
# Name: 0.25, dtype: float64

# %%
df.quantile() # default 50%
# Out:
# one      0.422700
# two      0.160326
# three    0.131991
# Name: 0.5, dtype: float64

# %%
df.quantile(.75)
# Out:
# one      0.777416
# two      0.317224
# three    0.268738
# Name: 0.75, dtype: float64

# %%
df.quantile(.75,axis=1)
# Out:
# a    0.079797
# b    0.768808
# c    0.226040
# d   -0.290112
# Name: 0.75, dtype: float64

# %%
df.quantile(axis=1)
# Out:
# a   -0.131679
# b    0.405484
# c    0.029379
# d   -0.712215
# Name: 0.5, dtype: float64

# %%
df.cumsum()
# Out:
#         one       two     three
# a -0.554632  0.291273       NaN
# b  0.577500  0.686349  0.405484
# c  1.000200  0.715728 -0.442251
# d       NaN -0.840693 -0.310259

# %%
df.cumprod(1)
# Out:
#         one       two     three
# a -0.554632 -0.161549       NaN
# b  1.132131  0.447278  0.181364
# c  0.422700  0.012419 -0.010528
# d       NaN -1.556421 -0.205434

# %%
df.cummax()
# Out:
#         one       two     three
# a -0.554632  0.291273       NaN
# b  1.132131  0.395076  0.405484
# c  1.132131  0.395076  0.405484
# d       NaN  0.395076  0.405484

# %%
df.cummin()
# Out:
#         one       two     three
# a -0.554632  0.291273       NaN
# b -0.554632  0.291273  0.405484
# c -0.554632  0.029379 -0.847735
# d       NaN -1.556421 -0.847735

# %% [markdown]
# **Series.nunique() will return the number of unique non-NA values in a Series:**

# %%
a = pd.Series(np.random.randn(100))

# %%
a
# Out:
# 0     0.511950
# 1    -0.049386
# 2     0.475766
# 3    -0.173028
# 4    -0.876329
#         ...
# 95    0.604836
# 96    2.153425
# 97    1.981389
# 98   -0.206653
# 99   -1.368263
# Length: 100, dtype: float64

# %%
a.nunique()
# Out:
# 100

# %%
a[10:20] = np.nan

# %%
a[21:40] = 6

# %%
a.nunique()
# Out:
# 72

# %% [markdown]
# #Summarizing data: describe

# %%
df = pd.DataFrame(np.random.randn(20,4),index = pd.date_range('2018--5-20',periods=20,freq='m'),columns=list('abcd'))

# %%
df.head()
# Out:
#                    a         b         c         d
# 2018-05-31  0.616556 -1.812899 -0.418611  1.040031
# 2018-06-30  0.023035 -1.096629  0.393114 -0.235360
# 2018-07-31  0.144521 -0.106900  1.104889  1.277541
# 2018-08-31 -0.719469 -0.855892 -0.952613 -1.826415
# 2018-09-30  0.688757  0.171053 -2.182707 -0.632628

# %%
df.describe()
# Out:
#                a          b          c          d
# count  20.000000  20.000000  20.000000  20.000000
# mean   -0.203670  -0.141086  -0.206512  -0.174709
# std     0.870587   0.888201   1.251522   0.891888
# min    -2.270970  -1.812899  -2.327019  -1.826415
# 25%    -0.778960  -0.862886  -0.995269  -0.674628
# 50%    -0.093061  -0.316578  -0.082467  -0.281245
# 75%     0.597342   0.604617   0.495294   0.342920
# max     1.228389   1.375532   1.973850   1.277541

# %% [markdown]
# **You can select specific percentiles to include in the output:**

# %%
df.describe(percentiles=[.25,.50,.75,.90,.95])
# Out:
#                a          b          c          d
# count  20.000000  20.000000  20.000000  20.000000
# mean   -0.203670  -0.141086  -0.206512  -0.174709
# std     0.870587   0.888201   1.251522   0.891888
# min    -2.270970  -1.812899  -2.327019  -1.826415
# 25%    -0.778960  -0.862886  -0.995269  -0.674628
# 50%    -0.093061  -0.316578  -0.082467  -0.281245
# 75%     0.597342   0.604617   0.495294   0.342920
# 90%     0.706608   1.037867   1.401511   1.118289
# 95%     0.885324   1.084445   1.476765   1.245989
# max     1.228389   1.375532   1.973850   1.277541

# %% [markdown]
# **For a non-numerical Series object, describe() will give a simple summary of the number of unique values and most frequently occurring values:**

# %%
s =pd.Series(list('abcdscdasxcbdc') )
s.head()
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    s
# dtype: object

# %%
s.describe()
# Out:
# count     14
# unique     6
# top        c
# freq       4
# dtype: object

# %% [markdown]
# **Note that on a mixed-type DataFrame object, describe() will restrict the summary to include only numerical columns or, if none are, only categorical columns:**

# %%
frame = pd.DataFrame({"a": ["Yes", "Yes", "No", "No"], "b": range(4)})

# %%
frame.describe()
# Out:
#               b
# count  4.000000
# mean   1.500000
# std    1.290994
# min    0.000000
# 25%    0.750000
# 50%    1.500000
# 75%    2.250000
# max    3.000000

# %% [markdown]
# **This behavior can be controlled by providing a list of types as include/exclude arguments. The special value all can also be used:**

# %%
frame.describe(include=['object'])
# Out:
#           a
# count     4
# unique    2
# top     Yes
# freq      2

# %%
frame.describe(include=['number'])
# Out:
#               b
# count  4.000000
# mean   1.500000
# std    1.290994
# min    0.000000
# 25%    0.750000
# 50%    1.500000
# 75%    2.250000
# max    3.000000

# %%
frame.describe(include=['all'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-120-9bf89aba327a> in <cell line: 1>()
# ----> 1 frame.describe(include=['all'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in describe(self, percentiles, include, exclude, datetime_is_numeric)
#   10938         max            NaN      3.0
#   10939         """
# > 10940         return describe_ndframe(
#   10941             obj=self,
#   10942             include=include,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/describe.py in describe_ndframe(obj, include, exclude, datetime_is_numeric, percentiles)
#      99         )
#     100
# --> 101     result = describer.describe(percentiles=percentiles)
#     102     return cast(NDFrameT, result)
#     103
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/describe.py in describe(self, percentiles)
#     174
#     175     def describe(self, percentiles: Sequence[float] | np.ndarray) -> DataFrame:
# --> 176         data = self._select_data()
#     177
#     178         ldesc: list[Series] = []
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/describe.py in _select_data(self)
#     206             data = self.obj
#     207         else:
# --> 208             data = self.obj.select_dtypes(
#     209                 include=self.include,
#     210                 exclude=self.exclude,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in select_dtypes(self, include, exclude)
#    4721             return frozenset(converted_dtypes)
#    4722
# -> 4723         include = check_int_infer_dtype(include)
#    4724         exclude = check_int_infer_dtype(exclude)
#    4725
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in check_int_infer_dtype(dtypes)
#    4718                     converted_dtypes.extend([np.float64, np.float32])
#    4719                 else:
# -> 4720                     converted_dtypes.append(infer_dtype_from_object(dtype))
#    4721             return frozenset(converted_dtypes)
#    4722
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/common.py in infer_dtype_from_object(dtype)
#    1694             pass
#    1695
# -> 1696     return infer_dtype_from_object(np.dtype(dtype))
#    1697
#    1698
#
# TypeError: data type 'all' not understood

# %%
frame.describe(include='all')
# Out:
#           a         b
# count     4  4.000000
# unique    2       NaN
# top     Yes       NaN
# freq      2       NaN
# mean    NaN  1.500000
# std     NaN  1.290994
# min     NaN  0.000000
# 25%     NaN  0.750000
# 50%     NaN  1.500000
# 75%     NaN  2.250000
# max     NaN  3.000000

# %% [markdown]
# # Index of min/max values
# **The idxmin() and idxmax() functions on Series and DataFrame compute the index labels with the minimum and maximum corresponding values:**

# %%
s =pd.Series(np.random.rand(5))
s
# Out:
# 0    0.354970
# 1    0.151689
# 2    0.521221
# 3    0.335224
# 4    0.525006
# dtype: float64

# %%
s.idxmin()
# Out:
# 1

# %%
s.idxmax()
# Out:
# 4

# %%
s.idxmin(),s.idxmax()
# Out:
# (1, 4)

# %%
df = pd.DataFrame(np.random.randn(6,4),columns=list('abcd'))

# %%
df
# Out:
#           a         b         c         d
# 0 -1.884904  1.274406  1.492304  0.812215
# 1 -0.552285  0.137596 -0.025676 -0.024808
# 2  0.778997 -0.197649  0.082588  2.495423
# 3  1.275496 -0.520712  0.127986  1.950268
# 4 -0.258949  0.873724  1.317255  0.235405
# 5  1.035958  0.027331 -0.929527 -0.392943

# %%
df.idxmax()# a column have a max element in 3rd row
# Out:
# a    3
# b    0
# c    0
# d    2
# dtype: int64

# %%
df.idxmin(1)
# Out:
# 0    a
# 1    a
# 2    b
# 3    b
# 4    a
# 5    c
# dtype: object

# %% [markdown]
# **When there are multiple rows (or columns) matching the minimum or maximum value, idxmin() and idxmax() return the first matching index:**

# %%
df3 = pd.DataFrame([2, 1, 1, 3, np.nan], columns=["A"], index=list("edcba"))
df3
# Out:
#      A
# e  2.0
# d  1.0
# c  1.0
# b  3.0
# a  NaN

# %%
df3['A'].idxmin() # it gives d but c also have one but "d" was touched first
# Out:
# 'd'

# %% [markdown]
# idxmin and idxmax are called argmin and argmax in NumPy.

# %% [markdown]
# #Value counts (histogramming) / mode

# %% [markdown]
# **The value_counts() Series method and top-level function computes a histogram of a 1D array of values. It can also be used as a function on regular arrays:**

# %%
data = np.random.randint(0,7,size=50)
data
# Out:
# array([3, 3, 4, 2, 5, 4, 2, 3, 1, 4, 1, 3, 1, 1, 1, 2, 4, 5, 1, 4, 5, 1,
#        1, 5, 5, 2, 1, 0, 2, 2, 0, 3, 2, 1, 4, 3, 5, 3, 5, 3, 3, 6, 6, 1,
#        3, 2, 0, 3, 1, 0])

# %%
s2 = pd.Series(data)

# %%
s2.value_counts()
# Out:
# 1    12
# 3    11
# 2     8
# 5     7
# 4     6
# 0     4
# 6     2
# dtype: int64

# %%
pd.value_counts(data)
# Out:
# 1    12
# 3    11
# 2     8
# 5     7
# 4     6
# 0     4
# 6     2
# dtype: int64

# %% [markdown]
# The value_counts() method can be used to count combinations across multiple columns. By default all columns are used but a subset can be selected using the subset argument.

# %%
data = {"a": [1, 2, 3, 4], "b": ["x", "x", "y", "y"]}
frame = pd.DataFrame(data)
frame.value_counts()
# Out:
# a  b
# 1  x    1
# 2  x    1
# 3  y    1
# 4  y    1
# dtype: int64

# %% [markdown]
# Similarly, you can get the most frequently occurring value(s), i.e. the mode, of the values in a Series or DataFrame:

# %%
s = pd.Series([1, 1, 3, 3, 3, 5, 5, 7, 7, 7])
s
# Out:
# 0    1
# 1    1
# 2    3
# 3    3
# 4    3
# 5    5
# 6    5
# 7    7
# 8    7
# 9    7
# dtype: int64

# %%
s.mode()
# Out:
# 0    3
# 1    7
# dtype: int64

# %%
df1 = pd.DataFrame(
    {
        "A": np.random.randint(0, 7, size=50),
        "B": np.random.randint(-10, 15, size=50),
    }
)
df1.head()
# Out:
#    A  B
# 0  4  7
# 1  0 -1
# 2  2 -8
# 3  1  6
# 4  5 -9

# %%
df1.mode()
# Out:
#      A   B
# 0  5.0   7
# 1  NaN  12

# %% [markdown]
# #Discretization and quantiling

# %% [markdown]
# Continuous values can be discretized using the cut() (bins based on values) and qcut() (bins based on sample quantiles) functions:

# %%
arr = np.random.randn(20)
factor = pd.cut(arr,4)
factor
# Out:
# [(0.122, 1.388], (0.122, 1.388], (-2.411, -1.145], (-2.411, -1.145], (-2.411, -1.145], ..., (-1.145, 0.122], (-1.145, 0.122], (-1.145, 0.122], (-3.683, -2.411], (0.122, 1.388]]
# Length: 20
# Categories (4, interval[float64, right]): [(-3.683, -2.411] < (-2.411, -1.145] < (-1.145, 0.122] <
#                                            (0.122, 1.388]]

# %%
factor = pd.cut(arr, [-5, -1, 0, 1, 5])
factor
# Out:
# [(0, 1], (0, 1], (-5, -1], (-5, -1], (-5, -1], ..., (-1, 0], (-1, 0], (-1, 0], (-5, -1], (0, 1]]
# Length: 20
# Categories (4, interval[int64, right]): [(-5, -1] < (-1, 0] < (0, 1] < (1, 5]]

# %% [markdown]
# **qcut() computes sample quantiles. For example, we could slice up some normally distributed data into equal-size quartiles like so:**

# %%
arr = np.random.randn(30)
factor = pd.qcut(arr,[0,.25,.50,.65,.75,.90])
factor
# Out:
# [(-0.432, 0.276], (0.451, 0.946], (-1.636, -0.432], (-0.432, 0.276], (-0.432, 0.276], ..., (-0.432, 0.276], (0.276, 0.451], (0.451, 0.946], (-1.636, -0.432], (0.276, 0.451]]
# Length: 30
# Categories (5, interval[float64, right]): [(-1.636, -0.432] < (-0.432, 0.276] < (0.276, 0.451] <
#                                            (0.451, 0.946] < (0.946, 1.35]]

# %%
pd.value_counts(factor)
# Out:
# (-1.636, -0.432]    8
# (-0.432, 0.276]     7
# (0.946, 1.35]       5
# (0.276, 0.451]      4
# (0.451, 0.946]      3
# dtype: int64

# %% [markdown]
# We can also pass infinite values to define the bins:

# %%
arr = np.random.randn(20)

factor = pd.cut(arr, [-np.inf, 0, np.inf])

factor
# Out:
# [(-inf, 0.0], (-inf, 0.0], (-inf, 0.0], (-inf, 0.0], (-inf, 0.0], ..., (0.0, inf], (0.0, inf], (-inf, 0.0], (0.0, inf], (-inf, 0.0]]
# Length: 20
# Categories (2, interval[float64, right]): [(-inf, 0.0] < (0.0, inf]]

# %% [markdown]
# #Function application

# %% [markdown]
# To apply your own or another library’s functions to pandas objects, you should be aware of the three methods below. The appropriate method to use depends on whether your function expects to operate on an entire DataFrame or Series, row- or column-wise, or elementwise.

# %% [markdown]
# * -Tablewise Function Application: pipe()
#
# * -Row or Column-wise Function Application: apply()
#
# * -Aggregation API: agg() and transform()
#
# * -Applying Elementwise Functions: applymap()

# %% [markdown]
# **Tablewise function application**

# %%
df_p = pd.DataFrame({"city_and_code": ["Chicago, IL","Dullas, IL","Texas, IL"]})
df_p
# Out:
#   city_and_code
# 0   Chicago, IL
# 1    Dullas, IL
# 2     Texas, IL

# %%
def extract_city_name(df):
  for city in df:
    df['city_name'] = df['city_and_code'].str.split(',').str.get(0)
    return df

def add_country_name(df,country_name = 'US'):
  df['city_and_country'] = df['city_name']+country_name
  return df

# %%
add_country_name(extract_city_name(df_p))
# Out:
#   city_and_code city_name city_and_country
# 0   Chicago, IL   Chicago        ChicagoUS
# 1    Dullas, IL    Dullas         DullasUS
# 2     Texas, IL     Texas          TexasUS

# %% [markdown]
# another way

# %%
df_p.pipe(extract_city_name).pipe(add_country_name,country_name='US')
# Out:
#   city_and_code city_name city_and_country
# 0   Chicago, IL   Chicago        ChicagoUS
# 1    Dullas, IL    Dullas         DullasUS
# 2     Texas, IL     Texas          TexasUS

# %% [markdown]
# For example, we can fit a regression using statsmodels. Their API expects a formula first and a DataFrame as the second argument, data. We pass in the function, keyword pair (sm.ols, 'data') to pipe:

# %%
import seaborn as sns
data =sns.load_dataset('iris')
data.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %% [markdown]
# ## Row or column-wise function application

# %% [markdown]
# Arbitrary functions can be applied along the axes of a DataFrame using the apply() method, which, like the descriptive statistics methods, takes an optional axis argument:

# %%
df
# Out:
#         one       two     three
# a  1.048996 -0.382394       NaN
# b  0.292270  0.376484 -1.287700
# c -0.178091  0.666440 -0.184708
# d       NaN -0.124115  1.603732

# %%
df.apply(np.mean)
# Out:
# one      0.387725
# two      0.134104
# three    0.043775
# dtype: float64

# %%
df.apply(np.mean,axis =1)
# Out:
# a    0.333301
# b   -0.206315
# c    0.101213
# d    0.739808
# dtype: float64

# %%
# diffrence between min max
df.apply(lambda x : x.max()-x.min())
# Out:
# one      1.227088
# two      1.048834
# three    2.891431
# dtype: float64

# %%
df.apply(lambda x : x.max()-x.min(),axis = 1)
# Out:
# a    1.431390
# b    1.664184
# c    0.851148
# d    1.727847
# dtype: float64

# %%
df.apply(np.cumsum)
# Out:
#         one       two     three
# a  1.048996 -0.382394       NaN
# b  1.341267 -0.005910 -1.287700
# c  1.163175  0.660530 -1.472408
# d       NaN  0.536415  0.131324

# %%
df.apply(np.exp)
# Out:
#         one       two     three
# a  2.854785  0.682226       NaN
# b  1.339465  1.457153  0.275905
# c  0.836866  1.947292  0.831347
# d       NaN  0.883278  4.971550

# %% [markdown]
# The apply() method will also dispatch on a string method name.

# %%
df.apply('mean')
# Out:
# one      0.387725
# two      0.134104
# three    0.043775
# dtype: float64

# %%
df.apply('max',axis = 1)
# Out:
# a    1.048996
# b    0.376484
# c    0.666440
# d    1.603732
# dtype: float64

# %% [markdown]
# The return type of the function passed to apply() affects the type of the final output from DataFrame.apply for the default behaviour:
#
# * If the applied function returns a Series, the final output is a DataFrame. The columns match the index of the Series returned by the applied function.
#
# * If the applied function returns any other type, the final output is a Series.
#
# This default behaviour can be overridden using the result_type, which accepts three options: reduce, broadcast, and expand. These will determine how list-likes return values expand (or not) to a DataFrame.

# %% [markdown]
# apply() combined with some cleverness can be used to answer many questions about a data set. For example, suppose we wanted to extract the date where the maximum value for each column occurred:

# %%
tsdf= pd.DataFrame(np.random.randn(100,4),index= pd.date_range('10-05-2020',periods=100,freq='m'),columns=list('abcd'))
tsdf
# Out:
#                    a         b         c         d
# 2020-10-31  1.733259 -0.000237  0.419733 -0.037877
# 2020-11-30 -1.101127  1.349144 -0.716047 -1.710003
# 2020-12-31 -0.788332 -0.564404  0.803175  0.144584
# 2021-01-31 -0.868174  0.065024 -0.374401 -0.192111
# 2021-02-28 -0.596463 -1.387275 -0.812557  1.142642
# ...              ...       ...       ...       ...
# 2028-09-30 -0.850095  1.800453  0.633854  1.295790
# 2028-10-31  0.275096 -0.303611  0.359850  0.158220
# 2028-11-30 -0.381011  2.257189  0.048562 -0.624478
# 2028-12-31 -0.576824  1.519060 -2.152579  0.269723
# 2029-01-31  0.341454  0.674703 -1.975855 -1.248976
#
# [100 rows x 4 columns]

# %%
tsdf.apply(lambda x : x.idxmax())
# Out:
# a   2024-10-31
# b   2028-11-30
# c   2027-04-30
# d   2026-11-30
# dtype: datetime64[ns]

# %% [markdown]
# You may also pass additional arguments and keyword arguments to the apply() method. For instance, consider the following function you would like to apply:

# %%
  def subtract_and_divide(x, sub, divide=1):
    return (x - sub) / divide

# %% [markdown]
# You may then apply this function as follows:

# %%
df.apply(subtract_and_divide, args=(5,), divide=3)
# Out:
#         one       two     three
# a -1.317001 -1.794131       NaN
# b -1.569243 -1.541172 -2.095900
# c -1.726030 -1.444520 -1.728236
# d       NaN -1.708038 -1.132089

# %% [markdown]
# Another useful feature is the ability to pass Series methods to carry out some Series operation on each column or row:

# %%
tsdf.iloc[1:5] = np.nan
tsdf
# Out:
#                    a         b         c         d
# 2020-10-31  1.733259 -0.000237  0.419733 -0.037877
# 2020-11-30       NaN       NaN       NaN       NaN
# 2020-12-31       NaN       NaN       NaN       NaN
# 2021-01-31       NaN       NaN       NaN       NaN
# 2021-02-28       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...
# 2028-09-30 -0.850095  1.800453  0.633854  1.295790
# 2028-10-31  0.275096 -0.303611  0.359850  0.158220
# 2028-11-30 -0.381011  2.257189  0.048562 -0.624478
# 2028-12-31 -0.576824  1.519060 -2.152579  0.269723
# 2029-01-31  0.341454  0.674703 -1.975855 -1.248976
#
# [100 rows x 4 columns]

# %%
tsdf.apply(pd.Series.interpolate)
# Out:
#                    a         b         c         d
# 2020-10-31  1.733259 -0.000237  0.419733 -0.037877
# 2020-11-30  1.361577  0.238057  0.252594  0.277106
# 2020-12-31  0.989895  0.476352  0.085454  0.592089
# 2021-01-31  0.618214  0.714646 -0.081685  0.907072
# 2021-02-28  0.246532  0.952940 -0.248824  1.222055
# ...              ...       ...       ...       ...
# 2028-09-30 -0.850095  1.800453  0.633854  1.295790
# 2028-10-31  0.275096 -0.303611  0.359850  0.158220
# 2028-11-30 -0.381011  2.257189  0.048562 -0.624478
# 2028-12-31 -0.576824  1.519060 -2.152579  0.269723
# 2029-01-31  0.341454  0.674703 -1.975855 -1.248976
#
# [100 rows x 4 columns]

# %% [markdown]
# ## Aggrigation API

# %% [markdown]
# The aggregation API allows one to express possibly multiple aggregation operations in a single concise way. This API is similar across pandas objects, see groupby API, the window API, and the resample API. The entry point for aggregation is DataFrame.aggregate(), or the alias DataFrame.agg().

# %%
tsdf
# Out:
#                    a         b         c         d
# 2020-10-31  1.733259 -0.000237  0.419733 -0.037877
# 2020-11-30       NaN       NaN       NaN       NaN
# 2020-12-31       NaN       NaN       NaN       NaN
# 2021-01-31       NaN       NaN       NaN       NaN
# 2021-02-28       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...
# 2028-09-30 -0.850095  1.800453  0.633854  1.295790
# 2028-10-31  0.275096 -0.303611  0.359850  0.158220
# 2028-11-30 -0.381011  2.257189  0.048562 -0.624478
# 2028-12-31 -0.576824  1.519060 -2.152579  0.269723
# 2029-01-31  0.341454  0.674703 -1.975855 -1.248976
#
# [100 rows x 4 columns]

# %% [markdown]
# Using a single function is equivalent to apply(). You can also pass named methods as strings. These will return a Series of the aggregated output:

# %%
tsdf.agg(np.sum)
# Out:
# a    -0.068341
# b    -7.049352
# c   -14.922788
# d    -8.166065
# dtype: float64

# %%
tsdf.agg('sum')
# Out:
# a    -0.068341
# b    -7.049352
# c   -14.922788
# d    -8.166065
# dtype: float64

# %%
# these are equivalent to a ``.sum()`` because we are aggregating
# on a single function
tsdf.sum()
# Out:
# a    -0.068341
# b    -7.049352
# c   -14.922788
# d    -8.166065
# dtype: float64

# %% [markdown]
# Single aggregations on a Series this will return a scalar value:

# %%
tsdf['a'].agg('sum')
# Out:
# -0.06834082487283638

# %% [markdown]
# **Aggregating with multiple functions**
#
# You can pass multiple aggregation arguments as a list. The results of each of the passed functions will be a row in the resulting DataFrame. These are naturally named from the aggregation function.

# %%
tsdf.agg(['sum'])
# Out:
#             a         b          c         d
# sum -0.068341 -7.049352 -14.922788 -8.166065

# %% [markdown]
# Multiple functions yield multiple rows:

# %%
tsdf.agg(['sum','mean'])
# Out:
#              a         b          c         d
# sum  -0.068341 -7.049352 -14.922788 -8.166065
# mean -0.000712 -0.073431  -0.155446 -0.085063

# %%
tsdf['a'].agg(['sum','mean'])
# Out:
# sum    -0.068341
# mean   -0.000712
# Name: a, dtype: float64

# %% [markdown]
# Passing a lambda function will yield a "lambda" named row:

# %%
tsdf['a'].agg('sum',lambda x:x.mean())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     553         try:
# --> 554             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555         except KeyError:
#
# KeyError: <function <lambda> at 0x7ec2a4b9a320>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-e860efca987e> in <cell line: 1>()
# ----> 1 tsdf['a'].agg('sum',lambda x:x.mean())
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in aggregate(self, func, axis, *args, **kwargs)
#    4596     def aggregate(self, func=None, axis: Axis = 0, *args, **kwargs):
#    4597         # Validate the axis parameter
# -> 4598         self._get_axis_number(axis)
#    4599
#    4600         # if func is None, will switch to user-provided "named aggregation" kwargs
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     554             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555         except KeyError:
# --> 556             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#     557
#     558     @final
#
# ValueError: No axis named <function <lambda> at 0x7ec2a4b9a320> for object type Series

# %%
tsdf['a'].agg(['sum',lambda x:x.mean()])
# Out:
# sum        -0.068341
# <lambda>   -0.000712
# Name: a, dtype: float64

# %% [markdown]
# Passing a named function will yield that name for the row:

# %%
def myMean(x):
  return x.mean()

tsdf['a'].agg(['sum',myMean])
# Out:
# sum      -0.068341
# myMean   -0.000712
# Name: a, dtype: float64

# %% [markdown]
# ### Aggregating with a dict

# %% [markdown]
# Passing a dictionary of column names to a scalar or a list of scalars, to DataFrame.agg allows you to customize which functions are applied to which columns. Note that the results are not in any particular order, you can use an OrderedDict instead to guarantee ordering.

# %%
tsdf.agg({'a':'sum','b':'mean'})
# Out:
# a   -0.068341
# b   -0.073431
# dtype: float64

# %% [markdown]
# Passing a list-like will generate a DataFrame output. You will get a matrix-like output of all of the aggregators. The output will consist of all unique functions. Those that are not noted for a particular column will be NaN:

# %%
tsdf.agg({'a':['sum','mean'],'b':['min','max']})
# Out:
#              a         b
# sum  -0.068341       NaN
# mean -0.000712       NaN
# min        NaN -2.071632
# max        NaN  2.257189

# %%
tsdf.agg({'a':['min','max'],'b':['min','max']})
# Out:
#             a         b
# min -3.145879 -2.071632
# max  2.188648  2.257189

# %% [markdown]
# ### Custom describe

# %% [markdown]
# With .agg() it is possible to easily create a custom describe function, similar to the built in describe function.

# %%
from functools import partial

q_25 = partial(pd.Series.quantile,q = .25)
q_25.__name__='25%'

q_75 = partial(pd.Series.quantile,q=.75)
q_75.__name__ = '75%'

tsdf.agg(['count','mean','std','min',q_25,'median',q_75,'max'])
# Out:
#                 a          b          c          d
# count   96.000000  96.000000  96.000000  96.000000
# mean    -0.000712  -0.073431  -0.155446  -0.085063
# std      0.930344   0.928088   1.008548   0.982234
# min     -3.145879  -2.071632  -2.225676  -2.675774
# 25%     -0.591501  -0.694638  -0.896644  -0.865235
# median  -0.005138  -0.073978  -0.139015  -0.074103
# 75%      0.635109   0.621679   0.550449   0.621188
# max      2.188648   2.257189   2.385861   2.780036

# %% [markdown]
# ## Transform API

# %% [markdown]
# The transform() method returns an object that is indexed the same (same size) as the original. This API allows you to provide multiple operations at the same time rather than one-by-one. Its API is quite similar to the .agg API.
#
# We create a frame similar to the one used in the above sections.

# %%
tsdf
# Out:
#                    a         b         c         d
# 2020-10-31  1.733259 -0.000237  0.419733 -0.037877
# 2020-11-30       NaN       NaN       NaN       NaN
# 2020-12-31       NaN       NaN       NaN       NaN
# 2021-01-31       NaN       NaN       NaN       NaN
# 2021-02-28       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...
# 2028-09-30 -0.850095  1.800453  0.633854  1.295790
# 2028-10-31  0.275096 -0.303611  0.359850  0.158220
# 2028-11-30 -0.381011  2.257189  0.048562 -0.624478
# 2028-12-31 -0.576824  1.519060 -2.152579  0.269723
# 2029-01-31  0.341454  0.674703 -1.975855 -1.248976
#
# [100 rows x 4 columns]

# %% [markdown]
# Transform the entire frame. .transform() allows input functions as: a NumPy function, a string function name or a user defined function.

# %%
tsdf.transform(np.abs)
# Out:
#                    a         b         c         d
# 2020-10-31  1.733259  0.000237  0.419733  0.037877
# 2020-11-30       NaN       NaN       NaN       NaN
# 2020-12-31       NaN       NaN       NaN       NaN
# 2021-01-31       NaN       NaN       NaN       NaN
# 2021-02-28       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...
# 2028-09-30  0.850095  1.800453  0.633854  1.295790
# 2028-10-31  0.275096  0.303611  0.359850  0.158220
# 2028-11-30  0.381011  2.257189  0.048562  0.624478
# 2028-12-31  0.576824  1.519060  2.152579  0.269723
# 2029-01-31  0.341454  0.674703  1.975855  1.248976
#
# [100 rows x 4 columns]

# %%
tsdf.transform('abs')
# Out:
#                    a         b         c         d
# 2020-10-31  1.733259  0.000237  0.419733  0.037877
# 2020-11-30       NaN       NaN       NaN       NaN
# 2020-12-31       NaN       NaN       NaN       NaN
# 2021-01-31       NaN       NaN       NaN       NaN
# 2021-02-28       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...
# 2028-09-30  0.850095  1.800453  0.633854  1.295790
# 2028-10-31  0.275096  0.303611  0.359850  0.158220
# 2028-11-30  0.381011  2.257189  0.048562  0.624478
# 2028-12-31  0.576824  1.519060  2.152579  0.269723
# 2029-01-31  0.341454  0.674703  1.975855  1.248976
#
# [100 rows x 4 columns]

# %%
tsdf.transform(lambda x: x.abs())
# Out:
#                    a         b         c         d
# 2020-10-31  1.733259  0.000237  0.419733  0.037877
# 2020-11-30       NaN       NaN       NaN       NaN
# 2020-12-31       NaN       NaN       NaN       NaN
# 2021-01-31       NaN       NaN       NaN       NaN
# 2021-02-28       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...
# 2028-09-30  0.850095  1.800453  0.633854  1.295790
# 2028-10-31  0.275096  0.303611  0.359850  0.158220
# 2028-11-30  0.381011  2.257189  0.048562  0.624478
# 2028-12-31  0.576824  1.519060  2.152579  0.269723
# 2029-01-31  0.341454  0.674703  1.975855  1.248976
#
# [100 rows x 4 columns]

# %% [markdown]
# Here transform() received a single function; this is equivalent to a ufunc application.

# %%
np.abs(tsdf)
# Out:
#                    a         b         c         d
# 2020-10-31  1.733259  0.000237  0.419733  0.037877
# 2020-11-30       NaN       NaN       NaN       NaN
# 2020-12-31       NaN       NaN       NaN       NaN
# 2021-01-31       NaN       NaN       NaN       NaN
# 2021-02-28       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...
# 2028-09-30  0.850095  1.800453  0.633854  1.295790
# 2028-10-31  0.275096  0.303611  0.359850  0.158220
# 2028-11-30  0.381011  2.257189  0.048562  0.624478
# 2028-12-31  0.576824  1.519060  2.152579  0.269723
# 2029-01-31  0.341454  0.674703  1.975855  1.248976
#
# [100 rows x 4 columns]

# %%
tsdf['a'].transform('abs')
# Out:
# 2020-10-31    1.733259
# 2020-11-30         NaN
# 2020-12-31         NaN
# 2021-01-31         NaN
# 2021-02-28         NaN
#                 ...
# 2028-09-30    0.850095
# 2028-10-31    0.275096
# 2028-11-30    0.381011
# 2028-12-31    0.576824
# 2029-01-31    0.341454
# Freq: M, Name: a, Length: 100, dtype: float64

# %% [markdown]
# **Transform with multiple functions**

# %%
tsdf.transform([np.abs,np.mean])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-f3f2f979b054> in <cell line: 1>()
# ----> 1 tsdf.transform([np.abs,np.mean])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in transform(self, func, axis, *args, **kwargs)
#    9405
#    9406         op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
# -> 9407         result = op.transform()
#    9408         assert isinstance(result, DataFrame)
#    9409         return result
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in transform(self)
#     228         if is_dict_like(func):
#     229             func = cast(AggFuncTypeDict, func)
# --> 230             return self.transform_dict_like(func)
#     231
#     232         # func is either str or callable
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in transform_dict_like(self, func)
#     288                     "No transform functions were provided",
#     289                 }:
# --> 290                     raise err
#     291                 else:
#     292                     if not isinstance(err, TypeError):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in transform_dict_like(self, func)
#     282             colg = obj._gotitem(name, ndim=1)
#     283             try:
# --> 284                 results[name] = colg.transform(how, 0, *args, **kwargs)
#     285             except Exception as err:
#     286                 if str(err) in {
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in transform(self, func, axis, *args, **kwargs)
#    4656         result = SeriesApply(
#    4657             self, func=func, convert_dtype=True, args=args, kwargs=kwargs
# -> 4658         ).transform()
#    4659         return result
#    4660
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in transform(self)
#     228         if is_dict_like(func):
#     229             func = cast(AggFuncTypeDict, func)
# --> 230             return self.transform_dict_like(func)
#     231
#     232         # func is either str or callable
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in transform_dict_like(self, func)
#     288                     "No transform functions were provided",
#     289                 }:
# --> 290                     raise err
#     291                 else:
#     292                     if not isinstance(err, TypeError):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in transform_dict_like(self, func)
#     282             colg = obj._gotitem(name, ndim=1)
#     283             try:
# --> 284                 results[name] = colg.transform(how, 0, *args, **kwargs)
#     285             except Exception as err:
#     286                 if str(err) in {
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in transform(self, func, axis, *args, **kwargs)
#    4656         result = SeriesApply(
#    4657             self, func=func, convert_dtype=True, args=args, kwargs=kwargs
# -> 4658         ).transform()
#    4659         return result
#    4660
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in transform(self)
#     254             obj.index  # type:ignore[arg-type]
#     255         ):
# --> 256             raise ValueError("Function did not transform")
#     257
#     258         return result
#
# ValueError: Function did not transform

# %%
tsdf.transform([np.abs,lambda x:x.mean()]) # better to use agg some times it gives error with two functions
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-2f266fc04c5d> in <cell line: 1>()
# ----> 1 tsdf.transform([np.abs,lambda x:x.mean()])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in transform(self, func, axis, *args, **kwargs)
#    9405
#    9406         op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
# -> 9407         result = op.transform()
#    9408         assert isinstance(result, DataFrame)
#    9409         return result
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in transform(self)
#     228         if is_dict_like(func):
#     229             func = cast(AggFuncTypeDict, func)
# --> 230             return self.transform_dict_like(func)
#     231
#     232         # func is either str or callable
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in transform_dict_like(self, func)
#     288                     "No transform functions were provided",
#     289                 }:
# --> 290                     raise err
#     291                 else:
#     292                     if not isinstance(err, TypeError):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in transform_dict_like(self, func)
#     282             colg = obj._gotitem(name, ndim=1)
#     283             try:
# --> 284                 results[name] = colg.transform(how, 0, *args, **kwargs)
#     285             except Exception as err:
#     286                 if str(err) in {
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in transform(self, func, axis, *args, **kwargs)
#    4656         result = SeriesApply(
#    4657             self, func=func, convert_dtype=True, args=args, kwargs=kwargs
# -> 4658         ).transform()
#    4659         return result
#    4660
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in transform(self)
#     228         if is_dict_like(func):
#     229             func = cast(AggFuncTypeDict, func)
# --> 230             return self.transform_dict_like(func)
#     231
#     232         # func is either str or callable
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in transform_dict_like(self, func)
#     288                     "No transform functions were provided",
#     289                 }:
# --> 290                     raise err
#     291                 else:
#     292                     if not isinstance(err, TypeError):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in transform_dict_like(self, func)
#     282             colg = obj._gotitem(name, ndim=1)
#     283             try:
# --> 284                 results[name] = colg.transform(how, 0, *args, **kwargs)
#     285             except Exception as err:
#     286                 if str(err) in {
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in transform(self, func, axis, *args, **kwargs)
#    4656         result = SeriesApply(
#    4657             self, func=func, convert_dtype=True, args=args, kwargs=kwargs
# -> 4658         ).transform()
#    4659         return result
#    4660
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in transform(self)
#     254             obj.index  # type:ignore[arg-type]
#     255         ):
# --> 256             raise ValueError("Function did not transform")
#     257
#     258         return result
#
# ValueError: Function did not transform

# %%
tsdf.transform([np.abs,lambda x:x+1])
# Out:
#                    a                   b                   c            \
#             absolute  <lambda>  absolute  <lambda>  absolute  <lambda>
# 2020-10-31  1.733259  2.733259  0.000237  0.999763  0.419733  1.419733
# 2020-11-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2020-12-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-02-28       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2028-09-30  0.850095  0.149905  1.800453  2.800453  0.633854  1.633854
# 2028-10-31  0.275096  1.275096  0.303611  0.696389  0.359850  1.359850
# 2028-11-30  0.381011  0.618989  2.257189  3.257189  0.048562  1.048562
# 2028-12-31  0.576824  0.423176  1.519060  2.519060  2.152579 -1.152579
# 2029-01-31  0.341454  1.341454  0.674703  1.674703  1.975855 -0.975855
#
#                    d
#             absolute  <lambda>
# 2020-10-31  0.037877  0.962123
# 2020-11-30       NaN       NaN
# 2020-12-31       NaN       NaN
# 2021-01-31       NaN       NaN
# 2021-02-28       NaN       NaN
# ...              ...       ...
# 2028-09-30  1.295790  2.295790
# 2028-10-31  0.158220  1.158220
# 2028-11-30  0.624478  0.375522
# 2028-12-31  0.269723  1.269723
# 2029-01-31  1.248976 -0.248976
#
# [100 rows x 8 columns]

# %%
tsdf['a'].transform([np.abs,lambda x : x+1])
# Out:
#             absolute  <lambda>
# 2020-10-31  1.733259  2.733259
# 2020-11-30       NaN       NaN
# 2020-12-31       NaN       NaN
# 2021-01-31       NaN       NaN
# 2021-02-28       NaN       NaN
# ...              ...       ...
# 2028-09-30  0.850095  0.149905
# 2028-10-31  0.275096  1.275096
# 2028-11-30  0.381011  0.618989
# 2028-12-31  0.576824  0.423176
# 2029-01-31  0.341454  1.341454
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Transforming with a dict

# %%
tsdf.transform({'a':np.abs,'b':lambda x:x+1})
# Out:
#                    a         b
# 2020-10-31  1.733259  0.999763
# 2020-11-30       NaN       NaN
# 2020-12-31       NaN       NaN
# 2021-01-31       NaN       NaN
# 2021-02-28       NaN       NaN
# ...              ...       ...
# 2028-09-30  0.850095  2.800453
# 2028-10-31  0.275096  0.696389
# 2028-11-30  0.381011  3.257189
# 2028-12-31  0.576824  2.519060
# 2029-01-31  0.341454  1.674703
#
# [100 rows x 2 columns]

# %%
tsdf.transform({'a':np.abs,'b':[lambda x : x+1 ,'sqrt']})
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#                    a         b
#             absolute  <lambda>      sqrt
# 2020-10-31  1.733259  0.999763       NaN
# 2020-11-30       NaN       NaN       NaN
# 2020-12-31       NaN       NaN       NaN
# 2021-01-31       NaN       NaN       NaN
# 2021-02-28       NaN       NaN       NaN
# ...              ...       ...       ...
# 2028-09-30  0.850095  2.800453  1.341809
# 2028-10-31  0.275096  0.696389       NaN
# 2028-11-30  0.381011  3.257189  1.502394
# 2028-12-31  0.576824  2.519060  1.232501
# 2029-01-31  0.341454  1.674703  0.821403
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Applying elementwise functions

# %% [markdown]
# Since not all functions can be vectorized (accept NumPy arrays and return another array or value), the methods applymap() on DataFrame and analogously map() on Series accept any Python function taking a single value and returning a single value. For example:

# %%
df
# Out:
#         one       two     three
# a  1.048996 -0.382394       NaN
# b  0.292270  0.376484 -1.287700
# c -0.178091  0.666440 -0.184708
# d       NaN -0.124115  1.603732

# %%
def func(x):
  return len(str(x))

df['one'].map(func)
# Out:
# a    17
# b    19
# c    19
# d     3
# Name: one, dtype: int64

# %%
df.applymap(func)
# Out:
#    one  two  three
# a   17   19      3
# b   19   18     19
# c   19   18     19
# d    3   20     18

# %% [markdown]
# Series.map() has an additional feature; it can be used to easily “link” or “map” values defined by a secondary series. This is closely related to merging/joining functionality:

# %%
s = pd.Series(
    ["six", "seven", "six", "seven", "six"], index=["a", "b", "c", "d", "e"]
)


t = pd.Series({"six": 6.0, "seven": 7.0})

# %%
s
# Out:
# a      six
# b    seven
# c      six
# d    seven
# e      six
# dtype: object

# %%
s.map(t)
# Out:
# a    6.0
# b    7.0
# c    6.0
# d    7.0
# e    6.0
# dtype: float64

# %% [markdown]
# # Reindexing and altering labels

# %% [markdown]
# reindex() is the fundamental data alignment method in pandas. It is used to implement nearly all other features relying on label-alignment functionality. To reindex means to conform the data to match a given set of labels along a particular axis. This accomplishes several things:
#
# * Reorders the existing data to match a new set of labels
#
# * Inserts missing value (NA) markers in label locations where no data for that label existed
#
# * If specified, fill data for missing labels using logic (highly relevant to working with time series data)

# %%
s = pd.Series(np.random.randn(5), index=["a", "b", "c", "d", "e"])
s
# Out:
# a    0.263757
# b    0.587894
# c   -0.903844
# d   -0.071259
# e    1.339860
# dtype: float64

# %%
s.reindex(["e", "b", "f", "d"])
# Out:
# e    1.339860
# b    0.587894
# f         NaN
# d   -0.071259
# dtype: float64

# %%
df
# Out:
#         one       two     three
# a  1.048996 -0.382394       NaN
# b  0.292270  0.376484 -1.287700
# c -0.178091  0.666440 -0.184708
# d       NaN -0.124115  1.603732

# %%
df.reindex(index = ['c','f','b'],columns = ['three','two','one'])
#Here, the f label was not contained in the Series and hence appears as NaN in the result.
# Out:
#       three       two       one
# c -0.184708  0.666440 -0.178091
# f       NaN       NaN       NaN
# b -1.287700  0.376484  0.292270

# %%
df.reindex(['c','f','b'],axis = 'index')
# Out:
#         one       two     three
# c -0.178091  0.666440 -0.184708
# f       NaN       NaN       NaN
# b  0.292270  0.376484 -1.287700

# %%
df.reindex(['one','two','three'],axis = 'columns')
# Out:
#         one       two     three
# a  1.048996 -0.382394       NaN
# b  0.292270  0.376484 -1.287700
# c -0.178091  0.666440 -0.184708
# d       NaN -0.124115  1.603732

# %% [markdown]
# ## Reindexing to align with another object

# %% [markdown]
# You may wish to take an object and reindex its axes to be labeled the same as another object. While the syntax for this is straightforward albeit verbose, it is a common enough operation that the reindex_like() method is available to make this simpler:

# %%
df3 = pd.DataFrame(np.random.randn(3,2), index = list('abc'),columns=['one','two'])

# %%
df4 = pd.DataFrame(np.random.randn(3,2), index = list('abc'),columns=['one','two'])

# %%
df3
# Out:
#         one       two
# a -0.560512  0.222174
# b  0.655735 -0.508792
# c  1.008279  1.470797

# %%
df4
# Out:
#         one       two
# a -0.179878  0.421876
# b -0.093670 -1.044807
# c  0.543076  1.208896

# %%
df.reindex_like(df3)
# Out:
#         one       two
# a  1.048996 -0.382394
# b  0.292270  0.376484
# c -0.178091  0.666440

# %% [markdown]
# ## Aligning objects with each other with align

# %% [markdown]
# The align() method is the fastest way to simultaneously align two objects. It supports a join argument (related to joining and merging):
#
# * join='outer': take the union of the indexes (default)
#
# * join='left': use the calling object’s index
#
# * join='right': use the passed object’s index
#
# * join='inner': intersect the indexes

# %%
s = pd.Series(np.random.randn(5), index=["a", "b", "c", "d", "e"])

# %%
s1 =s[:4]
s2 =s[1:]

# %%
s1.align(s2)
# Out:
# (a   -2.402740
#  b   -0.126574
#  c    1.094880
#  d    0.029777
#  e         NaN
#  dtype: float64,
#  a         NaN
#  b   -0.126574
#  c    1.094880
#  d    0.029777
#  e    0.733576
#  dtype: float64)

# %%
s1.align(s2,join='inner')
# Out:
# (b   -0.126574
#  c    1.094880
#  d    0.029777
#  dtype: float64,
#  b   -0.126574
#  c    1.094880
#  d    0.029777
#  dtype: float64)

# %%
s1.align(s2,join='left')
# Out:
# (a   -2.402740
#  b   -0.126574
#  c    1.094880
#  d    0.029777
#  dtype: float64,
#  a         NaN
#  b   -0.126574
#  c    1.094880
#  d    0.029777
#  dtype: float64)

# %%
s1.align(s2,join='right')
# Out:
# (b   -0.126574
#  c    1.094880
#  d    0.029777
#  e         NaN
#  dtype: float64,
#  b   -0.126574
#  c    1.094880
#  d    0.029777
#  e    0.733576
#  dtype: float64)

# %% [markdown]
# For DataFrames, the join method will be applied to both the index and the columns by defau

# %%
df.align(df3,join = 'inner',axis=0)
# Out:
# (        one       two     three
#  a  1.048996 -0.382394       NaN
#  b  0.292270  0.376484 -1.287700
#  c -0.178091  0.666440 -0.184708,
#          one       two
#  a -0.560512  0.222174
#  b  0.655735 -0.508792
#  c  1.008279  1.470797)

# %% [markdown]
# If you pass a Series to DataFrame.align(), you can choose to align both objects either on the DataFrame’s index or columns using the axis argument:

# %%
df.align(df3.iloc[0],axis=1)
# Out:
# (        one     three       two
#  a  1.048996       NaN -0.382394
#  b  0.292270 -1.287700  0.376484
#  c -0.178091 -0.184708  0.666440
#  d       NaN  1.603732 -0.124115,
#  one     -0.560512
#  three         NaN
#  two      0.222174
#  Name: a, dtype: float64)

# %% [markdown]
# ## Filling while reindexing
