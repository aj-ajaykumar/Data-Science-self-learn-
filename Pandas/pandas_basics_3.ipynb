# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## create a dictionary

# %%
dict1 = {
    "name": ["ajay","kumar","gnani","ram"],
    "number":[3,2,4,5],
    "test":["xyz","abc","afg","ert"],
    "String":['aj','ay','ku','mar']
    
}

# %%
dict1
# Out:
# {'name': ['ajay', 'kumar', 'gnani', 'ram'],
#  'number': [3, 2, 4, 5],
#  'test': ['xyz', 'abc', 'afg', 'ert'],
#  'String': ['aj', 'ay', 'ku', 'mar']}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#     name  number test String
# 0   ajay       3  xyz     aj
# 1  kumar       2  abc     ay
# 2  gnani       4  afg     ku
# 3    ram       5  ert    mar

# %%
dict2 = {
    "name": ["ajay1","raj1","gnani","sekhar"],
    "number":[6,7,8,9],
    "test":["xyz","abc","afg","ert"],
    "String":['aj','ay','ku','mar']
}

# %%
df2 = pd.DataFrame(dict2)

# %%
df2
# Out:
#      name  number test String
# 0   ajay1       6  xyz     aj
# 1    raj1       7  abc     ay
# 2   gnani       8  afg     ku
# 3  sekhar       9  ert    mar

# %% [markdown]
# ## concationation of two dictionaries

# %% [markdown]
# **there are two types of concatinations 1 vertical and 2 horizanta**

# %%
pd.concat([df,df2]) #check the axis
# Out:
#      name  number test String
# 0    ajay       3  xyz     aj
# 1   kumar       2  abc     ay
# 2   gnani       4  afg     ku
# 3     ram       5  ert    mar
# 0    ajay       3  xyz     aj
# 1     raj       2  abc     ay
# 2   gnani       4  afg     ku
# 3  sekhar       5  ert    mar

# %%
#row wise 
df4 = pd.concat([df,df2],axis = 1)

# %%
df4
# Out:
#     name  number test String    name  number test String
# 0   ajay       3  xyz     aj    ajay       3  xyz     aj
# 1  kumar       2  abc     ay     raj       2  abc     ay
# 2  gnani       4  afg     ku   gnani       4  afg     ku
# 3    ram       5  ert    mar  sekhar       5  ert    mar

# %% [markdown]
# **if you give a diffrent heders to the dicts then it will directly add them in a column wise because both row are not samre**

# %%
dict3 = {
    "name1": ["ajay","raj","gnani","sekhar"],
    "number1":[3,2,4,5],
    "test1":["xyz","abc","afg","ert"],
    "String1":['aj','ay','ku','mar']
}

# %%
df3 = pd.DataFrame(dict3)

# %%
df5 = pd.concat([df3,df2]) #It gives noun values because the columns are not same

# %%
df5
# Out:
#     name1  number1 test1 String1    name  number test String
# 0    ajay      3.0   xyz      aj     NaN     NaN  NaN    NaN
# 1     raj      2.0   abc      ay     NaN     NaN  NaN    NaN
# 2   gnani      4.0   afg      ku     NaN     NaN  NaN    NaN
# 3  sekhar      5.0   ert     mar     NaN     NaN  NaN    NaN
# 0     NaN      NaN   NaN     NaN    ajay     3.0  xyz     aj
# 1     NaN      NaN   NaN     NaN     raj     2.0  abc     ay
# 2     NaN      NaN   NaN     NaN   gnani     4.0  afg     ku
# 3     NaN      NaN   NaN     NaN  sekhar     5.0  ert    mar

# %%
df6 = pd.concat([df,df3],axis = 1)
df6
# Out:
#     name  number test String   name1  number1 test1 String1
# 0   ajay       3  xyz     aj    ajay        3   xyz      aj
# 1  kumar       2  abc     ay     raj        2   abc      ay
# 2  gnani       4  afg     ku   gnani        4   afg      ku
# 3    ram       5  ert    mar  sekhar        5   ert     mar

# %%
# extraxct some middle daata
df6[['number','test']][1:3]
# Out:
#    number test
# 1       2  abc
# 2       4  afg

# %%
# another way
df6.iloc[1:3,1:3]
# Out:
#    number test
# 1       2  abc
# 2       4  afg

# %%
# extract 2nd row last 3 columns and 4th row last 3 columns 
df6.iloc[1:4:2,5:]
# Out:
#    number1 test1 String1
# 1        2   abc      ay
# 3        5   ert     mar

# %%
#or 
df6.iloc[[1,3]][['number1','test1','String1']]
# Out:
#    number1 test1 String1
# 1        2   abc      ay
# 3        5   ert     mar

# %%
df
# Out:
#     name  number test String
# 0   ajay       3  xyz     aj
# 1  kumar       2  abc     ay
# 2  gnani       4  afg     ku
# 3    ram       5  ert    mar

# %%
df2
# Out:
#      name  number test String
# 0   ajay1       6  xyz     aj
# 1    raj1       7  abc     ay
# 2   gnani       8  afg     ku
# 3  sekhar       9  ert    mar

# %% [markdown]
# ## merge operations

# %%
pd.merge(df,df2) # we didn't get any data
# Out:
# Empty DataFrame
# Columns: [name, number, test, String]
# Index: []

# %%
pd.merge(df,df2, on = 'name') # if it only select both tables have same data as a name
# Out:
#     name  number_x test_x String_x  number_y test_y String_y
# 0  gnani         4    afg       ku         8    afg       ku

# %% [markdown]
# the above condition defaultly inner join  (try with shift+tab)

# %%
pd.merge(df,df2, on = 'test')
# Out:
#   name_x  number_x test String_x  name_y  number_y String_y
# 0   ajay         3  xyz       aj   ajay1         3       aj
# 1  kumar         2  abc       ay    raj1         2       ay
# 2  gnani         4  afg       ku   gnani         4       ku
# 3    ram         5  ert      mar  sekhar         5      mar

# %%
pd.merge(df,df2, on = 'number') # because there no common data
# Out:
# Empty DataFrame
# Columns: [name_x, number, test_x, String_x, name_y, test_y, String_y]
# Index: []

# %%
pd.merge(df,df2, on = 'number',how = 'left') #left join
# Out:
#   name_x  number test_x String_x name_y test_y String_y
# 0   ajay       3    xyz       aj    NaN    NaN      NaN
# 1  kumar       2    abc       ay    NaN    NaN      NaN
# 2  gnani       4    afg       ku    NaN    NaN      NaN
# 3    ram       5    ert      mar    NaN    NaN      NaN

# %% [markdown]
# **if the data in the header is diffrent in two dfs**
#
# **if on condition is in the  header like diffrent number1,number2**
#
# **both dfs have diffrent column names it gves error**

# %%
dict5 ={
    "name": ["ajay1","kumar2","gnani","ram"],
    "number1":[3,2,4,6],
    "test":["xyz","abck","afg","ert"],
    "String":['aj','ay','kuk1','mar']
}

df7 = pd.DataFrame(dict5)

# %%
df7
# Out:
#      name  number1  test String
# 0   ajay1        3   xyz     aj
# 1  kumar2        2  abck     ay
# 2   gnani        4   afg   kuk1
# 3     ram        6   ert    mar

# %%
pd.merge(df,df7, on = 'number',how = 'left') # because the column number is not in df7
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8412\1684336798.py in <module>
# ----> 1 pd.merge(df,df7, on = 'number',how = 'left') # because the column number is not in df7
#
# c:\users\ajay kumar\appdata\local\programs\python\python37\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     117         copy=copy,
#     118         indicator=indicator,
# --> 119         validate=validate,
#     120     )
#     121     return op.get_result()
#
# c:\users\ajay kumar\appdata\local\programs\python\python37\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     697             self.right_join_keys,
# ...

# %% [markdown]
# ## how to over come
# see the Shift+tab And observe

# %%
 pd.merge(df,df7, left_on = 'number',right_on='number1')# inner
# Out:
#   name_x  number test_x String_x  name_y  number1 test_y String_y
# 0   ajay       3    xyz       aj   ajay1        3    xyz       aj
# 1  kumar       2    abc       ay  kumar2        2   abck       ay
# 2  gnani       4    afg       ku   gnani        4    afg     kuk1

# %%
 pd.merge(df,df7, left_on = 'number',right_on='number1',how ='left') #left jon
# Out:
#   name_x  number test_x String_x  name_y  number1 test_y String_y
# 0   ajay       3    xyz       aj   ajay1      3.0    xyz       aj
# 1  kumar       2    abc       ay  kumar2      2.0   abck       ay
# 2  gnani       4    afg       ku   gnani      4.0    afg     kuk1
# 3    ram       5    ert      mar     NaN      NaN    NaN      NaN

# %%
 pd.merge(df,df7, left_on = 'number',right_on='number1',how ='right')# right  join
# Out:
#   name_x  number test_x String_x  name_y  number1 test_y String_y
# 0   ajay     3.0    xyz       aj   ajay1        3    xyz       aj
# 1  kumar     2.0    abc       ay  kumar2        2   abck       ay
# 2  gnani     4.0    afg       ku   gnani        4    afg     kuk1
# 3    NaN     NaN    NaN      NaN     ram        6    ert      mar

# %%
pd.merge(df,df7, left_on = 'number',right_on='number1',how = 'outer') # outer join
# Out:
#   name_x  number test_x String_x  name_y  number1 test_y String_y
# 0   ajay     3.0    xyz       aj   ajay1      3.0    xyz       aj
# 1  kumar     2.0    abc       ay  kumar2      2.0   abck       ay
# 2  gnani     4.0    afg       ku   gnani      4.0    afg     kuk1
# 3    ram     5.0    ert      mar     NaN      NaN    NaN      NaN
# 4    NaN     NaN    NaN      NaN     ram      6.0    ert      mar

# %%
df
# Out:
#     name  number test String
# 0   ajay       3  xyz     aj
# 1  kumar       2  abc     ay
# 2  gnani       4  afg     ku
# 3    ram       5  ert    mar

# %%
df7
# Out:
#      name  number1  test String
# 0   ajay1        3   xyz     aj
# 1  kumar2        2  abck     ay
# 2   gnani        4   afg   kuk1
# 3     ram        6   ert    mar

# %%
# if name and number both are match it will perform merge operation 
pd.merge(df,df7, on = ['name','String'])
# Out:
#   name  number test_x String  number1 test_y
# 0  ram       5    ert    mar        6    ert

# %%
pd.merge(df,df7, on = ['name','String'],how = 'left')
# Out:
#     name  number test_x String  number1 test_y
# 0   ajay       3    xyz     aj      NaN    NaN
# 1  kumar       2    abc     ay      NaN    NaN
# 2  gnani       4    afg     ku      NaN    NaN
# 3    ram       5    ert    mar      6.0    ert

# %%
pd.merge(df,df7, on = ['name','String'],how = 'outer')
# Out:
#      name  number test_x String  number1 test_y
# 0    ajay     3.0    xyz     aj      NaN    NaN
# 1   kumar     2.0    abc     ay      NaN    NaN
# 2   gnani     4.0    afg     ku      NaN    NaN
# 3     ram     5.0    ert    mar      6.0    ert
# 4   ajay1     NaN    NaN     aj      3.0    xyz
# 5  kumar2     NaN    NaN     ay      2.0   abck
# 6   gnani     NaN    NaN   kuk1      4.0    afg

# %% [markdown]
# **in merge operations are based on columns using (on)**
#
# **but in join it will inly use the indexes**

# %%
df.join(df2)# same columns
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8412\1869833937.py in <module>
# ----> 1 df.join(df2)# same columns
#
# c:\users\ajay kumar\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9098         """
#    9099         return self._join_compat(
# -> 9100             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9101         )
#    9102
#
# c:\users\ajay kumar\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9136                 right_index=True,
#    9137                 suffixes=(lsuffix, rsuffix),
# -> 9138                 sort=sort,
#    9139             )
#    9140         else:
#
# ...

# %%
df.join(df3) # columns are diffrent and default it take left
# Out:
#     name  number test String   name1  number1 test1 String1
# 0   ajay       3  xyz     aj    ajay        3   xyz      aj
# 1  kumar       2  abc     ay     raj        2   abc      ay
# 2  gnani       4  afg     ku   gnani        4   afg      ku
# 3    ram       5  ert    mar  sekhar        5   ert     mar

# %%
df3
# Out:
#     name1  number1 test1 String1
# 0    ajay        3   xyz      aj
# 1     raj        2   abc      ay
# 2   gnani        4   afg      ku
# 3  sekhar        5   ert     mar

# %%
df3.index  = [5,6,7,8] # change the index

# %%
df3
# Out:
#     name1  number1 test1 String1
# 5    ajay        3   xyz      aj
# 6     raj        2   abc      ay
# 7   gnani        4   afg      ku
# 8  sekhar        5   ert     mar

# %%
df.join(df3) #deafult left join
# Out:
#     name  number test String name1  number1 test1 String1
# 0   ajay       3  xyz     aj   NaN      NaN   NaN     NaN
# 1  kumar       2  abc     ay   NaN      NaN   NaN     NaN
# 2  gnani       4  afg     ku   NaN      NaN   NaN     NaN
# 3    ram       5  ert    mar   NaN      NaN   NaN     NaN

# %%
df.join(df3,how ='right')
# Out:
#   name  number test String   name1  number1 test1 String1
# 5  NaN     NaN  NaN    NaN    ajay        3   xyz      aj
# 6  NaN     NaN  NaN    NaN     raj        2   abc      ay
# 7  NaN     NaN  NaN    NaN   gnani        4   afg      ku
# 8  NaN     NaN  NaN    NaN  sekhar        5   ert     mar

# %%
df.join(df3,how ='outer')
# Out:
#     name  number test String   name1  number1 test1 String1
# 0   ajay     3.0  xyz     aj     NaN      NaN   NaN     NaN
# 1  kumar     2.0  abc     ay     NaN      NaN   NaN     NaN
# 2  gnani     4.0  afg     ku     NaN      NaN   NaN     NaN
# 3    ram     5.0  ert    mar     NaN      NaN   NaN     NaN
# 5    NaN     NaN  NaN    NaN    ajay      3.0   xyz      aj
# 6    NaN     NaN  NaN    NaN     raj      2.0   abc      ay
# 7    NaN     NaN  NaN    NaN   gnani      4.0   afg      ku
# 8    NaN     NaN  NaN    NaN  sekhar      5.0   ert     mar

# %% [markdown]
# **merge and join both are like same but the diffrence is merge takes a columns as refence key for cunstruct the table**
#
# **but in join only indesx wiil be taken as refence**

# %%
#suppose change the coulmns of df3
df3.index = [[1,0,7,8]]

# %%
df3
# Out:
#     name1  number1 test1 String1
# 1    ajay        3   xyz      aj
# 0     raj        2   abc      ay
# 7   gnani        4   afg      ku
# 8  sekhar        5   ert     mar

# %%
df.join(df3, how ='right')
# Out:
#   name  number test String   name1  number1 test1 String1
# 1  NaN     NaN  NaN    NaN    ajay        3   xyz      aj
# 0  NaN     NaN  NaN    NaN     raj        2   abc      ay
# 7  NaN     NaN  NaN    NaN   gnani        4   afg      ku
# 8  NaN     NaN  NaN    NaN  sekhar        5   ert     mar

# %%
dict11 ={
    'column1':[1,2,3,4,5,6,7],
    'column2':[2,33,434,465,87,55,77],
    'column3':"hi my name is ajay kumar aj"    
}

# %%
dfc = pd.DataFrame(dict11) # i dont want like this i want ervery word in every row 
dfc
# Out:
#    column1  column2                      column3
# 0        1        2  hi my name is ajay kumar aj
# 1        2       33  hi my name is ajay kumar aj
# 2        3      434  hi my name is ajay kumar aj
# 3        4      465  hi my name is ajay kumar aj
# 4        5       87  hi my name is ajay kumar aj
# 5        6       55  hi my name is ajay kumar aj
# 6        7       77  hi my name is ajay kumar aj

# %%
dict11 ={
    'column1':[1,2,3,4,5,6,7],
    'column2':[2,33,434,465,87,55,77],
    'column3':"hi my name is ajay kumar aj".split()   
}

# %%
dfc = pd.DataFrame(dict11) 
dfc
# Out:
#    column1  column2 column3
# 0        1        2      hi
# 1        2       33      my
# 2        3      434    name
# 3        4      465      is
# 4        5       87    ajay
# 5        6       55   kumar
# 6        7       77      aj

# %% [markdown]
# **but some time element in the dict are not in same count how we will achive this**

# %% [markdown]
# ## dict have diffrent variable count

# %%
dict22 ={
    'column1':[1,2,3,4,5,6,7],
    'column2':[2,33,434,465,87,55,77],
    'column3':"hi my name is ajay ".split()    
}

# %%
dfk = pd.DataFrame(dict22)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8412\3903363147.py in <module>
# ----> 1 dfk = pd.DataFrame(dict22)
#
# c:\users\ajay kumar\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# c:\users\ajay kumar\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     463
#     464     return arrays_to_mgr(
# ...

# %% [markdown]
# ## hoe to overcome

# %% [markdown]
# **using tranpose we can over come it**

# %%
dfk = pd.DataFrame.from_dict(dict22,orient = 'index')

# %%
dfk # and then transpose it
# Out:
#           0   1     2    3     4     5     6
# column1   1   2     3    4     5   6.0   7.0
# column2   2  33   434  465    87  55.0  77.0
# column3  hi  my  name   is  ajay   NaN   NaN

# %%
dfk =dfk.transpose()

# %%
dfk
# Out:
#   column1 column2 column3
# 0       1       2      hi
# 1       2      33      my
# 2       3     434    name
# 3       4     465      is
# 4       5      87    ajay
# 5     6.0    55.0     NaN
# 6     7.0    77.0     NaN

# %% [markdown]
# ## another way

# %%
dfs = pd.DataFrame(dict([(key,pd.series(value)) for key,value in dict22.items() ]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8412\2674174631.py in <module>
# ----> 1 dfs = pd.DataFrame(dict([(key,pd.series(value)) for key,value in dict22.items() ]))
#
# ~\AppData\Local\Temp\ipykernel_8412\2674174631.py in <listcomp>(.0)
# ----> 1 dfs = pd.DataFrame(dict([(key,pd.series(value)) for key,value in dict22.items() ]))
#
# c:\users\ajay kumar\appdata\local\programs\python\python37\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'series'

# %% [markdown]
# ## keep the all the data of column no 2 in to a new column

# %%
dfk['column4'] = dfk['column2']*2

# %%
dfk
# Out:
#   column1 column2 column3 column4
# 0       1       2      hi       4
# 1       2      33      my      66
# 2       3     434    name     868
# 3       4     465      is     930
# 4       5      87    ajay     174
# 5     6.0    55.0     NaN   110.0
# 6     7.0    77.0     NaN   154.0

# %%
# create a new column with log of column 2
import numpy as np
dfk['column5'] = np.log(dfk['column2'])# my jupyrer has not updated thats why it gives error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'int' object has no attribute 'log'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8412\2362512208.py in <module>
#       1 # create a new column with log of column 2
#       2 import numpy as np
# ----> 3 dfk['column5'] = np.log(dfk[['column2']])# my jupyrer has not updated thats why it gives error
#
# c:\users\ajay kumar\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in __array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2030         self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2031     ):
# -> 2032         return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#    2033
# ...

# %%
np.log(5)
# Out:
# 1.6094379124341003

# %% [markdown]
# ## when a coulmn 2 element grater then 70 then will fill in new column

# %%
def test(x):
    if x > 70:
        return x

# %%
dfk['column5'] = dfk['column2'].apply(test) # apply is work on only series
dfk
# Out:
#   column1 column2 column3 column4  column5
# 0       1       2      hi       4      NaN
# 1       2      33      my      66      NaN
# 2       3     434    name     868    434.0
# 3       4     465      is     930    465.0
# 4       5      87    ajay     174     87.0
# 5     6.0    55.0     NaN   110.0      NaN
# 6     7.0    77.0     NaN   154.0     77.0

# %%
# stor lenth of colum2 in new column
dfk['column7'] = dfk['column2'].apply(len)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8412\479458517.py in <module>
#       1 # stor lenth of colum2 in new column
# ----> 2 dfk['column7'] = dfk['column2'].apply(len)
#
# c:\users\ajay kumar\appdata\local\programs\python\python37\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# c:\users\ajay kumar\appdata\local\programs\python\python37\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ...

# %%
dfk.dtypes
# Out:
# column1     object
# column2     object
# column3     object
# column4     object
# column5    float64
# dtype: object

# %% [markdown]
# **the above log and this one gives error because column3 is a object type first convert into int**

# %%
dfk['column2'] = dfk['column2'].astype(int)

# %%
dfk.dtypes
# Out:
# column1     object
# column2      int32
# column3     object
# column4     object
# column5    float64
# dtype: object

# %%
# logerthm
dfk['column6'] = np.log(dfk['column2'])

# %%
dfk
# Out:
#   column1  column2 column3 column4  column5   column6
# 0       1        2      hi       4      NaN  0.693147
# 1       2       33      my      66      NaN  3.496508
# 2       3      434    name     868    434.0  6.073045
# 3       4      465      is     930    465.0  6.142037
# 4       5       87    ajay     174     87.0  4.465908
# 5     6.0       55     NaN   110.0      NaN  4.007333
# 6     7.0       77     NaN   154.0     77.0  4.343805

# %%
#store lenth of colum2 in new column
dfk["column7"]= dfk['column3'].apply(len)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8412\3798552621.py in <module>
#       1 #store lenth of colum2 in new column
# ----> 2 dfk["column7"]= dfk['column3'].apply(len)
#
# c:\users\ajay kumar\appdata\local\programs\python\python37\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# c:\users\ajay kumar\appdata\local\programs\python\python37\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ...

# %%
dfk.dtypes
# Out:
# column1     object
# column2      int32
# column3     object
# column4     object
# column5    float64
# column6    float64
# dtype: object

# %%
dfk['column2'] = dfk['column2'].astype(str)

# %%
dfk.dtypes
# Out:
# column1     object
# column2     object
# column3     object
# column4     object
# column5    float64
# column6    float64
# dtype: object

# %%
dfk["column7"]= dfk['column3'].apply(len)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8412\3707116999.py in <module>
# ----> 1 dfk["column7"]= dfk['column3'].apply(len)
#
# c:\users\ajay kumar\appdata\local\programs\python\python37\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# c:\users\ajay kumar\appdata\local\programs\python\python37\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# c:\users\ajay kumar\appdata\local\programs\python\python37\lib\site-packages\pandas\core\apply.py in apply_standard(self)
# ...
