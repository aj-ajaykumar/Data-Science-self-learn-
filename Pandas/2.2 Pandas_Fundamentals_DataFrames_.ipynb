# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # DataFrame

# %% [markdown]
# DataFrame is a 2-dimensional labeled data structure with columns of potentially different types. You can think of it like a spreadsheet or SQL table, or a dict of Series objects. It is generally the most commonly used pandas object.

# %% [markdown]
# **from dict**

# %%
# along with the data we can also pass index columns labels if we want (optional)
d = {
    "one": pd.Series([1.0, 2.0, 3.0], index=["a", "b", "c"]),
    "two": pd.Series([1.0, 2.0, 3.0, 4.0], index=["a", "b", "c", "d"]),
}

# %%
df = pd.DataFrame(d)
df
# Out:
#    one  two
# a  1.0  1.0
# b  2.0  2.0
# c  3.0  3.0
# d  NaN  4.0

# %%
pd.DataFrame(d,index=['z','a','b','c']) # in the above dict there is no index z so it gives null values
# Out:
#    one  two
# z  NaN  NaN
# a  1.0  1.0
# b  2.0  2.0
# c  3.0  3.0

# %%
# insted of you want to chage the index
df.index = ['z','y','x','v']
df
# Out:
#    one  two
# z  1.0  1.0
# y  2.0  2.0
# x  3.0  3.0
# v  NaN  4.0

# %%
# changing columnas
df.columns=['ajay','Gnani']
df
# Out:
#    ajay  Gnani
# z   1.0    1.0
# y   2.0    2.0
# x   3.0    3.0
# v   NaN    4.0

# %%
df.index
# Out:
# Index(['z', 'y', 'x', 'v'], dtype='object')

# %%
df.values # it give nD array
# Out:
# array([[ 1.,  1.],
#        [ 2.,  2.],
#        [ 3.,  3.],
#        [nan,  4.]])

# %% [markdown]
# **From dict of ndarrays / lists**

# %%
d = {"one": [1.0, 2.0, 3.0, 4.0], "two": [4.0, 3.0, 2.0, 1.0]}

# %%
pd.DataFrame(d)
# Out:
#    one  two
# 0  1.0  4.0
# 1  2.0  3.0
# 2  3.0  2.0
# 3  4.0  1.0

# %%
# here there is no index so here we can directly use the index in data frame
df2 = pd.DataFrame(d,index=['a','b','c','d']) # here we didn't get null values
df2
# Out:
#    one  two
# a  1.0  4.0
# b  2.0  3.0
# c  3.0  2.0
# d  4.0  1.0

# %%
df
# Out:
#    ajay  Gnani
# z   1.0    1.0
# y   2.0    2.0
# x   3.0    3.0
# v   NaN    4.0

# %%
df['ajay']
# Out:
# z    1.0
# y    2.0
# x    3.0
# v    NaN
# Name: ajay, dtype: float64

# %%
df2['newcol'] = df['ajay'] # if its diffrent indexes the values will be null
df2
# Out:
#    one  two  newcol
# a  1.0  4.0     NaN
# b  2.0  3.0     NaN
# c  3.0  2.0     NaN
# d  4.0  1.0     NaN

# %%
# we can also add any column as index
df2['newcol'] = np.arange(4)
df2
# Out:
#    one  two  newcol
# a  1.0  4.0       0
# b  2.0  3.0       1
# c  3.0  2.0       2
# d  4.0  1.0       3

# %%
df2['newcol'] = df2['one']
df2
# Out:
#    one  two  newcol
# a  1.0  4.0     1.0
# b  2.0  3.0     2.0
# c  3.0  2.0     3.0
# d  4.0  1.0     4.0

# %%
# setting index name
df2.set_index('newcol',inplace=True)
df2
# Out:
#         one  two
# newcol
# 1.0     1.0  4.0
# 2.0     2.0  3.0
# 3.0     3.0  2.0
# 4.0     4.0  1.0

# %% [markdown]
# ### Column selection, addition, deletion

# %%
df
# Out:
#    ajay  Gnani
# z   1.0    1.0
# y   2.0    2.0
# x   3.0    3.0
# v   NaN    4.0

# %%
df2
# Out:
#         one  two
# newcol
# 1.0     1.0  4.0
# 2.0     2.0  3.0
# 3.0     3.0  2.0
# 4.0     4.0  1.0

# %%
df['ajay'] # selection
# Out:
# z    1.0
# y    2.0
# x    3.0
# v    NaN
# Name: ajay, dtype: float64

# %%
df['ajay'][2:]
# Out:
# x    3.0
# v    NaN
# Name: ajay, dtype: float64

# %%
# add column
df['newclo'] = df['ajay']**2
df
# Out:
#    ajay  Gnani  newclo
# z   1.0    1.0     1.0
# y   2.0    2.0     4.0
# x   3.0    3.0     9.0
# v   NaN    4.0     NaN

# %%
# delete
del df['newclo']
df
# Out:
#    ajay  Gnani
# z   1.0    1.0
# y   2.0    2.0
# x   3.0    3.0
# v   NaN    4.0

# %%
# add column
df['newclo'] = df['ajay']*df['Gnani']
df
# Out:
#    ajay  Gnani  newclo
# z   1.0    1.0     1.0
# y   2.0    2.0     4.0
# x   3.0    3.0     9.0
# v   NaN    4.0     NaN

# %%
# we can also use pop to remove
df.pop('newclo')
# Out:
# z    1.0
# y    4.0
# x    9.0
# v    NaN
# Name: newclo, dtype: float64

# %%
df
# Out:
#    ajay  Gnani
# z   1.0    1.0
# y   2.0    2.0
# x   3.0    3.0
# v   NaN    4.0

# %%
# we can also use inset method to add

df2.insert(2,'Name',np.linspace(1,2,num=4))
df2
# Out:
#         one  two      Name
# newcol
# 1.0     1.0  4.0  1.000000
# 2.0     2.0  3.0  1.333333
# 3.0     3.0  2.0  1.666667
# 4.0     4.0  1.0  2.000000

# %%
# use rename for remane the index
df2.rename_axis('Index', inplace=True)
df2
# Out:
#        one  two      Name
# Index
# 1.0    1.0  4.0  1.000000
# 2.0    2.0  3.0  1.333333
# 3.0    3.0  2.0  1.666667
# 4.0    4.0  1.0  2.000000

# %% [markdown]
# **Assigning new columns in method chains**

# %%
# assigne alway returns the copy of the data so you can assigne to any variable to use
df2.assign(newcol = lambda x: x['one']**x['two'])
# Out:
#        one  two      Name  newcol
# Index
# 1.0    1.0  4.0  1.000000     1.0
# 2.0    2.0  3.0  1.333333     8.0
# 3.0    3.0  2.0  1.666667     9.0
# 4.0    4.0  1.0  2.000000     4.0

# %%
df2
# Out:
#        one  two      Name
# Index
# 1.0    1.0  4.0  1.000000
# 2.0    2.0  3.0  1.333333
# 3.0    3.0  2.0  1.666667
# 4.0    4.0  1.0  2.000000

# %% [markdown]
# **Indexing / selection**

# %%
df2
# Out:
#        one  two      Name
# Index
# 1.0    1.0  4.0  1.000000
# 2.0    2.0  3.0  1.333333
# 3.0    3.0  2.0  1.666667
# 4.0    4.0  1.0  2.000000

# %%
df2['one']
# Out:
# Index
# 1.0    1.0
# 2.0    2.0
# 3.0    3.0
# 4.0    4.0
# Name: one, dtype: float64

# %%
df.iloc[1]
# Out:
# ajay     2.0
# Gnani    2.0
# Name: y, dtype: float64

# %% [markdown]
# **Arithmetic methods**

# %%
df2+df2
# Out:
#        one  two      Name
# Index
# 1.0    2.0  8.0  2.000000
# 2.0    4.0  6.0  2.666667
# 3.0    6.0  4.0  3.333333
# 4.0    8.0  2.0  4.000000

# %%
df2*25
# Out:
#          one    two       Name
# Index
# 1.0     25.0  100.0  25.000000
# 2.0     50.0   75.0  33.333333
# 3.0     75.0   50.0  41.666667
# 4.0    100.0   25.0  50.000000

# %%
# transpose
df2.T
# Out:
# Index  1.0       2.0       3.0  4.0
# one    1.0  2.000000  3.000000  4.0
# two    4.0  3.000000  2.000000  1.0
# Name   1.0  1.333333  1.666667  2.0

# %%
# indixing
df2[['one','Name']]
# Out:
#        one      Name
# Index
# 1.0    1.0  1.000000
# 2.0    2.0  1.333333
# 3.0    3.0  1.666667
# 4.0    4.0  2.000000

# %%
# Maths methods
df2.sum() # defaultly it sums columns
# Out:
# one     10.0
# two     10.0
# Name     6.0
# dtype: float64

# %%
df2.sum(axis=1) # for index or rows
# Out:
# Index
# 1.0    6.000000
# 2.0    6.333333
# 3.0    6.666667
# 4.0    7.000000
# dtype: float64

# %%
df2.min()
# Out:
# one     1.0
# two     1.0
# Name    1.0
# dtype: float64

# %%
df2.min(axis=1)
# Out:
# Index
# 1.0    1.000000
# 2.0    1.333333
# 3.0    1.666667
# 4.0    1.000000
# dtype: float64

# %%
df2.mean()
# Out:
# one     2.5
# two     2.5
# Name    1.5
# dtype: float64

# %%
df2.mean(axis=1)
# Out:
# Index
# 1.0    2.000000
# 2.0    2.111111
# 3.0    2.222222
# 4.0    2.333333
# dtype: float64

# %%
df2.var()
# Out:
# one     1.666667
# two     1.666667
# Name    0.185185
# dtype: float64

# %%
df2.std()
# Out:
# one     1.290994
# two     1.290994
# Name    0.430331
# dtype: float64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 1.0 to 4.0
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   one     4 non-null      float64
#  1   two     4 non-null      float64
#  2   Name    4 non-null      float64
# dtypes: float64(3)
# memory usage: 300.0 bytes

# %%
df2.describe()
# Out:
#             one       two      Name
# count  4.000000  4.000000  4.000000
# mean   2.500000  2.500000  1.500000
# std    1.290994  1.290994  0.430331
# min    1.000000  1.000000  1.000000
# 25%    1.750000  1.750000  1.250000
# 50%    2.500000  2.500000  1.500000
# 75%    3.250000  3.250000  1.750000
# max    4.000000  4.000000  2.000000
