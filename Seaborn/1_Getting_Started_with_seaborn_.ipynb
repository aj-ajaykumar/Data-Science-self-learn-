# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
# example
iris = sns.load_dataset('iris')
sns.lineplot(data=iris,x='sepal_length',y='sepal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# > **Using Seaborn with Matplotlib**

# %%
sns.lineplot(data=iris,x='sepal_length',y='sepal_width')
plt.title("seaboen lineplot",c='r',size='x-large')

plt.show()# no need when you write %matplotlib inline

# %%
plt.figure(figsize=(5,3))
sns.lineplot(data=iris,x='sepal_length',y='sepal_width')
plt.title("seaboen lineplot",c='r',size='x-large')
plt.show()# no need when you write %matplotlib inline

# %% [markdown]
# **Example 2: Setting the xlim and ylim**

# %%
plt.figure(figsize=(5,3))
sns.lineplot(data=iris,x='sepal_length',y='sepal_width')
plt.title("seaboen lineplot",c='r',size='x-large')
# setting xlimit
plt.xlim(5)
# setting y limit
plt.ylim(2.75)


plt.show()# no need when you write %matplotlib inline
# compare with above diagram

# %% [markdown]
#  >**Customizing Seaborn Plots**
#
#   **Using the dark theme**

# %%
sns.lineplot(data=iris,x='sepal_length',y='sepal_width')
plt.title("seaboen lineplot",c='r',size='x-large')

#changing the theme
sns.set_style('dark')

plt.show()# no need when you write %matplotlib inline

# %%
sns.lineplot(data=iris,x='sepal_length',y='sepal_width')
plt.title("seaboen lineplot",c='r',size='x-large')

#changing the theme
sns.set_style('darkgrid')

# %%
sns.lineplot(data=iris,x='sepal_length',y='sepal_width')
plt.title("seaboen lineplot",c='r',size='x-large')

#changing the theme
sns.set_style('whitegrid')

# %%
sns.lineplot(data=iris,x='sepal_length',y='sepal_width')
plt.title("seaboen lineplot",c='r',size='x-large')

#changing the theme
sns.set_style('ticks')

# %% [markdown]
# > **Removal of Spines**

# %%
sns.lineplot(data=iris,x='sepal_length',y='sepal_width')
plt.title("seaboen lineplot",c='r',size='x-large')

#changing the theme
sns.set_style('ticks')

sns.despine() # remove grid

# %% [markdown]
# > **Changing the figure Size**

# %%
#changing the figure size
plt.figure(figsize=(4,2.5))

sns.lineplot(data=iris,x='sepal_length',y='sepal_width')
plt.title("seaboen lineplot",c='r',size='x-large')

#changing the theme
sns.set_style('ticks')

sns.despine() # remove grid

# %% [markdown]
# > **Scaling the plots**
#
# It can be done using the set_context() method. It allows us to override default parameters. This affects things like the size of the labels, lines, and other elements of the plot, but not the overall style. The base context is “notebook”, and the other contexts are “paper”, “talk”, and “poster”. font_scale sets the font size.

# %%
#changing the figure size
plt.figure(figsize=(5,3.5))

sns.lineplot(data=iris,x='sepal_length',y='sepal_width')
plt.title("seaboen lineplot",c='r',size='x-large')

# Setting the scale of the plot
sns.set_context('paper')


sns.despine() # remove grid

# %%
#changing the figure size
plt.figure(figsize=(5,3.5))

sns.lineplot(data=iris,x='sepal_length',y='sepal_width')
plt.title("seaboen lineplot",c='r',size='x-large')

# Setting the scale of the plot
sns.set_context('talk')


sns.despine() # remove grid

# %%
#changing the figure size
plt.figure(figsize=(5,3.5))

sns.lineplot(data=iris,x='sepal_length',y='sepal_width')
plt.title("seaboen lineplot",c='r',size='x-large')

# Setting the scale of the plot
sns.set_context('poster')


sns.despine() # remove grid
#observe the above diagrams

# %% [markdown]
# > **Setting the Style Temporarily**
#
# axes_style() method is used to set the style temporarily. It is used along with the with statement.

# %%
plot = sns.lineplot(data=iris,x='sepal_length',y='sepal_width')

with sns.axes_style('darkgrid'):
  #adding subplots
  plt.subplot(211)
  plot

# another subplot
plt.subplot(212)
plot

plt.tight_layout()
# Out:
# <ipython-input-41-8cc70b962dae>:5: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(211)

# %%
plt.figure(figsize=(6,4))
def plot():
  sns.lineplot(data=iris,x='sepal_length',y='sepal_width')

with sns.axes_style('darkgrid'):
  #adding subplots
  plt.subplot(211)
  plot()

# another subplot
plt.subplot(212)
plot()


plt.tight_layout()

# %% [markdown]
# > **Color Palette**

# %%
# current colot palette
pallet= sns.color_palette()

# plots the color palette as a
# horizontal array
sns.palplot(pallet)

# %% [markdown]
# > **Diverging Color Palette**
#
# This type of color palette uses two different colors where each color depicts different points ranging from a common point in either direction. Consider a range of -10 to 10 so the value from -10 to 0 takes one color and values from 0 to 10 take another.

# %%
# current colot palette
palette= sns.color_palette('PiYG',11)

# diverging color palette
sns.palplot(palette)

# %% [markdown]
# In the above example, we have used an in-built diverging color palette which shows 11 different points of color. The color on the left shows pink color and color on the right shows green color.

# %% [markdown]
# > **Sequential Color Palette**
#
# A sequential palette is used where the distribution ranges from a lower value to a higher value. To do this add the character ‘s’ to the color passed in the color palette.

# %%
# current colot palette
palette = sns.color_palette('Greens',11)

# sequential color palette
sns.palplot(palette)

# %% [markdown]
# > **Setting the default Color Palette**
#
# set_palette() method is used to set the default color palette for all the plots. The arguments for both color_palette() and set_palette() is same. set_palette() changes the default matplotlib parameters.

# %%
# load dataset
iris =sns.load_dataset('iris')
def plot():
  sns.lineplot(x='sepal_length',y='sepal_width',data=iris)

# setting the default color palette
sns.set_palette('vlag')
plt.subplot(211)

# plotting with the color palette
# as vlag
plot()

# setting another default color palette
sns.set_palette('Accent')
plt.subplot(212)
plot()

plt.tight_layout()

# %% [markdown]
# # Multiple plots with Seaborn
#
# > **Using add_axes() method**

# %%
def graph():
  sns.lineplot(x='sepal_length',y='sepal_width',data=iris)

fig = plt.figure(figsize=(5,4))

# Creating first axes for the figure

ax1=fig.add_axes([0.1,0.1,0.8,0.8])
#plotting graph
graph()

# creating secod figure
ax2 = fig.add_axes([0.55,0.65,0.2,0.2])
graph()

# %% [markdown]
# > **Using subplot() method**

# %%
def graph():
  sns.lineplot(x='sepal_length',y='sepal_width',data=iris)


fig = plt.figure(figsize=(5,3))

plt.subplot(121)
graph()

plt.subplot(122)
sns.set_style('ticks')
graph()

plt.tight_layout()

# %% [markdown]
# > **Using subplot2grid() method**

# %%
def graph():
  sns.lineplot(x='sepal_length',y='sepal_width',data=iris)

# adding subplots
axes1 = plt.subplot2grid((7,1),(0,0))
graph()

axes1 = plt.subplot2grid((7,1),(2,0))
graph()

axes1 = plt.subplot2grid((7,1),(4,0))
graph()

# %%
def graph():
  sns.lineplot(x='sepal_length',y='sepal_width',data=iris)

# adding subplots
axes1 = plt.subplot2grid((7,1),(0,0),rowspan=2,colspan=1)
graph()

axes1 = plt.subplot2grid((7,1),(2,0),rowspan=2,colspan=1)
graph()

axes1 = plt.subplot2grid((7,1),(4,0),rowspan=2,colspan=1)
graph()

# %% [markdown]
# > **Using Seaborn**
#
# **Using FacetGrid() method**

# %%
plot = sns.FacetGrid(iris,col='species')
plot.map(plt.plot,'sepal_width')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plot = sns.FacetGrid(iris,col='species')
plot.map(plt.plot,'sepal_length')

# %% [markdown]
# > **Using PairGrid() method**

# %%
data= sns.load_dataset('flights')
data.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
plot = sns.PairGrid(data)
plot.map(plt.plot)

# %%
sns.set_palette('vlag')
plot = sns.PairGrid(data)
plot.map(plt.scatter)
# set palette

# %%
plot = sns.PairGrid(iris)
plot.map(plt.plot,marker='o',markeredgecolor='r')

# %%
plot = sns.PairGrid(iris)
plot.map(plt.scatter)

# %% [markdown]
#  # Creating Different Types of Plots

# %% [markdown]
# ## Relational Plots
#
# There are different types of Relational Plots

# %% [markdown]
# > **Relplot()**
#
# This function provides us the access to some other different axes-level functions which shows the relationships between two variables with semantic mappings of subsets. It is plotted using the relplot() method.

# %%
data = sns.load_dataset('iris')
sns.relplot(x='sepal_length',y='species',data=data)
plt.show()

# %% [markdown]
# > **Scatter Plot**

# %%
sns.scatterplot(x='sepal_length',y='sepal_width',data=data)
plt.title('scatter plot using seaborn',fontweight='bold',c='r')
plt.xlabel('sepal_length',c='g')
plt.ylabel('sepal_width',c='g')
# Out:
# Text(0, 0.5, 'sepal_width')

# %% [markdown]
# > **Line Plot**

# %%
sns.lineplot(x="sepal_length",y='species',data=data)
plt.title('line chart using seaborn',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'line chart using seaborn')

# %% [markdown]
# ## Categorical Plots
#
# Categorical Plots are used where we have to visualize relationship between two numerical values. A more specialized approach can be used if one of the main variable is categorical which means such variables that take on a fixed and limited number of possible values.

# %% [markdown]
# > **Bar Plot**

# %%
sns.barplot(x='sepal_length',y='species',data=data)
plt.title('Box plot using seaborn')
# Out:
# Text(0.5, 1.0, 'Box plot using seaborn')

# %%
sns.barplot(x='species',y='sepal_length',data=data,)
plt.title('Box plot using seaborn')
# Out:
# Text(0.5, 1.0, 'Box plot using seaborn')

# %% [markdown]
# > **Count Plot**
#
#
# A countplot basically counts the categories and returns a count of their occurrences. It is one of the most simple plots provided by the seaborn library. It can be created using the countplot() method.

# %%
sns.countplot(x='species',data=data )
plt.title('count plot in seaborn')
# Out:
# Text(0.5, 1.0, 'count plot in seaborn')

# %% [markdown]
# > **Box Plot**

# %%
#boxplot
plt.figure(figsize=(4,4))
sns.boxplot(x='species',y='sepal_length',data = data)
plt.title('Box plot in seabon')
# Out:
# Text(0.5, 1.0, 'Box plot in seabon')

# %% [markdown]
# > **Violinplot**
#
# It is similar to the boxplot except that it provides a higher, more advanced visualization and uses the kernel density estimation to give a better description about the data distribution. It is created using the violinplot() method.

# %%
sns.violinplot(x='species',y='sepal_width',data=data)
plt.title('violinplot in seaborn')
# Out:
# Text(0.5, 1.0, 'violinplot in seaborn')

# %%
sns.violinplot(x='species',y='sepal_length',data=data)
plt.title('violinplot in seaborn')
# Out:
# Text(0.5, 1.0, 'violinplot in seaborn')

# %% [markdown]
# > **Stripplot**
#
# It basically creates a scatter plot based on the category. It is created using the stripplot() method

# %%
sns.stripplot(x='species',y='sepal_width',data = data)
plt.title('striplot in seaborn')
# Out:
# Text(0.5, 1.0, 'striplot in seaborn')

# %% [markdown]
# > **Swarmplot**
#
#
# Swarmplot is very similar to the stripplot except the fact that the points are adjusted so that they do not overlap.Some people also like combining the idea of a violin plot and a stripplot to form this plot. One drawback to using swarmplot is that sometimes they dont scale well to really large numbers and takes a lot of computation to arrange them. So in case we want to visualize a swarmplot properly we can plot it on top of a violinplot. It is plotted using the swarmplot() method.

# %%
sns.swarmplot(x='species',y='sepal_width',data=data)
plt.title('swarmplot in seaborn')
# Out:
# Text(0.5, 1.0, 'swarmplot in seaborn')

# %% [markdown]
# > **Factorplot**
#
#
# Factorplot is the most general of all these plots and provides a parameter called kind to choose the kind of plot we want thus saving us from the trouble of writing these plots separately. The kind parameter can be bar, violin, swarm etc. It is plotted using the factorplot() method.

# %%
sns.factorplot(x='species',y='sepal_width',data=data)
plt.title('Factorplot in seaborn')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-853d4d3accd4> in <cell line: 1>()
# ----> 1 sns.factorplot(x='species',y='sepal_width',data=data)
#       2 plt.title('Factorplot in seaborn')
#
# AttributeError: module 'seaborn' has no attribute 'factorplot'

# %% [markdown]
#  >**Distribution Plots**
#
#  Histogram

# %%
data = sns.load_dataset('iris')
sns.histplot(x='species',y='sepal_width',data=data)
plt.title('Histogram in seaboen')
# Out:
# Text(0.5, 1.0, 'Histogram in seaboen')

# %% [markdown]
# > **Distplot**
#
#
# Distplot is used basically for univariant set of observations and visualizes it through a histogram i.e. only one observation and hence we choose one particular column of the dataset. It is potted using the distplot() method

# %%
sns.distplot(x='sepal_width',data=data)
plt.title('distplot in seaborn')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-f80d737b5a23> in <cell line: 1>()
# ----> 1 sns.distplot(x='sepal_width',data=data)
#       2 plt.title('distplot in seaborn')
#
# TypeError: distplot() got an unexpected keyword argument 'data'

# %%
sns.distplot(data['sepal_width'])
plt.title('distplot in seaborn')
# Out:
# <ipython-input-10-a07b5350abe6>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['sepal_width'])
# Text(0.5, 1.0, 'distplot in seaborn')

# %%
# using displot
sns.displot(x='sepal_width',data=data,kde=True)
plt.title('distplot in seaborn')
# Out:
# Text(0.5, 1.0, 'distplot in seaborn')

# %% [markdown]
# > **Jointplot**
#
# Jointplot is used to draw a plot of two variables with bivariate and univariate graphs. It basically combines two different plots. It is plotted using the jointplot() method.

# %%
plt.figure(figsize=(2,2))
sns.jointplot(x='species',y='sepal_length',data=data)
plt.title('Jointplot in seaborn')
plt.tight_layout()

# %% [markdown]
#  >**Pairplot**
#
#
# Pairplot represents pairwise relation across the entire dataframe and supports an additional argument called hue for categorical separation. What it does basically is create a jointplot between every possible numerical column and takes a while if the dataframe is really huge. It is plotted using the pairplot() method.

# %%
sns.pairplot(data=data,hue='species')

# %% [markdown]
# > **Rugplot**
#
#
# Rugplot plots datapoints in an array as sticks on an axis.Just like a distplot it takes a single column. Instead of drawing a histogram it creates dashes all across the plot. If you compare it with the joinplot you can see that what a jointplot does is that it counts the dashes and shows it as bins. It is plotted using the rugplot() method.

# %%
sns.rugplot(data=data)
# Out:
# <Axes: >

# %% [markdown]
# > **KDE Plot**
#
# KDE Plot described as Kernel Density Estimate is used for visualizing the Probability Density of a continuous variable. It depicts the probability density at different values in a continuous variable. We can also plot a single graph for multiple samples which helps in more efficient data visualization.

# %%
sns.kdeplot(x='sepal_length',y='sepal_width',data=data)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# ## Regression Plots
# The regression plots are primarily intended to add a visual guide that helps to emphasize patterns in a dataset during exploratory data analyses. Regression plots as the name suggests creates a regression line between two parameters and helps to visualize their linear relationships.

# %% [markdown]
# there are two main functions that are used to draw linear regression models. These functions are lmplot(), and regplot(), are closely related to each other. They even share their core functionality.
#
#
#
# > **lmplot**
#
# lmplot() method can be understood as a function that basically creates a linear model plot. It creates a scatter plot with a linear fit on top of it.

# %%
sns.lmplot(x='sepal_length',y="petal_length",data=data)
plt.title('Linear Model using seaborn')
# Out:
# Text(0.5, 1.0, 'Linear Model using seaborn')

# %%
#tips data
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)

# %% [markdown]
# > **Regplot**
#
# regplot() method is also similar to lmplot which creates linear regression mode

# %%
sns.regplot(x='sepal_length',y='petal_length',data=data)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.regplot(x='total_bill',y='tip',data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# Note: The difference between both the function is that regplot accepts the x, y variables in different format including NumPy arrays, Pandas objects, whereas, the lmplot only accepts the value as strings.

# %% [markdown]
# ## Matrix Plots
#
# A matrix plot means plotting matrix data where color coded diagrams shows rows data, column data and values. It can shown using the heatmap and clustermap.

# %% [markdown]
# > **Heatmap**
#
# Heatmap is defined as a graphical representation of data using colors to visualize the value of the matrix. In this, to represent more common values or higher activities brighter colors basically reddish colors are used and to represent less common or activity values, darker colors are preferred. it can be plotted using the heatmap() function.

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# correlation between the different parameters

tc = tips.corr()
sns.heatmap(tips)
plt.title('Heat map using seaborn')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-74b0cad721a4> in <cell line: 3>()
#       1 # correlation between the different parameters
#       2
# ----> 3 tc = tips.corr()
#       4 sns.heatmap(tips)
#       5 plt.title('Heat map using seaborn')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839         if result.dtype is not dtype:
#    1840             result = np.array(result, dtype=dtype, copy=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in as_array(self, dtype, copy, na_value)
#    1730                 arr.flags.writeable = False
#    1731         else:
# -> 1732             arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733             # The underlying data was copied within _interleave, so no need
#    1734             # to further copy if copy=True or setting na_value
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in _interleave(self, dtype, na_value)
#    1786                 # error: Item "ndarray" of "Union[ndarray, ExtensionArray]" has no
#    1787                 # attribute "to_numpy"
# -> 1788                 arr = blk.values.to_numpy(  # type: ignore[union-attr]
#    1789                     dtype=dtype,
#    1790                     na_value=na_value,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arrays/base.py in to_numpy(self, dtype, copy, na_value)
#     483         numpy.ndarray
#     484         """
# --> 485         result = np.asarray(self, dtype=dtype)
#     486         if copy or na_value is not lib.no_default:
#     487             result = result.copy()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arrays/_mixins.py in method(self, *args, **kwargs)
#      84     def method(self, *args, **kwargs):
#      85         if self.ndim == 1:
# ---> 86             return meth(self, *args, **kwargs)
#      87
#      88         flags = self._ndarray.flags
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arrays/categorical.py in __array__(self, dtype)
#    1342         ret = take_nd(self.categories._values, self._codes)
#    1343         if dtype and not is_dtype_equal(dtype, self.categories.dtype):
# -> 1344             return np.asarray(ret, dtype)
#    1345         # When we're a Categorical[ExtensionArray], like Interval,
#    1346         # we need to ensure __array__ gets all the way to an
#
# ValueError: could not convert string to float: 'No'

# %%
tipdata = data[['total_bill','tip','size']]

# %%
tc = tipdata.corr()
sns.heatmap(tc)
# Out:
# <Axes: >

# %%
sns.heatmap(tipdata)
# Out:
# <Axes: >

# %%
tc=tipdata.corr()
sns.heatmap(tc,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# > **Clustermap**
#
# The clustermap() function of seaborn plots the hierarchically-clustered heatmap of the given matrix dataset. Clustering simply means grouping data based on relationship among the variables in the data.

# %%
#fig, ax = plt.subplots(figsize=(3,3))
correlation = tipdata.corr()
sns.clustermap(correlation)
plt.figure(figsize =(3, 3))

# %% [markdown]
# **colors**

# %%
# adding colors
data = sns.load_dataset('iris')
sns.barplot(x='species',y='sepal_width',data = data,palette='deep')
# Out:
# <ipython-input-97-463b2433c758>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='species',y='sepal_width',data = data,palette='deep')
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
data = sns.load_dataset('iris')
sns.barplot(x='species',y='sepal_width',data = data,palette='bright')
# Out:
# <ipython-input-101-3343ec0ebcae>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='species',y='sepal_width',data = data,palette='bright')
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
data = sns.load_dataset('iris')
sns.barplot(x='species',y='sepal_width',data = data,palette='pastel')
# Out:
# <ipython-input-102-de64774dc52f>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='species',y='sepal_width',data = data,palette='pastel')
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
data = sns.load_dataset('iris')
sns.barplot(x='species',y='sepal_width',data = data,palette='colorblind')
# Out:
# <ipython-input-103-202e239ed245>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='species',y='sepal_width',data = data,palette='colorblind')
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
data = sns.load_dataset('iris')
sns.barplot(x='species',y='sepal_width',data = data,palette='colorblind')
sns.set_style('ticks') # setting style
# Out:
# <ipython-input-105-18f483cb4c26>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='species',y='sepal_width',data = data,palette='colorblind')

# %% [markdown]
# also we use set_context to style the plot

# %%
data = sns.load_dataset('iris')
sns.barplot(x='species',y='sepal_width',data = data,palette='colorblind')
sns.set_style('ticks')
sns.set_context('paper')
# Out:
# <ipython-input-106-78f2c70b55d7>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='species',y='sepal_width',data = data,palette='colorblind')

# %%
data = sns.load_dataset('iris')
sns.barplot(x='species',y='sepal_width',data = data,palette='colorblind')
sns.set_style('ticks')
sns.set_context('talk',font_scale=1) # context types
# Out:
# <ipython-input-113-ae67654b5e87>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='species',y='sepal_width',data = data,palette='colorblind')

# %%
data = sns.load_dataset('iris')
sns.barplot(x='species',y='sepal_width',data = data,palette='colorblind')
sns.set_style('ticks')
sns.set_context('notebook',font_scale=2)
# Out:
# <ipython-input-108-509e7a20c19e>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='species',y='sepal_width',data = data,palette='colorblind')

# %% [markdown]
#  > **seaborn.FacetGrid() method**
#
#  which is used to create multiple plots

# %%
df = sns.load_dataset('tips')
graph = sns.FacetGrid(df,col='sex',hue = 'day')

graph.map(plt.scatter,'total_bill','tip',edgecolor='w').add_legend()

# %%
graph = sns.FacetGrid(df,col='time',row='smoker')

graph.map(plt.hist,'total_bill',bins=15,color='orange')

# %%
# we can also use seaborn plots
graph = sns.FacetGrid(df,col='time',row='smoker')
#with seaborn
graph.map(sns.histplot,'total_bill',bins = 15,kde=True,palette='deep',edgecolor='red')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(*plot_args, **plot_kwargs)

# %%
graph = sns.FacetGrid(df,col='time',row='smoker',palette='deep')

graph.map(sns.regplot,'total_bill','tip').add_legend()

# %%
# for changing colors

graph = sns.FacetGrid(df,col='time',row='smoker',palette='deep')

graph.map(sns.regplot,'total_bill','tip',scatter_kws={'color':'cyan'},line_kws={'color':'orange'}).add_legend()

# %%
graph = sns.FacetGrid(df,col='time',hue='smoker',palette='deep')

graph.map(sns.regplot,'total_bill','tip').add_legend()

# %% [markdown]
# > **seaborn.PairGrid() method**

# %%
graph = sns.PairGrid(df,hue='day')
# type of graph for diagonal
graph.map_diag(sns.histplot)
# type of graph for non-diagonal
graph.map_offdiag(sns.scatterplot)
graph.add_legend()

# %%
graph = sns.PairGrid(df,hue='day')
# type of graph for diagonal
graph.map_diag(sns.histplot,kde=True)
# type of graph for non-diagonal
graph.map_offdiag(sns.scatterplot)
graph.add_legend()

# %%
graph = sns.PairGrid(df)
graph.map_lower(sns.scatterplot)
graph.map_diag(sns.kdeplot,lw=2)
graph.map_upper(sns.kdeplot)
