# %% [markdown]
# ## **Introduction Probability**

# %% [markdown]
# Consider a random experiment with a finite sample space S.
#
# Assignment of a real number to each event of the sample space is known as a probability measure that depicts the likelihood of occurrence of the Event.
#
# Suppose a random experiment is repeated n times.
#
# If the Event A occurs n times, then the probability of the Event A is given as P(A) = n(A)/n
#
# where P(A) is a real number where n > 0
#
# n(A) is the number of times event A has occurred.

# %% [markdown]
# ## **Axioms:**
#
# <center>
#
# For a Finite Sample Space S, Consider an Event A.
#
# The probability P(A) which is a real number assigned to the Event A must follow the below axioms :
#
# P(A) >= 0
#
# P(S) = 1
#
# If event A and Event B are mutually exclusive then,
# P (A U B) = P(A) + P(B) , (A ∩ B ) = ∅
#
# <center>

# %% [markdown]
# ## **Elementry Properties**
#
#
#
# Using the axioms the following properties of probability can be obtained:
#
# * P ( A ) = 1 - P (A)
#
# * P (∅) = 0
#
# * P(A) < P(B)  if A ⊂ B
#
# * P(A) <= 1
#
# * P(A U B) = P(A) + P(B) - P(A ∩ B)

# %% [markdown]
# ## **Computing Probability**
#
# > **Scenario:**
#
# Let's try to understand computing probability by taking an example of a box having 3 red balls, 2 blue balls and 1 green ball. Let's take one ball randomly. What would be the probability that the selected ball will be a blue ball?
#
# > **Solution:**
#
# Total possible outcomes = Total number of balls = 3+2+1=6
#
# Total ways a blue ball can be drawn = 2C1 = 2
#
# The probability of drawing a blue ball =
#
# <center>
#
# ![image.png](data:image/png;base64,...)
#
#
# <center>

# %% [markdown]
# > **Scenario:** Let's try to compute the probability of a fair die which is rolled 12 times. We observed that the number 4 turned up 5 times.
#
# Now, what would be the probability of the number 4 being rolled for the given experiment?
#
# > **Solution:**
#
# Total possible outcomes = 12 (Total number of times the die is rolled)
#
# Number of times ‘4’ appeared = 5
#
# The probability of number 4 being rolled =
#
# <center>
#
# ![image.png](data:image/png;base64,...)
#
# <center>

# %% [markdown]
# # **Conditional Probability**

# %% [markdown]
# **Conditional Probability** is used to determine the likelihood of an event when a partial information about the event is known.
#
# Examples:
#
# 1. In an experiment of rolling a die, the die is rolled twice. It was observed that the sum of the outcomes was even. What is the chance that the first outcome was 2?
#
# 2. In an experiment where a word is to be guessed. It was observed that the first letter of the word is ‘A’. What is the chance that the second letter is ‘b’?
#
# **Observation:** In the above examples, what we have available is the partial information about the outcome of an experiment. In example 1, the sum is given as even and in example 2, the first letter is given.

# %% [markdown]
# **Scenario:** In an experiment of rolling a die, what is the likelihood that the outcome is 2, given that the outcome is even?
#
# Consider a fair roll of a die i.e. all the outcomes of an experiment have an equal probability of occurrence = 1/6.
#
# <center>
#
# ![image.png](data:image/png;base64,...)
#
# <center>

# %% [markdown]
# > **From the previous example :**
#
# It is given that the outcome is even (Event B)– so possible values are 2,4,6. Therefore the total number of elements for Event B =3
#
# Event A can take any ONE value amongst 2,4,6. Therefore the total number of elements for Event A=1 So,
#
# <center>
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
#
# <center>
#
#
#
#
# Conditional probability is undefined if the conditioning event has zero probability i.e.  P(B)>0 is mandatory.

# %% [markdown]
# ## **Extending Conditional Probability**

# %% [markdown]
# Consider a retailer procures bread from 3 different suppliers 40% from S1, 35% from S2 and 25% from S3.
#
# It was found that 5% of bread supplied by S1, 2% supplied by S2 and 3% supplied by S3 are defective.
#
# No other supplier is supplying bread - exhaustive
#
# All suppliers are different – mutually exclusive
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > **To visualize**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * If we have an event let's say D, in which a customer picks a defective bread, what would be the probability of finding a defective bread?
#
# <center>
#
# P(D) = P(S1)P(D|S1)+P(S2)P(D|S2)+P(S3)P(D|S3)
#
# =(0.4×0.05)+(0.35×0.02)+(0.25×0.03)
#
# = 0.0345
#
# </center>
#
# In general for ‘n’ suppliers
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * How would we calculate the probability of the event where a selected defective bread is supplied by S2?
#
# <center>
#
# ![image.png](data:image/png;base64,...)
#
# </center>
#
# * In general, the probability that the defective bread supplied by supplier ‘k’ (among ‘n’ suppliers, 1≤k≤n) is
#
# <center>
#
# ![image.png](data:image/png;base64,...)
#
# </center>

# %% [markdown]
# **For Event A and Event B,**
#
# P (A ∩ B) = P(A)P(B|A) if P(A) ≠ 0
#
# P (A ∩ B) = P(B)P(A|B) if P(B) ≠ 0
#
# Bayes Theorem gives a relation between P(A|B) as
#
# <center>
#
# ![image.png](data:image/png;base64,...)
#
# </center>
