# %% [markdown]
# > **Introduction:**
#
# Let's understand something in the context of a random experiment. For random experiments, it might be required for us to count the possible number of outcomes.
#
# Now in order to count the possible number of outcomes, the simplest way to do that is to list all the possible outcomes of the given experiment.
#
# However, for certain applied problems if the outcomes are too many in number it is not possible to list out all the possible outcomes.
#
# For applied problems where the count of possible outcomes is essential and listing out all possible outcomes is not feasible we adopt sophisticated counting techniques.
#
# Some of these commonly used techniques are:
#
# * Product Rule
#
# * Sum Rule
#
# * Combinations
#
# * Permutations

# %% [markdown]
# ### **PRODUCT RULE:**

# %% [markdown]
# > **Scenario:** Consider stocks in the banking and automotive sectors.
#
# Stocks(Bank) = {Bank1, Bank2, Bank3}
#
# Stocks(Auto) = {Auto1, Auto2, Auto3, Auto4}
#
# Let's take an example where an investor is interested in investing in both banking AND automotive sectors. The investor decides to go for one from each sector. How many different ways are there in which he can invest?
#
# ![image.png](data:image/png;base64,...)
#
#
# Total possible ways to make this investment is  3 × 4 = 12  i.e. (No. of bank stocks) × (No. of automotive stocks)

# %% [markdown]
# ## **SUM RULE:**

# %% [markdown]
# > **Scenario:**  Consider stocks in the banking and automotive sectors.
#
# Stocks(Bank) = {Bank1, Bank2, Bank3}
#
# Stocks(Auto) = {Auto1, Auto2, Auto3, Auto4}
#
# If an investor likes to invest in either banking OR automotive stocks then how many total possible ways can he invest?
#
# Total possibilities to invest in either banking OR automotive stock is 3 + 4 =7
#
# The investor has to make a single choice from all the stocks added together,
#
# i.e. (Total number of Banking stocks + Total number of Automotive stocks)

# %% [markdown]
# ## **COMBINATION:**

# %% [markdown]
# > **Scenario:** Consider stocks of the automotive sector.
#
# Stocks(Auto) = {Auto1, Auto2, Auto3, Auto4} If an Investor wants to invest in 2 automotive stocks, in how many possible ways can he invest?
# <center>Total possible ways to invest are:
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
#  n - Total number of automotive stocks.
#
#  r - Number of stocks the investor wants to invest in.
#
# <center>
#
# The combination can be computed using the command comb(n,r) in Python (from scipy library) as shown below

# %%
# python code
from scipy.special import comb
comb(4, 2, exact=True) #If exact is False, then floating point precision is used, otherwise exact long integer is computed.

# %% [markdown]
# > **Scenario:** Now let's understand by another example. Let's suppose we have an urn which contains 3 red balls and 4 green balls. We are interested in calculating the number of ways in which we can select 2 red balls and 2 green balls.
#
# <center>Note: We cannot replace the balls i.e. Replacement not allowed.
#
# Solution:
#
# Ways to choose 2 red balls from 3 red balls is
#
# ![image.png](data:image/png;base64,...)
#
#
# Ways to choose 2 green balls from 4 green balls is
#
# ![image.png](data:image/png;base64,...)
#
# <center>
#
#
#
# So total ways to choose 2 red and 2 green balls = 3C2 x 4C2 = 3 x 6 = 18

# %% [markdown]
# > **Scenario:** An urn contains 3 identical red balls and 4 identical green balls. In how many ways can we choose 2 red balls and 2 green balls.
#
# Note: Replacement allowed.
#
# > **Solution:**
#
# Ways to choose the 1st red ball from 3 red balls is
#
# ![image.png](data:image/png;base64,...)
#
# Ways to choose the 2nd red ball from 3 red balls is
#
# ![image.png](data:image/png;base64,...)
#
#
# Ways to choose the 1st green ball from 4 green balls is
#
# ![image.png](data:image/png;base64,...)
#
# Ways to choose the 2nd red ball from 4 green balls is
#
# ![image.png](data:image/png;base64,...)
#
#
# So total ways to choose 2 red and 2 green balls with replacement is = 3C1 x 3C1 x 4C1 x 4C1 = 3 x 3 x 4 x 4 = 144

# %% [markdown]
# ## **PERMUTATION:**

# %% [markdown]
# > **Scenario:** Let's understand permutations by considering an example of an investor who wants to invest in 2 automotive stocks Auto1 and Auto2.
#
# ![image.png](data:image/png;base64,...)
#
#
# Case 1: Investor invests in Auto1 stock at t1 and Auto2 stock at t2 – Total cost incurred = 35+21 = $56
#
# Case 2: Investor invests in Auto2 stock at t1 and Auto1 stock at t2 – Total cost incurred= 22+30 = $52
#
# Observation: Case 2 is profitable. So investing in Auto2 first and then in Auto1 stock would be preferred against Auto1 first and Auto2 later. So the order is important.

# %% [markdown]
# * **Permutation deals with Order/Sequence.**
#
# > **Scenario:** Consider stocks of the banking sector.
#
# Stock(Bank) = {Bank1, Bank2, Bank3}
#
# If an investor wants to invest in 2 banking stocks out of the available 3 banking stocks, how many ways can he invest if ordered one at a time?
#
# ![image.png](data:image/png;base64,...)
#
#
# Total possible ways to make this investment is =
#
# <CENTER>
#
# ![image.png](data:image/png;base64,...)
#
# n- Total number of stocks.
#
# r – Number of stocks to be invested.
#
# <CENTER>
#
# The permutation can be computed using the product of factorial(r) and command comb(n,r) in Python (from scipy library) as shown below.

# %%
#To find no. of permutations
import math;
comb(3, 2, exact=True)* math.factorial(2)

# %% [markdown]
# > **Scenario:** Consider 3 distinct letters A, B and C. How many ways can these letters be arranged to have a 3 letter word.
#
# Note: Repetition not allowed.
#
# Solution:
#
#
# ![image.png](data:image/png;base64,...)
#
#
# In order to have a 3 letter word, 3 distinct letters can be arranged in 3P3=6 ways.

# %% [markdown]
# > **Scenario:** Consider 3 distinct letters A,B and C. How many ways can 2 of these letters be arranged to have a 2 letter word.
#
# Note: Repetition (Replacement) allowed
#
# Solution:
#
# ![image.png](data:image/png;base64,...)
#
#
#
# 3 choices for each of the 2 selections are available when repetition is allowed and the order is significant.
#
# So, total ways for this arrangement is 32  i.e.  #Choices#Selections

# %% [markdown]
# > **Scenario:** Consider 3 letters A, A and B. How many distinct ways can these letters be arranged to have a 3 letter word.
#
# Note: Letter A is repeated twice.
#
# Solution:
#
# ![image.png](data:image/png;base64,...)
#
#
#
# Distinct Words: ABA, AAB, BAA
#
# Total distinct ways to arrange three letters to have a distinct 3 letter word is given by:
#
# <center>
#
# ![image.png](data:image/png;base64,...)
#
#
# <center>
