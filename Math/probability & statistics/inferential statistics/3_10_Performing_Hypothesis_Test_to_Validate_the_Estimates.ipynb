# %% [markdown]
# # **Hypothesis Testing: Validating Claim of Surveying Agency**

# %% [markdown]
# > **Problem Statement:**
#
#  To validate the estimation of the surveying agency that the mean marks scored by all the students in surprise test is 413 with the confidence interval as (408, 417), the government has picked up 100 students from the country. The mean marks scored in the surprise test by these 100 students is found to be 403 with a standard deviation of 75.
#
# The agency performs hypothesis test with a 0.05 level of significance to find which of the two claims (the government or the agency) needs to be accepted.

# %% [markdown]
# ###  **Step 1: Setting Null Hypothesis and Alternate Hypothesis**

# %% [markdown]
# The first step in hypothesis testing is to define the null hypothesis.
#
# As discussed, null hypothesis disproves the observation that is present.
#
# Here the government’s observation is that the estimations proposed by the surveying agency may NOT be accurate. Hence, the null hypothesis can be set as follows.
#
# **Null Hypothesis (H0):** The estimate given by the surveying agency is correct i.e. the mean marks scored by all the students in the surprise test is 413.
#
# The alternate hypothesis must disapprove the null hypothesis. In this scenario, the alternate hypothesis can be set in two different ways as given in the table below.
#
# <center>
#
# ![image.png](data:image/png;base64,...)
#
# </center>
#
#
# The agency decides to perform One-Tailed Hypothesis Test and sets the alternate hypothesis as stated in Option 2.
#
# **Alternate Hypothesis (Ha):** The claim of the surveying agency is incorrect i.e. the mean marks scored by all the students in surprise test is less than 413.

# %% [markdown]
# ### **Step 2: Calculating Probability of Occurrence of Observed Data**

# %% [markdown]
# As discussed in hypothesis testing, you need to assume the null hypothesis to be correct and find the probability of getting the observed data. Therefore, the surveying agency assumes its estimation to be correct and finds the probability of getting a sample mean of 403.
#
# The government has taken a sample of 100 students and found the sample mean to be 403. Hence, the agency plots the 'sampling distribution of means' curve for sample size 100. As the agency is dealing with large sample (n >= 30), 'sampling distribution of means' will have normal distribution.
#
# The agency calculates the mean and standard error of the 'sampling distribution of means' for n = 100.
#
# * The mean of the sampling distribution of means = population mean (μ) = 413
#
# * Standard error,
#
# <center>
#
# ![image.png](data:image/png;base64,...)
#
# </center>
#
# However, there is no information about the population standard deviation (σ) in the given problem. In such cases, you can use sample standard deviation (s) instead for the estimate.
#
# The sample standard deviation (s) is 75.
#
# The standard error is calculated as:
#
# <center>
#
# ![image.png](data:image/png;base64,...)
#
# </center>
#
#
#
# With the knowledge of mean and standard error of sampling distribution, the sampling distribution can be plotted by the agency. As the distribution is normal, Python function norm.pdf() can be used to plot the same.

# %%
#Importing required libraries
import matplotlib.pyplot as plt
import numpy as np
import math
from scipy.stats import norm
# Initializing mean of the sampling distribution of mean as mu and sample std deviation as sd
mu = 413
sd = 7.5

#Plotting the sampling distribution
x = np.linspace(375, 450, 100)
plt.plot(x,norm.pdf(x, mu, sd))
plt.show()

# %% [markdown]
# ### **Step 2.1: Calculating the Z Statistic**

# %% [markdown]
# Assuming the null hypothesis to be true the 'sampling distribution of sample means' is plotted. To calculate the probability of getting the sample mean as 403, the agency needs to find the distance of the point 403 from the mean in terms of standard deviation/standard error.
#
# Hence, the agency calculates the Z statistic which gives the distance of a point from the mean in terms of standard deviation:
#
# <center>
#
# ![image.png](data:image/png;base64,...)
#
#
# </center>
#
#
#
# The negative sign indicates that the point 403 is 1.33 standard deviation away to the left of the mean.
#
# Since, the agency decided to perform One-Sided Hypothesis Test, it finds the probability of finding a sample mean less than or equal to 403. In other words, the agency finds the probability of getting sample mean that is 1.33 standard deviation away to the left of the mean.
#
# The same is pictorially represented below:
#
# <center>
#
#
# ![image.png](data:image/png;base64,...)
#
# </center>
#
#
#
# The probability of getting the sample mean as 403 or lesser is represented by the shaded portion (in blue).
#
# Note: If the agency goes for Two-Sided Hypothesis Test, it should calculate the probability of getting a sample mean as extreme as 403. This includes finding the probability of getting a sample mean that is more than 1.33 standard deviations away from the mean of the distribution on both sides. The same is pictorially represented below:
#
# <center>
#
# ![image.png](data:image/png;base64,...)
#
#
# </center>
#
#
#
# Two-sided hypothesis test is about finding the area of the coloured region on either side of the mean.

# %% [markdown]
# ###  **Step 2.2: Calculating the P Value**

# %% [markdown]
# Since the agency is performing a one-sided hypothesis test, it finds the probability of getting a sample mean -1.33 standard deviations away from the mean of the sampling distribution. The same can be found using the Python function norm.cdf().

# %%
#Importing the norm function from the scipy.stats module
from scipy.stats import norm
#Finding the probability of getting a value that is -1.33 standard deviation from mean using norm.cdf() function
print("The probability of getting a value that is -1.33 standard deviation from mean :",norm.cdf(-1.33))
# Out:
# The probability of getting a value that is -1.33 standard deviation from mean : 0.09175913565028077

# %% [markdown]
# The output of the norm.cdf() function, also called as P value, is 0.0917. The output of norm.cdf() function gives the area enclosed under the sampling distribution curve to the left of the point 403.
#
# From the output of norm.cdf() function, it is clear that the probability of getting a sample mean as 403 or less is 0.0917 or 9.17%.

# %% [markdown]
# ### **Steps 4 & 5: Arriving at the Conclusion**

# %% [markdown]
# **Step 4: Concluding whether the Null hypothesis can be rejected or not based on the P value**
#
# The probability of finding a sample mean as 403 or lower is found to be 9.17%.
#
# The level of significance is set as 0.05.
#
# The null hypothesis is rejected if the probability that the observed value will occur is less than 5 percent.
#
# The null hypothesis cannot be rejected, as the probability of getting a sample mean of 403 is greater than 5% (9.17 > 5).
#
# **Step 5: Stating the conclusion**
#
# As the P value > significance level, null hypothesis CANNOT be rejected i.e. based on the performance of selected 100 students, it CANNOT be concluded that the surveying agency's estimation is not valid.
#
# <u>**Solution to Challenge 4 (Validating the estimations):**</u> The surveying agency successfully performs hypothesis test to validate its estimations. In the hypothesis test, the agency fails to reject the null hypothesis which assumes its estimations to be accurate. Thus, the surveying agency validates its estimations.

# %% [markdown]
# ### **Hypothesis Test - Example**

# %% [markdown]
# Suppose bulb manufacturer xyz claims that the mean lifetime of a light bulb is greater than 9,500 hours. In a random sample of 30 light bulbs, it is observed that the bulbs last only 9300 hours on average. Assume that the population standard deviation is 110 hours. At 0.05 significance level, test the validity of the xyz manufacturer.
#
# Solution:
#
# **Step 1:**
#
# The claim of the manufacturer: Mean Lifetime > 9500 Hours
#
# Observed Data: Mean Lifetime < 9500
#
# Level of significance: 0.05
#
# **Step 2:**
#
# **Null Hypothesis:** Claim of the manufacturer is correct i.e. the mean lifetime of bulbs is greater than 9500 hours.
#
# **Alternate Hypothesis:** Claim of the manufacturer is NOT correct i.e. mean lifetime of bulbs is less than 9500 hours.
#
# As the alternate hypothesis is about finding that mean is less than 9500 secs, you will be conducting a one-sided hypothesis test.
#
# **Step 3:**
#
# Finding the test statistic as follows:

# %%
#Importing required libraries
import numpy as np
from scipy.stats import norm
xbar = 9300 #sample mean
mu0 = 9500 # hypothesized value
sigma = 110 #population standard deviation
n = 30 # sample size
z =(xbar - mu0)/(sigma/np.sqrt(n))  # test statistic
print("Test Statistic:",z)
# Out:
# Test Statistic: -9.958591954639385

# %% [markdown]
# **Step 4:**
#
# Finding the P value as follows:

# %%
#Importing the norm function from the scipy.stats module
from scipy.stats import norm
#Finding the p-value
p_value = norm.cdf(z)
print("P-Value :",p_value)
# Out:
# P-Value : 1.1565773655967452e-23

# %% [markdown]
# **Conclusion: The claim made by the manufacturer is wrong i.e. mean life-time of the bulbs is NOT greater than 9500 hours.**

# %% [markdown]
# ###  **Hypothesis Test with Known Variance - Example**

# %% [markdown]
# Consider the average weight of penguins found in Antarctica last year as 16.3kg. In a sample of 33 penguins in the current year in the same colony, the mean penguin weight is 15.7 kg. Assume the population standard deviation is 2.7 kg. At 0.05 significance level, does the current year’s mean of penguin weight differ from last year?
#
# **Solution:**
#
# The null hypothesis is that μ = 16.3. Let us begin with computing the test statistic.

# %%
#Importing required libraries
import numpy as np
from scipy.stats import norm
xbar = 15.7 #sample mean
mu0 = 16.3 # hypothesized value
sigma = 2.7 #population standard deviation
n = 35 # sample size
z =(xbar - mu0)/(sigma/np.sqrt(n)) # test statistic
print("Test Statistic:",z)
# Out:
# Test Statistic: -1.3146843962443622

# %% [markdown]
# The Z statistic is calculated as -1.314684.
#
# Let us now compute the critical values at 0.05 significance level.

# %%
#Importing the norm function from the scipy.stats module
from scipy.stats import norm
#Compute the critical values at 0.05 significance level
alpha = 0.05
z_half_alpha = norm.ppf(1-alpha/2)
print("Critical values at 0.05 significance level is",-z_half_alpha,"and",z_half_alpha)
# Out:
# Critical values at 0.05 significance level is -1.959963984540054 and 1.959963984540054

# %% [markdown]
# The test statistic -1.314684 lies between the critical values -1.9600 and 1.9600. At 0.05 significance level, you can say that the mean penguin weight does not differ from last year i.e. the null hypothesis cannot be rejected.

# %% [markdown]
# ## **Errors in Hypothesis Testing**

# %% [markdown]
# While conducting hypothesis tests, two types of errors can be encountered. These errors are termed as:
#
# * Type I
# * Type II
#
# <center>
#
# ![image.png](data:image/png;base64,...)
#
# </center>
#
#
# Accepting or rejecting hypothesis is probabilistic. Therefore, you may fail to reject a hypothesis when it is false and reject it when it is true. These error conditions have special names.
#
# Type I error is said to occur when a null hypothesis is rejected when it is true.
#
# Type II error is said to occur when you fail to reject a null hypothesis when it is false.

# %% [markdown]
# ## **Exercises**

# %% [markdown]
# > **Hypothesis Testing - Exercise 1**

# %% [markdown]
# **Problem Statement:**
#
# Suppose the mean lifetime of a light bulb claimed by a manufacturer is more than 10,000 hours. Around 30 light bulbs are selected as a sample and it is found that they only last 9,900 hours on an average. Assume 120 hours as the population standard deviation. At 0.05 significance level, can you reject the claim by the manufacturer?

# %% [markdown]
# > **Hypothesis Testing - Exercise 2**

# %% [markdown]
# **Problem Statement:**
#
# Suppose 15.4 kg is the mean weight of fox found in a colony last year. In the current year in the same colony, 35 fox are selected as a sample and the mean fox weight is found to be 14.6 kg. Assume the population standard deviation is 2.5 kg. At 0.05 significance level, can you reject the null hypothesis that the mean fox weight does not differ from last year?

# %% [markdown]
# > **Hypothesis Testing - Exercise 3**

# %% [markdown]
# **Problem Statement:**
#
# Suppose 2 grams of saturated fat is said to be present in a single piece of brownie as per the label on the packet. 35 brownies are collected as a sample and it is found that the average saturated fat per brownie is 2.1 grams. 0.25 grams is the standard deviation of the population. Can you reject the claim on the label at 0.05 significance level?

# %% [markdown]
# > **Hypothesis Testing - Exercise 4**

# %% [markdown]
# **Problem Statement:**
#
# A manufacturer claims that the mean lifetime of a light bulb is more than 10,000 hours. In a sample of 25 light bulbs, it is found that they only last 9,900 hours on an average. Assume that the sample standard deviation is 125 hours. At 0.05 significance level, can you reject the claim by the manufacturer?
