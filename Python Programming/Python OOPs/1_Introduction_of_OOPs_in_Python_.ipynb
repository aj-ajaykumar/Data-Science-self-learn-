# %% [markdown]
# This style of programming where we create a template and create copies from that template is called object oriented programming. This style allows us to code for scenarios closely linked with real life.
#
# The template we create is called a Class and the copies we create out of it is called an object.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Objects** are real world entities. Anything you can describe in this world is an object.
#
# **Classes** on the other hand are not real. They are just a concept or a blue print. Class is a short form of Classification.
#
# A class is a classification of certain objects and it is just a description of the properties and behavior all objects of that classification should possess.

# %% [markdown]
# Class is a like a recipe and the object is like the cupcake we bake using it. All cupcakes created from a recipe share similar characteristics like shape, sweetness, etc.
#
#  But they are all unique as well. One cupcake may have strawberry frosting while another might have vanilla. Similarly, objects of a class share similar characteristics but they differ in their values for those characteristics.

# %% [markdown]
# >What does a recipe contain?
#
# It contains list of ingredients which make up the cake and the directions. Similarly, a class contains the properties/**attributes** of the object and the operations/**behavior** that can be performed on an object.

# %% [markdown]
# same like
#
# mobile is an mobile is a class and this calss conatain two attributes price and brand and also the class contains two behaviors(methids) Purchase,Return item

# %% [markdown]
# ![F11.png](data:image/png;base64,...)

# %% [markdown]
# >**class**
#
# A class is a collection of objects. A class contains the blueprints or the prototype from which the objects are being created. It is a logical entity that contains some attributes and methods.

# %% [markdown]
# **Some points on Python class:**
#
# * Classes are created by keyword class.
# * Attributes are the variables that belong to a class.
# * Attributes are always public and can be accessed using the dot (.) operator. Eg.: Myclass.Myattribute

# %%
# creating class
class Mobile():
  pass

# %% [markdown]
# variables inside the class are called as attributes

# %%
# class with attibutes
class Mobile():
  Brand = "samsung" # attribute 1
  price = 5000 # attribute 2

# %% [markdown]
# >**OBJECTS**
#
# In object oriented programming Python, The object is an entity that has a state and behavior associated with it. It may be any real-world object like a mouse, keyboard, chair, table, pen, etc.
#
# an object is an instance of the class suppose
#
# Dog is a class from dog calss you can create objects like Dog1, Dog2
# **Note:**  thease Dog1, DOg2 are like real world objects   but Dog class is not real word  its like a blue print to create real world objects

# %%
#creating object from class
mobile1 = Mobile()

# %% [markdown]
# suppose Integers, strings, floating-point numbers, even arrays, and dictionaries, are all objects. More specifically, any single integer or any single string is an object. The number 12 is an object, the string “Hello, world” is an object, a list is an object that can hold other objects, and so on. You’ve been using objects all along and may not even realize it.

# %%
# creating class
class Dog():
  name = 'vikky'
  color = 'Brown'

# creating objects
dog1  = Dog() # from this object we can acess all attributes form the Dog class
print(dog1.name)
print(dog1.color)
# Out:
# vikky
# Brown

# %% [markdown]
# now here **Dog1** is not any more blue print its like real dog
#
# we built this real dog from **Dog** class

# %% [markdown]
# ![downloadaa.png](data:image/png;base64,...)

# %% [markdown]
# >**An object consists of:**
#
# * **State**: It is represented by the attributes of an object. It also reflects the properties of an object.
# * **Behavior**: It is represented by the methods of an object. It also reflects the response of an object to other objects.
# * **Identity**: It gives a unique name to an object and enables one object to interact with other objects.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Example of each property
# >note:
# Attributes are the properties and behaviours are metods

# %% [markdown]
# To understand the state, behavior, and identity let us take the example of the class dog (explained above).
#
# * The identity can be considered as the name of the dog.
# * State or Attributes can be considered as the breed, age, or color of the dog.
# * The behavior can be considered as to whether the dog is eating or sleeping

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > **Examlpe**
#
#  refer thr link https://www.scientecheasy.com/wp-content/uploads/2023/08/python-object-example.png

# %% [markdown]
# >**Problem Statement**
#
# Try to create a mobile class and abjects and acess the object instances

# %%
# creating class
class Mobile():
  name = 'Samsung'
  price = 50000

# creating objects
samsung_Mobile =  Mobile()
Apple_Mobile = Mobile()

# %%
print(samsung_Mobile.name)
print(Apple_Mobile.name) # but here you can get name for both is samsung
# Out:
# Samsung
# Samsung

# %% [markdown]
# but here you can get name for both is samsung  BCZ the calss conatins these values

# %%
# here  to over come this we will assigne value to the particulor object
# creating class
class Mobile():
  name = 'Samsung'
  price = 50000

# creating objects
samsung_Mobile =  Mobile()

Apple_Mobile = Mobile()
#accessing Attributes to manipulate
Apple_Mobile.name="Apple"
Apple_Mobile.price = 75000

# now print
print(samsung_Mobile.name)
print(Apple_Mobile.name)
# Out:
# Samsung
# Apple

# %%
print("samsung price",samsung_Mobile.price)
print("Apple price",Apple_Mobile.price)
# Out:
# samsung price 50000
# Apple price 75000

# %% [markdown]
# for every instance or object we can aslo add exta propoeties based on our requirment

# %%
class Mobile():
  name = 'Samsung'
  price = 50000

# creating objects
samsung_Mobile =  Mobile()
Apple_Mobile = Mobile()


#accessing Attributes to manipulate
Apple_Mobile.name="Apple"
Apple_Mobile.price = 75000
Apple_Mobile.Storage = "128 Gb" # additional attribute for Specific instance/onject


print(Apple_Mobile.Storage)
# Out:
# 128 Gb

# %% [markdown]
# We can update the value of an existing attribute using the dot operator. For example, the below code will change the ios_version of mob1 object, since the mob1 object already has that attribute.
#
# mob1.ios_version=11
#
# In python, if we assign a value to a non-existent attribute, it will create that attribute for that object alone. For example, the below code will create an attribute for mob2 object alone.
#
# mob2.android_version="Marshmallow"

# %%
class Mobile():
  name = 'Samsung'
  price = 50000

# creating objects
samsung_Mobile =  Mobile()

# assigneing new attributes
samsung_Mobile.android_version = 'android 14'


Apple_Mobile = Mobile()
#Updating  Attributes to manipulate
Apple_Mobile.name="Apple"
Apple_Mobile.price = 75000

# assigning additional attribute for Specific instance/o
Apple_Mobile.ios_version = 10
print ("Apple IOS version Before Update",Apple_Mobile.ios_version)

# Upadting version for apple
Apple_Mobile.ios_version = 11
print ("Apple IOS version after Update",Apple_Mobile.ios_version)
# Out:
# Apple IOS version Before Update 10
# Apple IOS version after Update 11

# %% [markdown]
# every object occupaies diffrent memory space  in memory
# so hadling objects is very importent for performence

# %% [markdown]
# diffrences between attribute and variable
#
# * **variable** is acessed directly
# * **attribute** is aceessed with .(dot)

# %% [markdown]
# >**Note:**
#
# in the above code there is a lack reuse it will be very difficult to manipulate attributes for each object
#
# example if an object has 10 attributes and we have 10 objects, then we have to write 100 lines of code! There is no reuse at all.
#
# We need a way to mention the attributes of all the objects of a class in one place so that we can create and initialize the attributes.
#
# here where the constructor are into picture

# %% [markdown]
# >**Constructors**
#
# Attributes can be added to a class through a special function called __init__(). We will discuss more about the syntax later. But for now, this is how the mobile class will look like with attributes in it.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In the code, brand and price are the attributes. All objects of this class will now have these attributes automatically. Here mob1 is assigned “Apple” and 20000 as values for the attributes brand and price respectively.
#
# Note:The parameter names and attribute names need not match

# %% [markdown]
# >**Self()**
#
# 1. Class methods must have an extra first parameter in the method definition. We do not give a value for this parameter when we call the method, Python provides it
# 2. If we have a method that takes no arguments, then we still have to have one argument.
# 3. This is similar to this pointer in C++ and this reference in Java.

# %% [markdown]
# **Self** represents the instance of the class. By using the “self”  we can access the attributes and methods of the class in Python.
#
#
# The reason you need to use self. is because Python does not use the @ syntax to refer to instance attributes. Python decided to do methods in a way that makes the instance to which the method belongs be passed automatically,
#
#  but not received automatically: the first parameter of methods is the instance the method is called on.

# %% [markdown]
# **What is the use of self in Python?**
#
# When working with classes in Python, the term “self” refers to the instance of the class that is currently being used. It is customary to use “self” as the first parameter in instance methods of a class. Whenever you call a method of an object created from a class,
#
#  the object is automatically passed as the first argument using the “self” parameter. **This enables** you to **modify** the object’s properties and execute tasks unique to that particular instance.

# %% [markdown]
# >**In methods**
#
# When we call a method of this object as myobject.method(arg1, arg2), this is automatically converted by Python into MyClass.method(myobject, arg1, arg2) – this is all the special self is about.

# %% [markdown]
# **use of self:**
# In Python, the keyword "self" refers to the current instance of a class. It's used to access the class's variables, attributes, and methods

# %% [markdown]
# >**Note:**
#
# When working with classes, it’s important to understand that in Python, a class constructor is a special method named **\__init__()\** that gets called when you create an instance (object) of a class. This method is used to initialize the attributes of the object. Keep in mind that the self parameter in the constructor refers to the instance being created and allows you to access and set its attributes.

# %% [markdown]
# >**\__init__()**
#
# The __init__ method is the Python equivalent of the C++ constructor in an object-oriented approach. The __init__ function is called every time an object is created from a class. The __init__ method lets the class initialize the object's attributes and serves no other purpose. It is only used within classes.

# %% [markdown]
# we can create constructor without perameteres also

# %%
# example
class myself:
  def __init__(self):
    print("my self ajay")

d1 = myself() # here eah time when i create new object what ever in the init will be executed first in the object
d2 = myself() # It runs as soon as an object of a class is instantiated
# Out:
# my self ajay
# my self ajay

# %% [markdown]
# **Definition:**
#
# The __init__ method is similar to constructors in C++ and Java. Constructors are used to initializing the object’s state. Like methods, a constructor also contains a collection of statements(i.e. instructions) that are executed at the time of Object creation.
#
# **It runs as soon** as an object of a class is instantiated. The method is useful to do any initialization you want to do with your object.

# %% [markdown]
# __init__ is in two types
#
# default constructor
#
# paramerarised constructor

# %%
class Mobile:
  # default constructor
  def __init__(self) -> None:
     pass

  # parametarised Constructor
  def __init__(self,brand,price):
    self.brand = brand
    self.price = price

# %% [markdown]
# but as a best practice we use one constructor

# %%
class Mobile:
  # class Attributes
  Attr1 = "Ajay"

  # intrance Attributes
  def __init__ (self,brand,price): # the fist perameter is taken as self and we can change the self nane as ourwish
    self.brand = brand
    self.price = price

Sam_Mobile = Mobile('samsung',50000)
print(Sam_Mobile.brand)
# Out:
# samsung

# %% [markdown]
# with multiple objects

# %%
class Mobile:
  # class Attributes
  Attr1 = "Ajay"

  # intrance Attributes
  def __init__ (self,brand,price): # the fist perameter is taken as self and we can change the self nane as ourwish
    self.brand = brand
    self.price = price

Sam_Mobile = Mobile('samsung',50000)
app_Mobile = Mobile('Apple',75000)
print('mobile brand is '+Sam_Mobile.brand+" price: "+str(Sam_Mobile.price))
print('mobile brand is '+app_Mobile.brand+" price: "+str(app_Mobile.price))
# Out:
# mobile brand is samsung price: 50000
# mobile brand is Apple price: 75000

# %% [markdown]
# >**Problem Statement**
#
# Attributes can be created only by using the self variable and the dot operator. Without self we are only creating a local variable and not an attribute.

# %%
class Mobile:
    def __init__(self):
        print ("Inside the Mobile constructor")
        self.brand = None
        brand = "Apple" #This is a local variable.
        #Variables without self are local and they dont
        #affect the attributes.

        #Local varaibles cannot be accessed outside the init
        #Using self creates attributes which are
        #accessible in other methods as well

mob1=Mobile()
print(mob1.brand)#This does not print Apple
#This prints None because brand=Apple creates
#a local variable and it does not affect the attribute
# Out:
# Inside the Mobile constructor
# None

# %% [markdown]
# we can not access the Appple BCZ its a local variable
#
# we can only access the varibles in the object with self only

# %% [markdown]
# Acessing class Attributes

# %%
class Mobile:
    # class attributes
    name = 'Ajay'
    def __init__(self):
        print ("Inside the Mobile constructor")
        self.brand = None
        brand = "Apple" #This is a local variable.


mob1=Mobile()
print(mob1.brand)#This does not print Apple

print(mob1.name) # we access the class attributes directly
# Out:
# Inside the Mobile constructor
# None
# Ajay

# %% [markdown]
# we access the class attributes directly but we can't update those values

# %%
class Mobile:
    # class attributes
    name = 'Ajay'

    # instance attributes
    def __init__(self):
        print ("Inside the Mobile constructor")
        self.brand = None
        brand = "Apple" #This is a local variable.


mob1=Mobile()
print(mob1.brand)#This does not print Apple

print(mob1.name) # we access the class attributes directly
mob1.name = "Gani"
print(mob1.name)
# Out:
# Inside the Mobile constructor
# None
# Ajay
# Gani

# %% [markdown]
# if you have attribute with same name in bothe class and instance attibutes

# %%
class mobile:
  #class Attribute
  brand = 'Samsung'

  #  instance attributes
  def __init__(self,brand,price):
    self.brand = brand   # inst attr > class attri
    self.price = price

mob1 = mobile("Apple",75000) # which attribute will print
print(mob1.brand)
# Out:
# Apple

# %% [markdown]
# here the instance attribute have heigher precedence then class attribute
#
# so instance attribute will  printed

# %% [markdown]
# >**Methods in python**

# %% [markdown]
#  method defines the behaviour of the object
# mothed is noting but a function we can used inside the class
#
#
# the functions which are used inside the class is called as  **methods**

# %% [markdown]
# Python Method
#
# 1. Method is called by its name, but it is associated to an object (dependent).
# 2. A method definition always includes ‘self’ as its first parameter.
# 3. A method is implicitly passed to the object on which it is invoked.
# 4. It may or may not return any data.
# 5. A method can operate on the data (instance variables) that is contained by the corresponding class

# %%
class dog:
  # constructor
  def __init__(self,name,color):
    self.name = name
    self.color = color
  # method
  def eat(self):
    print(self.name+" is eating")

  def bark(self):
    print(self.name+" is barking ")


dog1 = dog("rockey","Brown")
dog1.eat()
dog1.bark()
# Out:
# rockey is eating
# rockey is barking

# %% [markdown]
# >**Problem Statement**
#
# We can access an attribute in a method by using self. Value of the attribute accessed inside the method is determined by the object used to invoke the method.
#
# For example, in the code below when we invoke purchase using mob1, attribute values (Apple and 20000) of mob1 are accessed.
#
# Similarly, when mob2 is used to invoke purchase, attribute values (Samsung and 3000) of mob2 are accessed in purchase().

# %%
class Mobile:
    def __init__(self, brand, price):
        print("Inside constructor")
        self.brand = brand
        self.price = price

    def purchase(self):
        print("Purchasing a mobile")
        print("This mobile has brand", self.brand, "and price", self.price)

print("Mobile-1")
mob1=Mobile("Apple", 20000)
mob1.purchase()

print("Mobile-2")
mob2=Mobile("Samsung",3000)
mob2.purchase()
# Out:
# Mobile-1
# Inside constructor
# Purchasing a mobile
# This mobile has brand Apple and price 20000
# Mobile-2
# Inside constructor
# Purchasing a mobile
# This mobile has brand Samsung and price 3000

# %% [markdown]
# >**Problem Statement**
#
# We can also invoke one method from another using self.

# %%
class Mobile:
    def display(self):
        print("Displaying details")

    def purchase(self):
        self.display()
        print("Calculating price")

Mobile().purchase()
# Out:
# Displaying details
# Calculating price

# %% [markdown]
# type od calling methods

# %%
class Mobile:
    def __init__(self,price,brand):
        print (id(self))
        self.price = price
        self.brand = brand

    def return_product(self):
        print (id(self))
        print ("Brand being returned is ",self.brand," and price is ",self.price)

mob1 = Mobile(1000, "Apple")
print ("Mobile 1 has id", id(mob1))

mob2=Mobile(2000, "Samsung")
print ("Mobile 2 has id", id(mob2))

mob2.return_product() # type 1
Mobile.return_product(mob2) # type 2
# Out:
# 138272423042720
# Mobile 1 has id 138272423042720
# 138272423044256
# Mobile 2 has id 138272423044256
# 138272423044256
# Brand being returned is  Samsung  and price is  2000
# 138272423044256
# Brand being returned is  Samsung  and price is  2000

# %% [markdown]
# mob2.return_product() can also be invoked as Mobile.return_product(mob2).
#
# Thus self now refers to mob2. For simplicity sake and for better readability we use mob2.return_product() instead of Mobile.return_product(mob2).

# %% [markdown]
# >**note:**     .upper( )  -------   is also a method from string class like this python itself works on  OOps
#
#
# perameters are optional in functions
#
# but in  methods
#
# A method must have at least one parameter : self

# %% [markdown]
# >**Reference VAriabels**

# %% [markdown]
# **un used references**

# %%
class Mobile:
    def __init__(self, price, brand):
        self.price = price
        self.brand = brand

Mobile(1000, "Apple")
#After the above line the Mobile
# object created is lost and unusable

# %% [markdown]
# **multiple referencrs**

# %%
class Mobile:
    def __init__(self, price, brand):
        print ("Inside constructor")
        self.price = price
        self.brand = brand

mob1=Mobile(1000, "Apple")
mob2=mob1
print ("Id of object referred by mob1 reference variable is :", id(mob1))
print ("Id of object referred by mob2 reference variable is :", id(mob2))
#mob1 and mob2 are reference variables to the same object
# Out:
# Inside constructor
# Id of object referred by mob1 reference variable is : 139025076133776
# Id of object referred by mob2 reference variable is : 139025076133776

# %% [markdown]
# multiple reference - object updation

# %%
class Mobile:
    def __init__(self, price, brand):
        self.price = price
        self.brand = brand

mob1=Mobile(1000, "Apple")
print("Price of mobile 1 :", mob1.price)

mob2=mob1
mob2.price=3000

print("Price of mobile 1 :", mob1.price)
print("Price of mobile 2 :", mob2.price) # the price of the both instances will chage beacause both are pointing same memory
# Out:
# Price of mobile 1 : 1000
# Price of mobile 1 : 3000
# Price of mobile 2 : 3000

# %% [markdown]
# **Defrencing**
#
# we can make one reference variable refer to another object. Now any change made through this reference variable will not affect the old object.

# %%
class Mobile:
    def __init__(self, price, brand):
        self.price = price
        self.brand = brand

mob1=Mobile(1000, "Apple")

mob2=mob1
mob2=Mobile(2000," Samsung")
mob2.price=3000

print("Mobile", "Id","Price")
print("mob1", id(mob1), mob1.price)
print("mob2", id(mob2), mob2.price)
# Out:
# Mobile Id Price
# mob1 139025076127344 1000
# mob2 139025076126480 3000

# %% [markdown]
# 1. Reference variables hold the objects
# 2. We can create objects without reference variable as well
# 3. An object can have multiple reference variables
# 4. Assigning a new reference variable to an existing object does not create a new objec

# %% [markdown]
# >**Printing an object**
#
# What would be the output if we print the reference variable? Since it is an object, printing it will display the internal hex representation of it. How can we get a more readable output for this?

# %%
class Shoe:
    def __init__(self, price, material):
        self.price = price
        self.material = material

s1=Shoe(1000, "Canvas")
print(s1)

# %% [markdown]
# >**\__str__() Method**

# %% [markdown]
# Python has a particular method called __str__(). that is used to define how a class object should be represented as a string. It is often used to give an object a human-readable textual representation, which is helpful for logging, debugging, or showing users object information. When a class object is used to create a string using the built-in functions print() and str(), the __str__() function is automatically used. You can alter how objects of a class are represented in strings by defining the __str__() method.

# %% [markdown]
# For a more readable output when printing an object we can use the inbuilt special __str__ method. This method MUST return a string and this string will be used when the object is printed. This is useful in debugging as we can print the values of the attributes.

# %%
class Shoe:
    def __init__(self, price, material):
        self.price = price
        self.material = material

    def __str__(self):
        return "Shoe with price: " + str(self.price) + " and material: " + self.material

s1=Shoe(1000, "Canvas")
print(s1)
# Out:
# Shoe with price: 1000 and material: Canvas

# %% [markdown]
# >**Coding standerdes**

# %% [markdown]
# All variable names and method names are in snake_case and all class names should be in PascalCase ( It is similar to camelCase but the first character is also Capitalized ). For example:
#
# Classes:
# Mobile
# RegularCustomer
#
# Methods:
# change_password()
# display_details()
#
# Variables:
# price = 1000
# brand = "Samsung"

# %% [markdown]
# >**OOPs BAsic Summary**

# %% [markdown]
# * OOP is a style of programming which allows us to club data and behavior together.
#
# * This is more suited for coding real life scenarios.
#
# * Objects are real world entities
#
# * Class is just a classification. It is just a concept.
#
# * Class is a description of attributes and behavior that objects of that classification should possess.
#
# * Attributes are created in a special function called __init__ and behaviors are created using functions called methods.
#
# * Objects can be created using ClassName() or using object literals for some of the built in classes
#
# * Attributes are created using reference_variable.attribute_name = value syntax.
#
# * Behavior is created by defining a function inside the class having a special parameter called self.

# %% [markdown]
# >**Excersice**

# %% [markdown]
# **Problem:**Create a student class that takes name and marks of 3 subjects as arguments in constructor
#
# then create a method to print the average

# %%
class student:
  def __init__(self,name,marks):
    self.name = name
    self.marks = marks

  def calc_Avg(self):
    MarksCount = 0
    for i in self.marks:
      MarksCount +=i
    print("hi "+self.name+" yor average marks was "+str(MarksCount/3 ))

student1 = student("ajay",[98,95,99])
student1.calc_Avg()
# Out:
# hi ajay yor average marks was 97.33333333333333
