# %% [markdown]
# # **inheritance.**
#
# inheritance is a mechanism that allows you to create a hierarchy of classes that share a set of properties and methods by deriving a class from another class. Inheritance is the capability of one class to derive or inherit the properties from another class.
#
# Benefits of inheritance are:
#
# Inheritance allows you to inherit the properties of a class, i.e., base class to another, i.e., derived class. The benefits of Inheritance in Python are as follows:
#
# * It represents real-world relationships well.
# * It provides the reusability of a code. We don’t have to write the same code again and again. Also, it allows us to add more features to a class without modifying it.
# * It is transitive in nature, which means that if class B inherits from another class A, then all the subclasses of B would automatically inherit from class A.
# * Inheritance offers a simple, understandable model structure.
# * Less development and maintenance expenses result from an inheritance.

# %%
#syntax
class vehicle:
  pass

class car(vehicle):
  pass

# %% [markdown]
# **lets take our online shopping Problem.**
#
# Let us say that the online shopping app wants to sell different types of phones:
#
# Feature phones and Smartphones
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The below are the class diagrams for both the classes:
#
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **We can see** that both the class have a lot in common. This is because they both are ultimately phones and each is just a special type of phone.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Since both** the classes are of type phone, we can create a phone class with the common attributes and methods and make these two classes inherit those attributes and behavior, as shown:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# When a class inherits from another class, then those classes are said to have an inheritance relationship. The class which is inheriting is called the child/sub/derived class and the class which is getting inherited is called the parent/super/base class. Inheritance is also called as "is-A" relationship.
#
# In our example, FeaturePhone is inheriting the Phone and SmartPhone is inheriting the Phone class (SmartPhone "is-A" phone, FeaturePhone "is-A" phone). So Phone is the parent class and FeaturePhone and SmartPhone are derived classes.

# %% [markdown]
# **There are three main advantages of inheritance:**
#
# We can keep common properties in a single place. Thus any changes needs to be made need not be repeated.
# Inheritance encourages code reuse thus saving us time.
# If we want to add a new type of phone later on, we can simply inherit the Phone class instead of writing it from scratch.

# %% [markdown]
# >**Problem Statement**
#
# Let us look at inheritance in code. For now we will create the Phone class with necessary attributes and methods. We will create FeaturePhone and SmartPhone classes without any attributes or methods now. We will create them later.

# %%
class phone:
  def __init__(self,brand,price,camera):
    self.brand = brand
    self.price = price
    self.camera = camera

  # methods
  def buy(self):
    print("buying phone....")

  def return_phone(self):
    print("returning phone...")

class featurePhone:
  pass

class smartPhone:
  pass

phone("Samsung",50000,"200Px").buy()
# Out:
# buying phone....

# %% [markdown]
# >**Inheritance - Connecting Classes**
#
# **Problem Statement**
#
# To create an inheritance relationship between the classes, mention the name of the parent class in brackets as shown:

# %%
class phone:
  def __init__(self,brand,price,camera):
    self.brand = brand
    self.price = price
    self.camera = camera

  # methods
  def buy(self):
    print("buying phone....")

  def return_phone(self):
    print("returning phone...")

class featurePhone(phone): # making inheritance connection
  pass

class smartPhone(phone): # making inheritance connection
  pass

phone("Samsung",50000,"200Px").buy()
phone1 = phone("Samsung",50000,"200Px")
phone1.return_phone()
# Out:
# buying phone....
# returning phone...

# %% [markdown]
# >**What gets inherited?**
#
# When we have a inheritance relationship, the attributes and behaviors get inherited, just like a child inherits certain attributes and behaviours from its parent.
#
# From a code perspective, a child class inherits:
#
# * Constructor
# * Non Private Attributes
# * Non Private Methods
#
# This is true for languages like Java, C# etc.
#
# Unlike other languages, private variables get inherited in Python. We will discuss more about this later.
#
# When we say a child class inherits the attributes and methods, we can treat the attributes and behavior as if it is owned by the child class itself.

# %% [markdown]
# >**Inheriring Attributes**

# %%
class phone:
  def __init__(self,brand,price,camera):
    self.brand = brand
    self.price = price
    self.camera = camera

  # methods
  def buy(self):
    print("buying phone....")

  def return_phone(self):
    print("returning phone...")

class featurePhone(phone):
  pass

class smartPhone(phone):
  def check_Price(self):
    print(self.price) # accessing parent attribute in child class


smart1 = smartPhone("samsung",45000,"108Px")

print(smart1.brand)

smart1.check_Price()
# Out:
# samsung
# 45000

# %% [markdown]
# **Override Peretn Attributes**

# %%
class phone:
  def __init__(self,brand,price,camera):
    self.brand = brand
    self.price = price
    self.camera = camera

  # methods
  def buy(self):
    print("buying phone....")

  def return_phone(self):
    print("returning phone...")

class featurePhone(phone):
  pass

class smartPhone(phone):
  def check_Price(self):
    print("price: ",self.price) # accessing parent attribute in child class


smart1 = smartPhone("samsung",45000,"108Px")
print("brand : ",smart1.brand)
smart1.check_Price()

# overriding parent Attributes
smart1.brand = "Apple"
print("Overriding.... parent Attributes")
print("brand : ",smart1.brand)
# Out:
# brand :  samsung
# price:  45000
# Overriding.... parent Attributes
# brand :  Apple

# %% [markdown]
# **Problem Statement**
#
# A child class cannot directly access the private attributes of the parent class.

# %%
class phone:
  def __init__(self,brand,price,camera):
    self.brand = brand
    self.__price = price
    self.camera = camera

  # methods
  def buy(self):
    print("buying phone....")

  def return_phone(self):
    print("returning phone...")

class featurePhone(phone):
  pass

class smartPhone(phone):
  def check_Price(self):
    print(self.__price) # accessing parent attribute in child class

    # we can't access private attributes directly  in child


smart1 = smartPhone("samsung",45000,"108Px")


smart1.check_Price() # we can't access private attributes directly  in child
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-45a88d11be79> in <cell line: 27>()
#      25
#      26
# ---> 27 smart1.check_Price() # we can't access private attributes directly  in child
#      28
#
# <ipython-input-13-45a88d11be79> in check_Price(self)
#      17 class smartPhone(phone):
#      18   def check_Price(self):
# ---> 19     print(self.__price) # accessing parent attribute in child class
#      20
#      21     # we can't access private attributes directly  in child
#
# AttributeError: 'smartPhone' object has no attribute '_smartPhone__price'

# %% [markdown]
# >**Inheriting Methods**
#
# **Problem Statement**
#
# Apart from attributes, the child class inherits the methods of the parent class as shown:

# %%
class phone:
  def __init__(self,brand,price,camera):
    self.brand = brand
    self.price = price
    self.camera = camera

  # methods
  def buy(self):
    print("buying phone....")

  def return_phone(self):
    print("returning phone...")

class featurePhone(phone):
  pass

class smartPhone(phone):
  def check_Price(self):
    print("\n printing from child class....")
    self.return_phone()# accessing parent method in child class

smart1 = smartPhone("samsung",45000,"108Px")

smart1.buy()#parent method

smart1.check_Price()
# Out:
# buying phone....
#
#  printing from child class....
# returning phone...

# %% [markdown]
# >**Overriding Method in child class**

# %% [markdown]
# **Problem Statement**
#
# Sometimes a child may not want to use what it has inherited from the parent. The same holds true for OOP as well. If the child class does not want to use a method inherited from the parent class then it may create its own method with the same name.
#
# When the child has a method with the same name as that of the parent, it is said to override the parent’s method. This is called as Method Overriding. Method overriding is also called as Polymorphism.
#
# will discuss about Polymorphism later..

# %%
class phone:
  def __init__(self,brand,price,camera):
    self.brand = brand
    self.price = price
    self.camera = camera

  # methods
  def buy(self):
    print("buying phone....")

  def return_phone(self):
    print("returning phone...")

class featurePhone(phone):
  pass

class smartPhone(phone):

  # overriding Parent method
  def buy(self):
    print("buying... Smart phone..")

  def check_Price(self):
    print("\n printing from child class....")
    self.return_phone()# accessing parent method in child class


smart1 = smartPhone("samsung",45000,"108Px")

smart1.buy() #Oveerided parent method
# Out:
# buying... Smart phone..

# %% [markdown]
# >**Inheriting Constructor**
#
# **Problem Statement**
#
# Since the SmartPhone class is inheriting the Phone class, the SmartPhone class inherits the constructor of the Phone class.

# %%
class phone:
  def __init__(self,brand,price,camera):
    self.brand = brand
    self.phone = phone
    self.camera = camera

  # methods
  def buy(self):
    print("buying phone....")

  def return_phone(self):
    print("returning phone...")

class featurePhone(phone):
  pass

class smartPhone(phone):
  # when ever you creatng own constructtor for child it don't inherit  attibutes from parent directly
  # because here we ovverriding the constructor
  def __init__(self,ram,rom):
    self.ram = ram
    self.rom = rom

  def buy_phone(self):
    print("buying a smart phone with features...")
    print("Brand : ", self.brand,"camera: ",self.camera,"Ram : ",self.ram,"Rom :",self.rom)


#instatiating phone calss because child class taking attributes fromn here
phone1 = phone("Samsung",50000,"108Px")

smart1 = smartPhone("8Gb","256 Gb")

# calling child Method
smart1.buy_phone()
# Out:
# buying a smart phone with features...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-ccfe120919ce> in <cell line: 33>()
#      31
#      32 # calling child Method
# ---> 33 smart1.buy_phone()
#      34
#      35
#
# <ipython-input-26-ccfe120919ce> in buy_phone(self)
#      22   def buy_phone(self):
#      23     print("buying a smart phone with features...")
# ---> 24     print("Brand : ", self.brand,"camera: ",self.camera,"Ram : ",self.ram,"Rom :",self.rom)
#      25
#      26
#
# AttributeError: 'smartPhone' object has no attribute 'brand'

# %% [markdown]
# When ever we want to create extra Attribute in child class we can't directly acess parent attributes
#
# here where exactly Super() comes into picture

# %% [markdown]
# >**super() - Invoke Constructor**

# %% [markdown]
# **Problem Statement**
#
# To access the parent class constructor we can use super(). Thus, the data is passed to the child class constructor, from there the data is sent to the parent class constructor and thus the attributes of the parent class get inherited.
#
# super() function can be used to access the constructor or methods of the parent class, but not the attributes. Also super() function can be used only inside a class and not outside it

# %%
class phone:
  def __init__(self,brand,price,camera):
    self.brand = brand
    self.phone = phone
    self.camera = camera

  # methods
  def buy(self):
    print("buying phone....")

  def return_phone(self):
    print("returning phone...")

class featurePhone(phone):
  pass

class smartPhone(phone):
  def __init__(self,brand,price,camera,ram,rom):
    self.ram = ram
    self.rom = rom
    # inheriting constructor from parent to pass attributes to child directly on child object creation
    super().__init__(brand,price,camera)


  def buy_phone(self):
    print("buying a smart phone with features...")
    print("\n Brand : ", self.brand,"\n","camera: ",self.camera,"\n","Ram : ",self.ram,"\n","Rom :",self.rom)



#now there is no use of this we can directly pass attributes in child
# phone1 = phone("Samsung",50000,"108Px")

smart1 = smartPhone("Samsung",50000,"108Px","8Gb","256 Gb")

# calling child Method
smart1.buy_phone()
# Out:
# buying a smart phone with features...
#
#  Brand :  Samsung
#  camera:  108Px
#  Ram :  8Gb
#  Rom : 256 Gb

# %% [markdown]
# >**super() - Invoke Overridden Method**
#
# **Problem Statement**
#
# Even though the child class may override the methods of the parent class, it might still decide to use the parent class overridden method. To invoke anything belonging to the parent class, the child class needs to use the super() function, as shown below:

# %%
class phone:
  def __init__(self,brand,price,camera):
    self.brand = brand
    self.phone = phone
    self.camera = camera

  # methods
  #Features methods
  def features(self):
    print("from parent class")
    print(" Brand : ", self.brand,"\n","camera: ",self.camera,)

  def buy(self):
    print("buying phone....")

  def return_phone(self):
    print("returning phone...")


class featurePhone(phone):
  pass

class smartPhone(phone):
  def __init__(self,brand,price,camera,ram,rom):
    self.ram = ram
    self.rom = rom
    # inheriting constructor from parent to pass attributes to child directly on child object creation
    super().__init__(brand,price,camera)


  def buy(self): # ovverriding parent method
    print("buying a smart phone with features...")
    print("\n Ram : ",self.ram,"\n","Rom :",self.rom)
    # method from parent even we are overriding the parent
    super().features()



 # Note:  we use super() when ever we want use menthd from parent  even the method is oveerided in child



smart1 = smartPhone("Samsung",50000,"108Px","8Gb","256 Gb")

# calling child Method
smart1.buy()
# Out:
# buying a smart phone with features...
#
#  Ram :  8Gb
#  Rom : 256 Gb
# from parent class
#  Brand :  Samsung
#  camera:  108Px

# %% [markdown]
# >**Inheritance Summary**
#
# A class can inherit from another class.
#
# Inheritance improves code reuse
#
# Constructor, attributes, methods get inherited to the child class
#
# The parent has no access to the child class
#
# Private properties of parent are not accessible directly in child class
#
# Child class can override the attributes or methods. This is called method overriding
#
# super() is an inbuilt function which is used to invoke the parent class methods and constructor
