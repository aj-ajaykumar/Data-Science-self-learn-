# %% [markdown]
# # **Data Abstraction in Python**
#
# Data abstraction is one of the most essential concepts of Python OOPs which is used to hide irrelevant details from the user and show the details that are relevant to the users.

# %% [markdown]
# A simple example of this can be a car. A car has an accelerator, clutch, and break and we all know that pressing an accelerator will increase the speed of the car and applying the brake can stop the car but we don’t know the internal mechanism of the car and how these functionalities can work this detail hiding is known as data abstraction.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >**Importance of Data Abstraction**
#
# It enables programmers to hide complex implementation details while just showing users the most crucial data and functions. This abstraction makes it easier to design modular and well-organized code, makes it simpler to understand and maintain, promotes code reuse, and improves developer collaboration.
#
# >**Data Abstraction in Python**
#
# Data abstraction in Python is a programming concept that hides complex implementation details while exposing only essential information and functionalities to users. In Python, we can achieve data abstraction by using abstract classes and abstract classes can be created using abc (abstract base class) module and abstractmethod of abc module.
#
# >**Abstraction classes in Python**
#
# Abstract class is a class in which one or more abstract methods are defined. When a method is declared inside the class without its implementation is known as abstract method.
#
# **Abstract Method:**
# In Python, abstract method feature is not a default feature. To create abstract method and abstract classes we have to import the “ABC” and “abstractmethod” classes from abc (Abstract Base Class) library. Abstract method of base class force its child class to write the implementation of the all abstract methods defined in base class. If we do not implement the abstract methods of base class in the child class then our code will give error.

# %% [markdown]
# >**Introduction**
#
# Let us assume that we have a Product class , all items being sold in our online app and extend this Product class.
#
# ![image.png](data:image/png;base64,...)
#
# In an online shopping app, we only have specific types of products. We don’t have something called a Product itself. In that sense, an object of Product class would not represent a real world object, because a Product is just an abstract concept. While shopping, we purchase types of products, not a product itself. Thus the best practice is not to create object of the parent class.

# %% [markdown]
# >**note**
#
# Since we are the creator of the Product class, we know it is abstract in nature and we won’t create an instance for it. But how can another programmer know about it? How can we ensure that some other developer does not end up creating an object of such an abstract class?

# %% [markdown]
# We can programmatically declare a class as an abstract class. An abstract class should not be instantiated.
#
# Note: In python, you will not get an error if you try to instantiate it. However, in languages like Java, C++, C# you will get an error if you try to instantiate an abstract class

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# an abstract class should never be instantiated, then what is the use of such a class? The only way we can use an abstract class is to make other classes inherit from the abstract class. An abstract class is meant to be sub classed

# %% [markdown]
# Let us extend the concept of abstract further. All products must have a return_policy() method which will display the number of days within which the products have to be returned

# %%
class Product:
    def return_policy(self):
        pass
class Mobile(Product):
    pass
class Shoe(Product):
    pass

# %% [markdown]
# >**Need for Abstract Method - Scenario 1**
#
# **Problem Statement**
#
# Now each type of product will have its own return_policy(), so we will override the return_policy() in each of the child classes.

# %%
class Product:
    def return_policy(self):
        pass

class Mobile(Product):
    def return_policy(self):
        print("All mobiles must be returned within 10 days of purchase")

class Shoe(Product):
    def return_policy(self):
        print("All shoes must be returned within 7 days of purchase")

m=Mobile()
m.return_policy()

s=Shoe()
s.return_policy()
# Out:
# All mobiles must be returned within 10 days of purchase
# All shoes must be returned within 7 days of purchase

# %% [markdown]
# **Problem Statement**
#
# Since the return_policy() is overridden in each of the child classes, the parent class return_policy() is never used and hence it becomes redundant.

# %% [markdown]
# By mistake we have forgotten to override the return_policy() in the Furniture class. If someone tries to find the return_policy() of furniture by invoking the method, it will invoke the redundant return_policy() of the parent

# %%
from abc import ABCMeta
class Product(metaclass=ABCMeta):
    def return_policy(self):
        pass
class Furniture(Product):
    pass

# %% [markdown]
# **Problem Statement**
#
# How can we ensure that all subclasses of the Product class must mandatorily override the return_policy()?

# %%
from abc import ABCMeta
class product(metaclass = ABCMeta):
  def return_policy(self):
    pass

class furneture(product):
  pass

class mobile(product):

  def return_policy(self):
      print("All mobiles must be returned within 10 days of purchase")

class shoe(product):

  def return_policy(self):
     print("All shoes must be returned within 7 days of purchase")

# %% [markdown]
# >**Declaring Abstract Method - Try out**
#
# **Problem Statement**
#
# If we programmatically declare our return_policy() of Product class as an abstract method, then every sub-class of Product class MUST override the abstract method. We can make our return_policy() an abstract method as shown below:

# %%
from abc import ABCMeta,abstractmethod
class product(metaclass = ABCMeta):
  @abstractmethod
  def return_policy(self):
    pass

# %% [markdown]
# >**Instantiating Abstract Class - Try out**
#
# **Problem Statement**
#
# Even if one method is abstract, then we will get an error if we try to instantiate the class.

# %%
from abc import ABCMeta,abstractmethod
class product(metaclass = ABCMeta):
  @abstractmethod
  def return_policy(self):
    pass

product()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-f12c2d797201> in <cell line: 7>()
#       5     pass
#       6
# ----> 7 product()
#
# TypeError: Can't instantiate abstract class product with abstract method return_policy

# %% [markdown]
# >**Instantiating Abstract Subclass - Try out**
#
# **Problem Statement**
#
# If a method is abstract, then the Subclass must override the abstract method. Else we cannot instantiate the subclass also.

# %%
from abc import ABCMeta,abstractmethod
class product(metaclass = ABCMeta):
  @abstractmethod
  def return_policy(self):
    pass

class furniture(product):
  pass

furniture()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-e5e54ebe994d> in <cell line: 10>()
#       8   pass
#       9
# ---> 10 furniture()
#
# TypeError: Can't instantiate abstract class furniture with abstract method return_policy

# %% [markdown]
# >**Need not override abstract method - Try out**
#
# **Problem Statement**
#
# If a child class overrides the abstract method, then its own child classes need not override the abstract method.

# %%
from abc import ABCMeta,abstractmethod
class product(metaclass = ABCMeta):
  @abstractmethod
  def return_policy(self):
    pass

class furniture(product):
  # overriding abstract class
  def return_policy(self):
     print("All furnitures must be returned within 10 days of purchase")

class sofa(furniture):
  pass

# it executes well because sofa ingerit the dat from furniture. so furniture class  alredy overrided the the abstract method
sofa()

# %% [markdown]
# >**Abstraction - summary**
#
# * Abstract classes should not be instantiated.
# * An abstract class may contain 0 or many abstract methods.
# * Usually the parent class is an abstract class.
# * Abstract classes are meant to be inherited.
# * If a class has an abstract method, then the class cannot be instantiated.
# * The child class must implement/override all the abstract methods of the * parent class. Else the child class cannot be instantiated.

# %% [markdown]
# implementation our item purchase code

# %% [markdown]
# **Hierarchical Inheritance with Abstraction**

# %%
from abc import abstractmethod

class product:
  @abstractmethod
  def buy(self):
    print("buying product....")
  @abstractmethod
  def return_phone(self):
    print("returning product...")


class clothes(product):
  def buy(self):# overriding abstract method
    print("buying clothes....")

  def return_phone(self):# overriding abstract method
    print("returning clothes...")


class phone(product):
  def __init__(self,brand,price,camera):
    self.brand = brand
    self.phone = phone
    self.camera = camera

  # methods
  #Features methods
  def features(self):
    print("from parent class")
    print(" Brand : ", self.brand,"\n","camera: ",self.camera,)


  def buy(self):# overriding abstract method
    print("buying phone....")

  def return_phone(self):# overriding abstract method
    print("returning phone...")

#child class 1
class featurePhone(phone):
  def __init__(self,brand,price,camera,style,size):
    self.style = style
    self.size = size
    super().__init__(brand,price,camera)



  def buy(self): # overriding abstract method
    print("buying a feature Phone with features...")
    print("\n Keypas Style : ",self.style,"\n","Display size :",self.size," inches")
    super().features()

#child class 2
class smartPhone(phone):
  def __init__(self,brand,price,camera,ram,rom):
    self.ram = ram
    self.rom = rom
    # inheriting constructor from parent to pass attributes to child directly on child object creation
    super().__init__(brand,price,camera)


  def buy(self): # overriding abstract method
    print("buying a smart phone with features...")
    print("\n Ram : ",self.ram,"\n","Rom :",self.rom)
    # method from parent even we are overriding the parent
    super().features()
 # Note:  we use super() when ever we want use menthd from parent  even the method is oveerided in child





smart1 = smartPhone("Samsung",50000,"108Px","8Gb","256 Gb")
keypad = featurePhone("Nokia",2500,"3Px","QWERTY keypad",2)

# calling child Method
smart1.buy()
print("\n -----------------------------------------")
keypad.buy()
# Out:
# buying a smart phone with features...
#
#  Ram :  8Gb
#  Rom : 256 Gb
# from parent class
#  Brand :  Samsung
#  camera:  108Px
#
#  -----------------------------------------
# buying a feature Phone with features...
#
#  Keypas Style :  QWERTY keypad
#  Display size : 2  inches
# from parent class
#  Brand :  Nokia
#  camera:  3Px
