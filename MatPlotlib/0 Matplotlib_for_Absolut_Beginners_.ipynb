# %%
import numpy as np
import pandas as pd

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
#  ## Matplotlib
#  is a low level graph plotting library in python that serves as a visualization utility.
#
# Matplotlib was created by John D. Hunter.
#
# Matplotlib is open source and we can use it freely.
#
# Matplotlib is mostly written in python, a few segments are written in C, Objective-C and Javascript for Platform compatibility.

# %%
x_points = np.array([1,8])
y_points = np.array([19,33])

plt.plot(x_points,y_points)
plt.show()

# %% [markdown]
# **Plotting x and y points:**
#
# The plot() function is used to draw points (markers) in a diagram.
#
# By default, the plot() function draws a line from point to point.
#
# The function takes parameters for specifying points in the diagram.
#
# Parameter 1 is an array containing the points on the x-axis.
#
# Parameter 2 is an array containing the points on the y-axis.
#
# If we need to plot a line from (1, 8) to (19, 33), we have to pass two arrays [1, 19] and [8, 33] to the plot function.

# %% [markdown]
#  > **Plotting Without Line**
#
#
# To plot only the markers, you can use shortcut string notation parameter 'o', which means 'rings'.

# %%
x_points = np.array([1,8])
y_points = np.array([19,33])

plt.plot(x_points,y_points,'o')

# %% [markdown]
# > **Multiple Points**
#
# You can plot as many points as you like, just make sure you have the same number of points in both axis.

# %%
x_points = np.array([1,3,6,9])
y_points = np.array([3,21,6,30])

plt.plot(x_points,y_points)
plt.show()

# %% [markdown]
# > **Default X-Points**
#
# If we do not specify the points on the x-axis, they will get the default values 0, 1, 2, 3 etc., depending on the length of the y-points.

# %%
y_points = np.array([3, 8, 1, 10, 5, 7])

plt.plot(y_points)
plt.show()

# %% [markdown]
# > **Markers**
#
# You can use the keyword argument marker to emphasize each point with a specified marker:

# %%
y_points = np.array([3, 8, 1, 10, 5, 7])

plt.plot(y_points,marker='o')
plt.show()

# %%
y_points = np.array([3, 8, 1, 10, 5, 7])

plt.plot(y_points,marker='*')
plt.show()

# %% [markdown]
# Marker Reference
#
# Marker	Description
#
# 'o'	Circle
# '*'	Star
# '.'	Point
# ','	Pixel
# 'x'	X
# 'X'	X (filled)
# '+'	Plus
# 'P'	Plus (filled)
# 's'	Square
# 'D'	Diamond
# 'd'	Diamond (thin)
# 'p'	Pentagon
# 'H'	Hexagon
# 'h'	Hexagon
# refer docs for more*

# %% [markdown]
# > **Format Strings fmt**
#
# You can also use the shortcut string notation parameter to specify the marker.
#
# This parameter is also called fmt, and is written with this syntax:
#
# marker|line|color

# %%
y_points = np.array([3, 8, 1, 10, 5, 7])
plt.plot(y_points,'D--r')
plt.show()

# %%
plt.plot(y_points,'*:b')
plt.show()

# %% [markdown]
# **Line Reference**
#
# '-'    	Solid line
# ':'   	Dotted line
# '--'   	Dashed line
# '-.'   	Dashed/dotted line

# %% [markdown]
# > **Marker Size**
#
# Marker size -----ms

# %%
plt.plot(y_points,marker='o',ms=20)
plt.show()

# %% [markdown]
# **Marker Color**
#
# markeredgecolor  --- mec

# %%
plt.plot(y_points,marker='o',ms=20,mec= 'r')
plt.show()

# %% [markdown]
# You can use the keyword argument markerfacecolor or the shorter mfc to set the color inside the edge of the markers:

# %%
plt.plot(y_points,marker='o',ms=20,mec='r',mfc='g')
# we can also use hexadecinal or color names

# %% [markdown]
# **Linestyle**
#
# line style ---- ls

# %%
plt.plot(y_points,ls='dotted')

# %%
plt.plot(y_points,ls='dashed')

# %% [markdown]
# **Line Color**
#
# line color-----lc

# %%
plt.plot(y_points,ls='dashed',c='#4CAF50')

# %% [markdown]
# **Line Width**  lw

# %%
plt.plot(y_points,ls='solid',c='g',lw=15.5)

# %% [markdown]
# > **Multiple Lines**
#
# You can plot as many lines as you like by simply adding more plt.plot() functions:

# %%
y1 = np.array([1,7,3,10])
y2=np.array([4,6,2,9,1])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %% [markdown]
# In the examples above we only specified the points on the y-axis, meaning that the points on the x-axis got the the default values (0, 1, 2, 3).

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %%
# with only Y values
y2 = np.array([1, 10, 6,10])
y1 = np.array([3, 8, 1, 10])
y3 = np.array([0, 1, 2, 3])
y4 = np.array([6, 2, 7, 11])

plt.plot(y1,marker='D',c='r',mec='b',mfc='w',ls='dotted')
plt.plot(y2, marker='*',c='g',mec='#ff471a',mfc='b',ms=10,ls='dashdot')
plt.plot(y3,marker='p',c='hotpink',mec='b',mfc='w',ls='dashed')
plt.plot(y4,marker='o',c='b',mec='b',mfc='w',ls='solid')
plt.show()

# %%
plt.plot(y1)
plt.plot(y2)
plt.plot(y3)
plt.plot(y4)
plt.show()

# %% [markdown]
# > **Labels and Title**
#
# With Pyplot, you can use the xlabel() and ylabel() functions to set a label for the x- and y-axis.

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.xlabel('X Axis label')
plt.ylabel('Y axis label')
plt.title('Chat Title')
plt.show()

# %% [markdown]
# > **Set Font Properties for Title and Labels**
#
# You can use the fontdict parameter in xlabel(), ylabel(), and title() to set font properties for the title and labels.

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.plot(x1, y1, x2, y2)
plt.xlabel('X Axis label',fontdict=font2,)
plt.ylabel('Y axis label',fontdict=font2)
plt.title('Chat Title',fontdict=font1)
plt.show()

# %% [markdown]
# > **Position the Title**
#
# You can use the loc parameter in title() to position the title.
#
# Legal values are: 'left', 'right', and 'center'. Default value is 'center'.

# %%
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.plot(x1, y1, x2, y2)
plt.xlabel('X Axis label',fontdict=font2)
plt.ylabel('Y axis label',fontdict=font2)
plt.title('Chat Title',fontdict=font1,loc='left')
plt.show()

# %% [markdown]
# > **Add Grid Lines to a Plot**
#
# With Pyplot, you can use the grid() function to add grid lines to the plot.

# %%
plt.plot(x1, y1, x2, y2)
plt.grid()
plt.show()

# %% [markdown]
# **Specify Which Grid Lines to Display**
#
# You can use the axis parameter in the grid() function to specify which grid lines to display.
#
# Legal values are: 'x', 'y', and 'both'. Default value is 'both'.

# %%
plt.plot(x1,y1,x2,y2)
plt.grid(axis='x')
plt.show()

# %%
plt.plot(x1,y1,x2,y2)
plt.grid(axis='y')
plt.show()

# %%
plt.plot(x1,y1,x2,y2)
plt.grid(axis='both',color='g',ls='dashdot',lw=0.6)
plt.show()

# %% [markdown]
# ### Matplotlib Subplot
#
# > **Display Multiple Plots**
#
# With the subplot() function you can draw multiple plots in one figure:

# %%
#plot 1:
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
#the figure has 1 row, 2 columns, and this plot is the first plot.
plt.plot(x1,y1)

#plot 2:
x2 = np.array([0, 1, 2, 3])
y2 = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
#the figure has 1 row, 2 columns, and this plot is the second plot.
plt.plot(x2,y2)

plt.show()

# %%
# for vertical subplots
plt.subplot(2,1,1)
plt.plot(x1,y1)
plt.grid(axis='y')



plt.subplot(2,1,2)
plt.plot(x2,y2)
plt.grid(axis='x')
plt.show()

# %%
# we can drow many plots like this
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
# we can drow many plots like this
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)
plt.grid(c='g',ls="dashdot")

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)
plt.grid(c='r',ls="dashed")

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)
plt.grid(c='#9900cc',ls="dotted")

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)
plt.grid(c='g',ls="dashdot")

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)
plt.grid(c='r',ls="dashed")

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)
plt.grid(c='#9900cc',ls="dotted")

plt.show()

# %%
# add titles
#plot1
plt.subplot(1,2,1)
plt.plot(x1,y1)
plt.title('sales')

#plot2
plt.subplot(1,2,2)
plt.plot(x2,y2)
plt.title('Income')

plt.suptitle('delevery outcomes')
plt.show()
# dont write anthing after show
#it cont be displayedd inn graf

# %% [markdown]
# ## Scatter Plots

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y)
plt.show()

# %% [markdown]
# The observation in the example above is the result of 13 cars passing by.
#
# The X-axis shows how old the car is.
#
# The Y-axis shows the speed of the car when it passes.
#
# It seems that the newer the car, the faster it drives, but that could be a coincidence, after all we only registered 13 cars.

# %% [markdown]
# > **Compare Plots**
#
# In the example above, there seems to be a relationship between speed and age, but what if we plot the observations from another day as well? Will the scatter plot tell us something else?

# %%
#day one, the age and speed of 13 cars:
x1 = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y1 = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x1, y1)

#day two, the age and speed of 15 cars:
x2 = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y2 = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x2, y2)

plt.show()

# %% [markdown]
# > **Colors**

# %%
plt.scatter(x1,y1,color='r')
plt.scatter(x2,y2,color='g')
plt.show()

# %% [markdown]
# > **Color Each Dot**
#
# You can even set a specific color for each dot by using an array of colors as value for the c argument:

# %%
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta","hotpink","lightgreen"])
plt.scatter(x,y,c=colors)

# %% [markdown]
# > **color MAP**
#
# You can specify the colormap with the keyword argument cmap with the value of the colormap, in this case 'viridis' which is one of the built-in colormaps available in Matplotlib.
#
# In addition you have to create an array with values (from 0 to 100), one value for each point in the scatter plot:

# %%
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70,75, 80, 90,95, 100])
plt.scatter(x,y,c=colors,cmap='viridis')
plt.show()

# %% [markdown]
# You can include the colormap in the drawing by including the plt.colorbar() statement:

# %%
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70,75, 80, 90,95, 100])
plt.scatter(x,y,c=colors,cmap='viridis')
plt.colorbar()
plt.show()

# %% [markdown]
# > there is lot of color map type you can refer docs to know more about colorMap type

# %% [markdown]
# > **Size**
#
# You can change the size of the dots with the s argument.

# %%
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75,88,91])
plt.scatter(x,y,s=sizes)
plt.xlabel("age of the CAR")
plt.ylabel("Speed of the CAR")
plt.show()

# %% [markdown]
# > **Alpha**
#
# You can adjust the transparency of the dots with the alpha argument.

# %%
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75,88,91])
plt.scatter(x,y,s=sizes,alpha=0.5)
plt.xlabel("age of the CAR")
plt.ylabel("Speed of the CAR")
plt.show()

# %% [markdown]
# > **Combine Color Size and Alpha**
#
# You can combine a colormap with different sizes of the dots. This is best visualized if the dots are transparent:

# %%
x= np.random.randint(100,size=100)
y= np.random.randint(100,size=100)
colors=np.random.randint(100,size=100)
sizes= np.random.randint(100,size=100)

plt.scatter(x,y,s=sizes,c=colors,cmap='nipy_spectral',alpha=0.6)
plt.colorbar()
plt.show()

# %%
x= np.random.randint(100,size=100)
y= np.random.randint(100,size=100)
colors=np.random.randint(100,size=100)
# improvments in sizes
sizes= 5* np.random.randint(100,size=100)

plt.scatter(x,y,s=sizes,c=colors,cmap='nipy_spectral',alpha=0.6)
plt.colorbar()
plt.show()

# %% [markdown]
#  ## Bars plots

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %% [markdown]
# > **Horizontal Bars**

# %%
plt.barh(x,y)
plt.show()

# %% [markdown]
# > **Bar Color**

# %%
plt.barh(x,y,color='g')
plt.show()

# %% [markdown]
#  we can also use hashcodes for colors

# %% [markdown]
# **bar Width**

# %%
plt.bar(x,y,color='r',width=0.3)
plt.show()

# %% [markdown]
# **Bar Hieght**
#
# for horizantal plots we use hieght

# %%
plt.barh(x,y,height=0.3)
plt.show()

# %% [markdown]
# ## Histogram
#
# A histogram is a graph showing frequency distributions.
#
# It is a graph showing the number of observations within each given interval.
#
#
# For simplicity we use NumPy to randomly generate an array with 250 values, where the values will concentrate around 170, and the standard deviation is 10.

# %%
x= np.random.normal(170,10,200)
x
# Out:
# array([171.93467313, 175.04869358, 178.34243281, 152.54644784,
#        165.92260277, 171.80301497, 169.77900507, 173.15974403,
#        161.97520755, 181.37966926, 177.375603  , 151.51116605,
#        173.6890282 , 167.00671768, 189.35953765, 164.73424047,
#        159.86361359, 150.12389976, 176.11990327, 173.87171599,
#        165.43518234, 168.64019003, 158.07037907, 181.35770237,
#        169.87596885, 187.89023201, 160.85527062, 173.50892437,
#        167.40061307, 187.32628765, 164.92984841, 152.19578272,
#        154.71095661, 180.27863532, 156.5922482 , 177.92797198,
#        163.85617116, 165.84931462, 157.53039603, 162.51475992,
#        177.43630615, 167.15590633, 156.18745087, 183.49663069,
#        166.19390229, 160.64564985, 165.54217954, 160.24776171,
#        156.48864845, 174.06070701, 180.72564268, 155.09314114,
#        168.37918429, 177.64490578, 176.55933396, 164.51544547,
#        173.69972623, 160.2115513 , 163.20434356, 157.50232969,
# ...

# %%
# nomal distributed data
x= np.random.normal(170,10,200)
plt.hist(x)
plt.show()

# %%
y = np.linspace(1,100,100,endpoint=False,retstep=False)
y
# Out:
# array([ 1.  ,  1.99,  2.98,  3.97,  4.96,  5.95,  6.94,  7.93,  8.92,
#         9.91, 10.9 , 11.89, 12.88, 13.87, 14.86, 15.85, 16.84, 17.83,
#        18.82, 19.81, 20.8 , 21.79, 22.78, 23.77, 24.76, 25.75, 26.74,
#        27.73, 28.72, 29.71, 30.7 , 31.69, 32.68, 33.67, 34.66, 35.65,
#        36.64, 37.63, 38.62, 39.61, 40.6 , 41.59, 42.58, 43.57, 44.56,
#        45.55, 46.54, 47.53, 48.52, 49.51, 50.5 , 51.49, 52.48, 53.47,
#        54.46, 55.45, 56.44, 57.43, 58.42, 59.41, 60.4 , 61.39, 62.38,
#        63.37, 64.36, 65.35, 66.34, 67.33, 68.32, 69.31, 70.3 , 71.29,
#        72.28, 73.27, 74.26, 75.25, 76.24, 77.23, 78.22, 79.21, 80.2 ,
#        81.19, 82.18, 83.17, 84.16, 85.15, 86.14, 87.13, 88.12, 89.11,
#        90.1 , 91.09, 92.08, 93.07, 94.06, 95.05, 96.04, 97.03, 98.02,
#        99.01])

# %%
plt.hist(y)
plt.show()

# %% [markdown]
# ## Pie Charts
#
# Creating Pie Charts
# With Pyplot, you can use the pie() function to draw pie charts:

# %%
y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %% [markdown]
# As you can see the pie chart draws one piece (called a wedge) for each value in the array (in this case [35, 25, 25, 15]).
#
# By default the plotting of the first wedge starts from the x-axis and moves counterclockwise:

# %% [markdown]
# > **labels**

# %%
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y,labels=mylabels)
plt.show()

# %% [markdown]
# > **Explode**
#
# Maybe you want one of the wedges to stand out? The explode parameter allows you to do that.
#
# The explode parameter, if specified, and not None, must be an array with one value for each wedge.
#
# Each value represents how far from the center each wedge is displayed:

# %%
myexplode = [0.2, 0, 0, 0]
plt.pie(y,labels=mylabels,explode=myexplode)
plt.show()

# %%
myexplode = [0.01, 0.01, 0.01, 0.09]
plt.pie(y,labels=mylabels,explode=myexplode)
plt.show()

# %% [markdown]
# > **Shadow**
#
# Add a shadow to the pie chart by setting the shadows parameter to True:

# %%
myexplode = [0.1, 0.01, 0.01, 0.01]
plt.pie(y,labels=mylabels,explode=myexplode,shadow=True)
plt.show()

# %%
# we can also give colors
mycolors = ["r", "gold", "OrangeRed", "#F08080"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %%
# adding legends #A0522D
mycolors = ["r", "gold", "OrangeRed", "#CD853F"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.legend(title= 'four fruits')
plt.show()

# %%
# setting legend placment
mycolors = ["r", "gold", "FireBrick", "#CD853F"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.legend(title= 'four fruits',loc ='upper left')
plt.show()
