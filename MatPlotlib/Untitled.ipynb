# %%
import numpy as np
import pandas as pd
import json

# %%
import requests
res = requests.get('https://api.spacexdata.com/v3/missions')

# %%
res
# Out:
# <Response [200]>

# %%
data = res.json()

# %%
data
# Out:
# [{'mission_name': 'Thaicom',
#   'mission_id': '9D1B7E0',
#   'manufacturers': ['Orbital ATK'],
#   'payload_ids': ['Thaicom 6', 'Thaicom 8'],
#   'wikipedia': 'https://en.wikipedia.org/wiki/Thaicom',
#   'website': 'http://www.thaicom.net/en/satellites/overview',
#   'twitter': 'https://twitter.com/thaicomplc',
#   'description': 'Thaicom is the name of a series of communications satellites operated from Thailand, and also the name of Thaicom Public Company Limited, which is the company that owns and operates the Thaicom satellite fleet and other telecommunication businesses in Thailand and throughout the Asia-Pacific region. The satellite projects were named Thaicom by the King of Thailand, His Majesty the King Bhumibol Adulyadej, as a symbol of the linkage between Thailand and modern communications technology.'},
#  {'mission_name': 'Telstar',
#   'mission_id': 'F4F83DE',
#   'manufacturers': ['SSL'],
#   'payload_ids': ['Telstar 19V', 'Telstar 18V'],
# ...

# %%
pd.DataFrame(data)
# Out:
#                    mission_name mission_id  \
# 0                       Thaicom    9D1B7E0
# 1                       Telstar    F4F83DE
# 2                  Iridium NEXT    F3364BF
# 3  Commercial Resupply Services    EE86F74
# 4                           SES    6C42550
# 5                         JCSAT    FE3533D
# 6                       AsiaSat    593B499
# 7                   Orbcomm OG2    CE91D46
# 8                           ABS    2CF444A
# 9                      Eutelsat    F7709F2
#
#                                      manufacturers  \
# 0                                    [Orbital ATK]
# 1                                            [SSL]
# 2                                    [Orbital ATK]
# 3                                         [SpaceX]
# 4  [Orbital ATK, Boeing, Airbus Defence and Space]
# 5                                            [SSL]
# 6                                            [SSL]
# 7                      [Sierra Nevada Corporation]
# ...

# %%
res1 = requests.get("https://api.spacexdata.com/v4/launches/past")
res1
# Out:
# <Response [200]>

# %%
spaceX_data = res1.json()

# %%
df = pd.DataFrame(spaceX_data)

# %%
df.head(5)
# Out:
#                                             fairings  \
# 0  {'reused': False, 'recovery_attempt': False, '...
# 1  {'reused': False, 'recovery_attempt': False, '...
# 2  {'reused': False, 'recovery_attempt': False, '...
# 3  {'reused': False, 'recovery_attempt': False, '...
# 4  {'reused': False, 'recovery_attempt': False, '...
#
#                                                links  \
# 0  {'patch': {'small': 'https://images2.imgbox.co...
# 1  {'patch': {'small': 'https://images2.imgbox.co...
# 2  {'patch': {'small': 'https://images2.imgbox.co...
# 3  {'patch': {'small': 'https://images2.imgbox.co...
# 4  {'patch': {'small': 'https://images2.imgbox.co...
#
#        static_fire_date_utc  static_fire_date_unix    net  window  \
# 0  2006-03-17T00:00:00.000Z           1.142554e+09  False     0.0
# 1                      None                    NaN  False     0.0
# 2                      None                    NaN  False     0.0
# ...

# %%
spaceX_data[1]
# Out:
# {'fairings': {'reused': False,
#   'recovery_attempt': False,
#   'recovered': False,
#   'ships': []},
#  'links': {'patch': {'small': 'https://images2.imgbox.com/f9/4a/ZboXReNb_o.png',
#    'large': 'https://images2.imgbox.com/80/a2/bkWotCIS_o.png'},
#   'reddit': {'campaign': None,
#    'launch': None,
#    'media': None,
#    'recovery': None},
#   'flickr': {'small': [], 'original': []},
#   'presskit': None,
#   'webcast': 'https://www.youtube.com/watch?v=Lk4zQ2wP-Nc',
#   'youtube_id': 'Lk4zQ2wP-Nc',
#   'article': 'https://www.space.com/3590-spacex-falcon-1-rocket-fails-reach-orbit.html',
#   'wikipedia': 'https://en.wikipedia.org/wiki/DemoSat'},
#  'static_fire_date_utc': None,
#  'static_fire_date_unix': None,
#  'net': False,
#  'window': 0,
#  'rocket': '5e9d0d95eda69955f709d1eb',
#  'success': False,
#  'failures': [{'time': 301,
#    'altitude': 289,
#    'reason': 'harmonic oscillation leading to premature engine shutdown'}],
# ...

# %%
getrocket(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13456\3746841246.py in <module>
# ----> 1 getrocket(df)
#
# NameError: name 'getrocket' is not defined

# %%
df = df[['rocket', 'payloads', 'launchpad', 'cores', 'flight_number', 'date_utc']]

# %%
df
# Out:
#                        rocket  \
# 0    5e9d0d95eda69955f709d1eb
# 1    5e9d0d95eda69955f709d1eb
# 2    5e9d0d95eda69955f709d1eb
# 3    5e9d0d95eda69955f709d1eb
# 4    5e9d0d95eda69955f709d1eb
# ..                        ...
# 182  5e9d0d95eda69973a809d1ec
# 183  5e9d0d95eda69973a809d1ec
# 184  5e9d0d95eda69973a809d1ec
# 185  5e9d0d95eda69973a809d1ec
# 186  5e9d0d95eda69973a809d1ec
#
#                                               payloads  \
# 0                           [5eb0e4b5b6c3bb0006eeb1e1]
# 1                           [5eb0e4b6b6c3bb0006eeb1e2]
# 2    [5eb0e4b6b6c3bb0006eeb1e3, 5eb0e4b6b6c3bb0006e...
# 3                           [5eb0e4b7b6c3bb0006eeb1e5]
# 4                           [5eb0e4b7b6c3bb0006eeb1e6]
# ..                                                 ...
# 182  [631614e9ffc78f3b85670717, 631617fbffc78f3b856...
# 183  [63161610ffc78f3b85670718, 63161872ffc78f3b856...
# 184                         [63161699ffc78f3b85670719]
# ...

# %%
BoosterVersion = []

# %%
BoosterVersion
# Out:
# []

# %%
getBoosterVersion(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13456\1223516396.py in <module>
# ----> 1 getBoosterVersion(df)
#
# NameError: name 'getBoosterVersion' is not defined

# %%
ers2 = requests.get('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/API_call_spacex_api.json')

# %%
ers2
# Out:
# <Response [200]>

# %%
res2 = ers2.json()

# %%
import requests
res3 = requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')
res3
# Out:
# <Response [200]>

# %%
data = pd.DataFrame(res2)

# %%
data.head()
# Out:
#                                             fairings  \
# 0  {'reused': False, 'recovery_attempt': False, '...
# 1  {'reused': False, 'recovery_attempt': False, '...
# 2  {'reused': False, 'recovery_attempt': False, '...
# 3  {'reused': False, 'recovery_attempt': False, '...
# 4  {'reused': False, 'recovery_attempt': False, '...
#
#                                                links  \
# 0  {'patch': {'small': 'https://images2.imgbox.co...
# 1  {'patch': {'small': 'https://images2.imgbox.co...
# 2  {'patch': {'small': 'https://images2.imgbox.co...
# 3  {'patch': {'small': 'https://images2.imgbox.co...
# 4  {'patch': {'small': 'https://images2.imgbox.co...
#
#        static_fire_date_utc  static_fire_date_unix    tbd    net  window  \
# 0  2006-03-17T00:00:00.000Z           1.142554e+09  False  False     0.0
# 1                      None                    NaN  False  False     0.0
# 2                      None                    NaN  False  False     0.0
# ...

# %%
res3 = res3.json()

# %%
data_new = pd.DataFrame(res3,columns=['title','state','created_at','updated_at','open_issues','closed_issues'])

# %%
data3.head()
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
# ...

# %%
data_new
# Out:
#                                                 title state  \
# 0         DOC: Added depr note to swapaxes docstrings  open
# 1   BUILD: fail to compile for x86_64 architecture...  open
# 2   DOC: description of record_prefix param for js...  open
# 3   TST:add tests for kurt in integer/test_reducti...  open
# 4             CoW: Set refs properly for non CoW mode  open
# 5   CoW: Avoid unnecessary copies for columnwise r...  open
# 6   CoW: Copy less in replace implementation with ...  open
# 7       ENH: .shift optionally takes multiple periods  open
# 8              CoW: Adjust test to cover missing case  open
# 9          CoW: Avoid unnecessary writeable=False ops  open
# 10  CoW: Fix test that is failing with new arrow v...  open
# 11  CoW: Avoid tracking references in delete if no...  open
# 12                      CI: Fix pyarrow nightly build  open
# 13  ENH: support argmin/max, idxmin/max with objec...  open
# 14  DOC: Make code formatting corrections in `read...  open
# ...

# %%
res3[0]['user']
# Out:
# {'login': 'DeaMariaLeon',
#  'id': 11835246,
#  'node_id': 'MDQ6VXNlcjExODM1MjQ2',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/11835246?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/DeaMariaLeon',
#  'html_url': 'https://github.com/DeaMariaLeon',
#  'followers_url': 'https://api.github.com/users/DeaMariaLeon/followers',
#  'following_url': 'https://api.github.com/users/DeaMariaLeon/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/DeaMariaLeon/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/DeaMariaLeon/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/DeaMariaLeon/subscriptions',
#  'organizations_url': 'https://api.github.com/users/DeaMariaLeon/orgs',
#  'repos_url': 'https://api.github.com/users/DeaMariaLeon/repos',
#  'events_url': 'https://api.github.com/users/DeaMariaLeon/events{/privacy}',
# ...

# %%
listb = []
for i in range(len(res3)):
    listb.append(res3[i]['user'])
user = pd.DataFrame(listb,columns=['login','id','node_id','type','site_admin'])

# %%
user.head()
# Out:
#            login        id               node_id  type  site_admin
# 0   DeaMariaLeon  11835246  MDQ6VXNlcjExODM1MjQ2  User       False
# 1  subhashsharma   4167913  MDQ6VXNlcjQxNjc5MTM=  User       False
# 2       wjandrea  22385371  MDQ6VXNlcjIyMzg1Mzcx  User       False
# 3     topper-123  26364415  MDQ6VXNlcjI2MzY0NDE1  User       False
# 4          phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0  User       False

# %%
res3
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54125',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54125/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54125/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54125/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54125',
#   'id': 1804645339,
#   'node_id': 'PR_kwDOAA0YD85VgeXm',
#   'number': 54125,
#   'title': 'DOC: Added depr note to swapaxes docstrings',
#   'user': {'login': 'DeaMariaLeon',
#    'id': 11835246,
#    'node_id': 'MDQ6VXNlcjExODM1MjQ2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11835246?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DeaMariaLeon',
#    'html_url': 'https://github.com/DeaMariaLeon',
# ...

# %%
type(res3[1]['milestone'])
# Out:
# NoneType

# %%
lis= []
for i in range(len(res3)):
    if type(res3[i]['milestone'])=='NoneType':
        lis.append('NAN')
    else:
        lis.append(res3[i]['milestone']['creator'])
df3 = pd.DataFrame(ils,columns=['login','id','type','site_admin'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13456\830624531.py in <module>
#       4         lis.append('NAN')
#       5     else:
# ----> 6         lis.append(res3[i]['milestone']['creator'])
#       7 df3 = pd.DataFrame(ils,columns=['login','id','type','site_admin'])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
keys
# Out:
# ['login',
#  'id',
#  'node_id',
#  'avatar_url',
#  'gravatar_id',
#  'url',
#  'html_url',
#  'followers_url',
#  'following_url',
#  'gists_url',
#  'starred_url',
#  'subscriptions_url',
#  'organizations_url',
#  'repos_url',
#  'events_url',
#  'received_events_url',
#  'type',
#  'site_admin']

# %% [markdown]
# ## there is no use with creator becauese only one creator avalible in total res3
# **but fot our undrestanding**

# %%
try:
    lis= []
    for i in range(len(res3)):
        lis.append(res3[i]['milestone']['creator'])
    #df3 = pd.DataFrame(ils,columns=['login','id','type','site_admin'])
except Exception as e:
    dic = {}
    for i in range(18):
        for k in keys:
            dic.update({k:'NAN'})
    lis.append(dic)

# %%
lis
# Out:
# [{'login': 'phofl',
#   'id': 61934744,
#   'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/phofl',
#   'html_url': 'https://github.com/phofl',
#   'followers_url': 'https://api.github.com/users/phofl/followers',
#   'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#   'organizations_url': 'https://api.github.com/users/phofl/orgs',
#   'repos_url': 'https://api.github.com/users/phofl/repos',
#   'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/phofl/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'NAN',
# ...

# %%
df3 = pd.DataFrame(lis,columns=['login','id','type','site_admin'])

# %%
df3
# Out:
#    login        id  type site_admin
# 0  phofl  61934744  User      False
# 1    NAN       NAN   NAN        NAN

# %%
dic = {}
for i in range(len(res3[i]['milestone']['creator'])):
    for k in keys:
        dic.update({k:'NAN'})

# %%
dic
# Out:
# {'login': 'NAN',
#  'id': 'NAN',
#  'node_id': 'NAN',
#  'avatar_url': 'NAN',
#  'gravatar_id': 'NAN',
#  'url': 'NAN',
#  'html_url': 'NAN',
#  'followers_url': 'NAN',
#  'following_url': 'NAN',
#  'gists_url': 'NAN',
#  'starred_url': 'NAN',
#  'subscriptions_url': 'NAN',
#  'organizations_url': 'NAN',
#  'repos_url': 'NAN',
#  'events_url': 'NAN',
#  'received_events_url': 'NAN',
#  'type': 'NAN',
#  'site_admin': 'NAN'}

# %% [markdown]
# ## combine all data

# %%
data_new.head()
# Out:
#                                                title state  \
# 0        DOC: Added depr note to swapaxes docstrings  open
# 1  BUILD: fail to compile for x86_64 architecture...  open
# 2  DOC: description of record_prefix param for js...  open
# 3  TST:add tests for kurt in integer/test_reducti...  open
# 4            CoW: Set refs properly for non CoW mode  open
#
#              created_at            updated_at  open_issues  closed_issues
# 0  2023-07-14T10:38:09Z  2023-07-14T11:05:40Z          NaN            NaN
# 1  2023-07-14T07:53:54Z  2023-07-14T07:53:54Z          NaN            NaN
# 2  2023-07-13T23:44:46Z  2023-07-13T23:44:46Z          NaN            NaN
# 3  2023-07-13T22:26:13Z  2023-07-13T22:26:13Z          NaN            NaN
# 4  2023-07-13T20:19:55Z  2023-07-13T23:36:02Z          NaN            NaN

# %%
creator = df3

# %%
creator
# Out:
#    login        id  type site_admin
# 0  phofl  61934744  User      False
# 1    NAN       NAN   NAN        NAN

# %%
user.head()
# Out:
#            login        id               node_id  type  site_admin
# 0   DeaMariaLeon  11835246  MDQ6VXNlcjExODM1MjQ2  User       False
# 1  subhashsharma   4167913  MDQ6VXNlcjQxNjc5MTM=  User       False
# 2       wjandrea  22385371  MDQ6VXNlcjIyMzg1Mzcx  User       False
# 3     topper-123  26364415  MDQ6VXNlcjI2MzY0NDE1  User       False
# 4          phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0  User       False

# %%
t_data = pd.concat([data_new,user])

# %%
t_data
# Out:
#                                                 title state  \
# 0         DOC: Added depr note to swapaxes docstrings  open
# 1   BUILD: fail to compile for x86_64 architecture...  open
# 2   DOC: description of record_prefix param for js...  open
# 3   TST:add tests for kurt in integer/test_reducti...  open
# 4             CoW: Set refs properly for non CoW mode  open
# 5   CoW: Avoid unnecessary copies for columnwise r...  open
# 6   CoW: Copy less in replace implementation with ...  open
# 7       ENH: .shift optionally takes multiple periods  open
# 8              CoW: Adjust test to cover missing case  open
# 9          CoW: Avoid unnecessary writeable=False ops  open
# 10  CoW: Fix test that is failing with new arrow v...  open
# 11  CoW: Avoid tracking references in delete if no...  open
# 12                      CI: Fix pyarrow nightly build  open
# 13  ENH: support argmin/max, idxmin/max with objec...  open
# 14  DOC: Make code formatting corrections in `read...  open
# ...

# %%
data_new = data_new.join(user)

# %%
creator
# Out:
#    login        id  type site_admin
# 0  phofl  61934744  User      False
# 1    NAN       NAN   NAN        NAN

# %%
data_new.head(3)
# Out:
#                                                title state  \
# 0        DOC: Added depr note to swapaxes docstrings  open
# 1  BUILD: fail to compile for x86_64 architecture...  open
# 2  DOC: description of record_prefix param for js...  open
#
#              created_at            updated_at  open_issues  closed_issues  \
# 0  2023-07-14T10:38:09Z  2023-07-14T11:05:40Z          NaN            NaN
# 1  2023-07-14T07:53:54Z  2023-07-14T07:53:54Z          NaN            NaN
# 2  2023-07-13T23:44:46Z  2023-07-13T23:44:46Z          NaN            NaN
#
#            login        id               node_id  type  site_admin
# 0   DeaMariaLeon  11835246  MDQ6VXNlcjExODM1MjQ2  User       False
# 1  subhashsharma   4167913  MDQ6VXNlcjQxNjc5MTM=  User       False
# 2       wjandrea  22385371  MDQ6VXNlcjIyMzg1Mzcx  User       False

# %%
data_new.join(creator)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13456\1686292904.py in <module>
# ----> 1 data_new.join(creator)
#
# c:\users\ajay kumar\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9098         """
#    9099         return self._join_compat(
# -> 9100             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9101         )
#    9102
#
# c:\users\ajay kumar\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9136                 right_index=True,
#    9137                 suffixes=(lsuffix, rsuffix),
# -> 9138                 sort=sort,
#    9139             )
#    9140         else:
#
# ...

# %%
creator.columns = ['C_login','C_id','C_type','']
# Out:
# Index(['login', 'id', 'type', 'site_admin'], dtype='object')
