# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# # Matplotlib Getting Started

# %% [markdown]
# > **Creating Different Types of Plot**
#
# Line Graph in Matplotlib

# %%
x = [3, 1, 3]
y = [3, 2, 1]

plt.plot(x,y)
plt.legend('Line Chart')
plt.show()

# %% [markdown]
# > **Stem Plot in Matplotlib**
#
# A stem plot, also known as a stem-and-leaf plot, is a type of plot used to display data along a number line. Stem plots are particularly useful for visualizing discrete data sets, where the values are represented as “stems” extending from a baseline, with data points indicated as “leaves” along the stems. let’s understand the components of a typical stem plot:
#
# Stems: The stems represent the main values of the data and are typically drawn vertically along the y-axis.
# Leaves: The leaves correspond to the individual data points and are plotted horizontally along the stems.
# Baseline: The baseline serves as the reference line along which the stems are drawn.

# %%
x = np.linspace(0.1, 2 * np.pi, 41)
y = np.exp(np.sin(x))

plt.stem(x,y)
plt.show()

# %%
plt.stem(x,y,use_line_collection=True)
plt.subplot_tool()
plt.show()

# use_line_collection depreciated
# Out:
# <ipython-input-4-62ee93293d58>:1: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(x,y,use_line_collection=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-62ee93293d58> in <cell line: 2>()
#       1 plt.stem(x,y,use_line_collection=True)
# ----> 2 plt.subplot_tool()
#       3 plt.show()
#       4
#       5 # use_line_collection depreciated
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in subplot_tool(targetfig)
#    1732         return tb.trigger_tool("subplots")
#    1733     else:
# -> 1734         raise ValueError("subplot_tool can only be launched for figures with "
#    1735                          "an associated toolbar")
#    1736
#
# ValueError: subplot_tool can only be launched for figures with an associated toolbar

# %% [markdown]
# > **Bar chart in Matplotlib**

# %%
x = [3, 1, 3, 12, 2, 4, 4]
y = [3, 2, 1, 4, 5, 6, 7]

plt.bar(x,y,color='g')
plt.legend("BAR")
plt.show()

# %% [markdown]
# > **Histogram in Matplotlib**

# %%
x = [1, 2, 3, 4, 5, 6, 7, 4]

plt.hist(x,bins = [1, 2, 3, 4, 5, 6, 7])
plt.legend('bar')
plt.title("Histogram")
plt.show()

# %% [markdown]
# > **Scatter Plot in Matplotlib**

# %%
x = [3, 1, 3, 12, 2, 4, 4]
y = [3, 2, 1, 4, 5, 6, 7]

plt.scatter(x,y)
plt.title("Scatter Plot")
plt.legend("Points")
plt.show()

# %% [markdown]
# > **Stack Plot in Matplotlib**

# %%
days = [1, 2, 3, 4, 5]

# No of Study Hours
Studying = [7, 8, 6, 11, 7]

# No of Playing Hours
playing = [8, 5, 7, 8, 13]

plt.stackplot(days,Studying,playing,colors=['r','b'])
plt.xlabel("Days")
plt.ylabel("No of hours")
plt.title("Representation of Study and \
Playing wrt to Days")
plt.show()

# %% [markdown]
# > **Box Plot in Matplotlib**

# %%
np.random.seed(10)
data = np.random.normal(100, 20, 200)

plt.boxplot(data)
plt.show()

# %% [markdown]
# > **Pie Chart in Matplotlib**

# %%
x = np.array([1,2,3,4])
# explode
e =(0.1,0,0,0)

plt.pie(x,explode=e,shadow=True)
plt.title("Pie Chat")
plt.show()

# %% [markdown]
# > **Error Plot in Matplotlib**
#
#
# Error plots display the variability or uncertainty associated with each data point in a dataset. They are commonly used in scientific research, engineering, and statistical analysis to visualize measurement errors, confidence intervals, standard deviations, or other statistical properties of the data. By incorporating error bars into plots, we can convey not only the central tendency of the data but also the range of possible values around each point.

# %%
# making a simple plot
x =[1, 2, 3, 4, 5, 6, 7]
y =[1, 2, 1, 2, 1, 2, 1]

# creating error
y_error = 0.2

plt.plot(x,y)
plt.errorbar(x,y,yerr=y_error,fmt='D')
plt.show()

# %% [markdown]
# > **Violin Plot in Matplotlib**
#
# A violin plot is a method of visualizing the distribution of numerical data and its probability density. It is similar to a box plot but provides additional insights into the data’s distribution by incorporating a kernel density estimation (KDE) plot mirrored on each side. This allows for a more comprehensive understanding of the data’s central tendency, spread, and shape.

# %%
x = np.arange(-100,100)
plt.violinplot(x)
plt.show()

# %%
# creating list of uniform distributed values
uniform = np.arange(-100,101)
# creating list of normal distributed values
normal = np.random.normal(size=100)*30

# creating sub plots
fig, (ax1,ax2)= plt.subplots(1,2,figsize=(9,4))# it automatically adjust which is first plot which is second

#ploting violin plot for uniform distribution
ax1.violinplot(uniform)
ax1.set_ylabel('observed values')
ax1.set_title('Uniform Distribution')

#ploting violin plot for normal distribution
ax2.violinplot(normal)
ax2.set_title('normal distribution')

plt.suptitle("Distributions",fontsize=20)

plt.show()

# %% [markdown]
# > **3D Plots in Matplotlib**
#
# Sometimes, data visualization requires a three-dimensional perspective. We’ll delve into creating 3D plots to visualize complex relationships and structures within multidimensional datasets.

# %%
fig = plt.figure()

# creates the 3d plot
ax = plt.axes(projection = '3d')

# %%
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]
z = [1, 8, 27, 64, 125]

fig=plt.figure()

ax = plt.axes(projection='3d')
ax.plot(x,y,z)
plt.show()

# %% [markdown]
# **Parts of a Matplotlib Figure**
#
# Refer the link
# https://matplotlib.org/stable/_images/anatomy.png
